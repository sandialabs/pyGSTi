# %%
import std_clifford_compilations
std_clifford_compilations.test_clifford_compilations()
print("Std compilations success")
import rb_theory
rb_theory.test_rb_theory()
print("RB theory success")
import rb_simulate
rb_simulate.test_rb_simulate()
print("RB simulate success")
import rb_group
rb_group.test_rb_group()
print("RB group success")
import rb_io_results_and_analysis
rb_io_results_and_analysis.test_rb_io_results_and_analysis()
print("RB io, results and analysis success")
import rb_sample
rb_sample.test_sample()
print("RB sample success")
import algorithms_compilers
algorithms_compilers.test_compilers()
print("Compilers success")
import objects_circuit
objects_circuit.test_circuit()
print("Circuit success")
import objects_processorspec
objects_processorspec.test_processorspec()
print("ProcessorSpec success")
import tools_internalgates
tools_internalgates.test_internalgates()
print("Internal gates success")
import tools_symplectic
tools_symplectic.test_symplectic()
print("Symplectic success")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# Std compilations success
# RB theory success
# RB simulate success
# RB group success
# Importing testfiles/rb_io_test.txt...Complete.
# RB io, results and analysis success
# RB sample success
# Compilers success
# Circuit success
# ProcessorSpec success
# Internal gates success
# Symplectic success
