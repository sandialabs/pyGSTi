# %% [markdown]
# # An overview of Gate Set tomography the function-based way.

# %% [markdown]
# This tutorial shows you how to run gate set tomography using the older-style function-centric API.  This can be useful in certain scenarios, but most of the time it's easier to use the newer, object-oriented approach outlined in the main [GST overview tutorial](GST-Overview.ipynb).  For more details and options for running GST, see the [GST circuits tutorial](../objects/advanced/GSTCircuitConstruction.ipynb) and the [tutorial covering the different pyGSTi functions for running GST](GST-Drivers.ipynb).
#
# To run GST, we need three inputs:
# 1. a "**target model**" which describes the desired, or ideal, operations we want our experimental hardware to perform.  In the example below, we use one of pyGSTi's build-in "model packs" (see the [tutorial on model packs](objects/advanced/ModelPacks.ipynb)) - which acts on a single qubit with the following operations:
#     - three gates: the identity, and $\pi/2$ rotations around the $x$- and $y$-axes.
#     - a single state preparation in the $|0\rangle$ state.
#     - a 2-outcome measurement with the label "0" associated with measuring $|0\rangle$ and "1" with measuring $|1\rangle$.
#
# 2. a list of circuits tailored to the target model; essentially a list of what experiments we need to run.  Using a standard model makes things especially straightforward here, since the building blocks, called *germ* and *fiducial* circuits, needed to make good GST circuits have already been computed (see the [tutorial on GST circuits](../objects/advanced/GSTCircuitConstruction.ipynb)).
#
# 3. data, in the form of experimental outcome counts, for each of the required sequences.  In this example we'll generate "fake" or "simulated" data from a depolarized version of our ideal model.  For more information about `DataSet` objects, see the [tutorial on DataSets](../objects/DataSet.ipynb).

# %%
#Import the pygsti module (always do this) and the XYI model pack
import pygsti
from pygsti.modelpacks import smq1Q_XYI

# 1) get the target Model
target_model = smq1Q_XYI.target_model()

# 2) get the building blocks needed to specify which operation sequences are needed
prep_fiducials, meas_fiducials = smq1Q_XYI.prep_fiducials(), smq1Q_XYI.meas_fiducials()
germs = smq1Q_XYI.germs()
maxLengths = [1,2,4,8,16,32] # roughly gives the length of the sequences used by GST

# 3) generate "fake" data from a depolarized version of target_model
mdl_datagen = target_model.depolarize(op_noise=0.01, spam_noise=0.001)
listOfExperiments = pygsti.construction.make_lsgst_experiment_list(
    target_model, prep_fiducials, meas_fiducials, germs, maxLengths)
ds = pygsti.construction.generate_fake_data(mdl_datagen, listOfExperiments, nSamples=1000,
                                            sampleError="binomial", seed=1234)

#Note: from listOfExperiments we can also create an empty dataset file
# which has columns of zeros where actual data should go. 
pygsti.io.write_empty_dataset("../tutorial_files/GettingStartedDataTemplate.txt", listOfExperiments,
                              "## Columns = 0 count, 1 count")
# After replacing the zeros with actual data, the data set can be 
# loaded back into pyGSTi using the line below and used in the rest
# of this tutorial. 
#ds = pygsti.io.load_dataset("tutorial_files/GettingStartedDataTemplate.txt")

# %% [markdown]
# Now that we have all of the inputs, we can run GST in a standard way using the `do_stdpractice_gst` function.  For more information about this and related functions, see the [GST methods tutorial](GST-Drivers.ipynb).  This returns a `pygsti.report.Results` object (see the [Results tutorial](../objects/advanced/Results.ipynb)), from which we can generate a report giving us a summary of the analysis.

# %%
#Run GST and create a report
results = pygsti.do_stdpractice_gst(ds, target_model, prep_fiducials, meas_fiducials, 
                                    germs, maxLengths, verbosity=3)

pygsti.report.create_standard_report(results, filename="../tutorial_files/gettingStartedReport",
                                    title="GST Overview Tutorial Example Report", verbosity=2)
# Out:
# --- Circuit Creation ---
#    784 sequences created
# -- Std Practice:  Iter 1 of 3  (TP) --:
#   --- Iterative MLGST: Iter 1 of 6  92 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 75.234 (92 data params - 31 model params = expected mean of 61; p-value = 0.103921)
#     Completed in 0.6s
#     2*Delta(log(L)) = 76.7443
#     Iteration 1 took 0.6s
#
#   --- Iterative MLGST: Iter 2 of 6  168 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 150.337 (168 data params - 31 model params = expected mean of 137; p-value = 0.205839)
#     Completed in 0.5s
#     2*Delta(log(L)) = 153.02
#     Iteration 2 took 0.6s
#
#   --- Iterative MLGST: Iter 3 of 6  285 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 254.783 (285 data params - 31 model params = expected mean of 254; p-value = 0.474382)
#     Completed in 0.7s
#     2*Delta(log(L)) = 259.904
#     Iteration 3 took 0.9s
#
#   --- Iterative MLGST: Iter 4 of 6  448 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 418.056 (448 data params - 31 model params = expected mean of 417; p-value = 0.476228)
#     Completed in 1.1s
#     2*Delta(log(L)) = 423.508
#     Iteration 4 took 1.3s
#
#   --- Iterative MLGST: Iter 5 of 6  616 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 559.61 (616 data params - 31 model params = expected mean of 585; p-value = 0.768443)
#     Completed in 1.5s
#     2*Delta(log(L)) = 564.273
#     Iteration 5 took 1.8s
#
#   --- Iterative MLGST: Iter 6 of 6  784 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 722.85 (784 data params - 31 model params = expected mean of 753; p-value = 0.779441)
#     Completed in 2.1s
#     2*Delta(log(L)) = 726.367
#     Iteration 6 took 2.6s
#
#     Switching to ML objective (last iteration)
#     --- MLGST ---
#       Maximum log(L) = 362.74 below upper bound of -1.2109e+06
#         2*Delta(log(L)) = 725.481 (784 data params - 31 model params = expected mean of 753; p-value = 0.758264)
#       Completed in 2.3s
#     2*Delta(log(L)) = 725.481
#     Final MLGST took 2.3s
#
#   Iterative MLGST Total Time: 10.1s
# -- Std Practice:  Iter 2 of 3  (CPTP) --:
#   --- Iterative MLGST: Iter 1 of 6  92 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 78.0495 (92 data params - 31 model params = expected mean of 61; p-value = 0.0696274)
#     Completed in 4.3s
#     2*Delta(log(L)) = 79.4928
#     Iteration 1 took 4.3s
#
#   --- Iterative MLGST: Iter 2 of 6  168 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 151.456 (168 data params - 31 model params = expected mean of 137; p-value = 0.188271)
#     Completed in 18.2s
#     2*Delta(log(L)) = 154.174
#     Iteration 2 took 18.2s
#
#   --- Iterative MLGST: Iter 3 of 6  285 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 255.52 (285 data params - 31 model params = expected mean of 254; p-value = 0.461421)
#     Completed in 5.4s
#     2*Delta(log(L)) = 260.65
#     Iteration 3 took 5.6s
#
#   --- Iterative MLGST: Iter 4 of 6  448 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 422.163 (448 data params - 31 model params = expected mean of 417; p-value = 0.420309)
#     Completed in 2.4s
#     2*Delta(log(L)) = 427.614
#     Iteration 4 took 2.6s
#
#   --- Iterative MLGST: Iter 5 of 6  616 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 559.625 (616 data params - 31 model params = expected mean of 585; p-value = 0.768305)
#     Completed in 4.6s
#     2*Delta(log(L)) = 564.331
#     Iteration 5 took 4.9s
#
#   --- Iterative MLGST: Iter 6 of 6  784 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 722.86 (784 data params - 31 model params = expected mean of 753; p-value = 0.779357)
#     Completed in 3.5s
#     2*Delta(log(L)) = 726.446
#     Iteration 6 took 3.9s
#
#     Switching to ML objective (last iteration)
#     --- MLGST ---
#       Maximum log(L) = 362.783 below upper bound of -1.2109e+06
#         2*Delta(log(L)) = 725.566 (784 data params - 31 model params = expected mean of 753; p-value = 0.757559)
#       Completed in 1.6s
#     2*Delta(log(L)) = 725.566
#     Final MLGST took 1.6s
#
#   Iterative MLGST Total Time: 41.2s
# -- Std Practice:  Iter 3 of 3  (Target) --:
# *** Creating workspace ***
# *** Generating switchboard ***
# Found standard clifford compilation from smq1Q_XYI
# Found standard clifford compilation from smq1Q_XYI
# Found standard clifford compilation from smq1Q_XYI
# *** Generating tables ***
#   targetSpamBriefTable                          took 0.88686 seconds
#   targetGatesBoxTable                           took 0.475044 seconds
#   datasetOverviewTable                          took 0.107075 seconds
#   bestGatesetSpamParametersTable                took 0.002207 seconds
#   bestGatesetSpamBriefTable                     took 0.763393 seconds
#   bestGatesetSpamVsTargetTable                  took 0.759512 seconds
#   bestGatesetGaugeOptParamsTable                took 0.008367 seconds
#   bestGatesetGatesBoxTable                      took 0.644076 seconds
#   bestGatesetChoiEvalTable                      took 2.05254 seconds
#   bestGatesetDecompTable                        took 1.610805 seconds
#   bestGatesetEvalTable                          took 0.01906 seconds
#   bestGermsEvalTable                            took 0.079704 seconds
#   bestGatesetVsTargetTable                      took 0.470052 seconds
#   bestGatesVsTargetTable_gv                     took 1.107188 seconds
#   bestGatesVsTargetTable_gvgerms                took 0.252192 seconds
#   bestGatesVsTargetTable_gi                     took 0.085278 seconds
#   bestGatesVsTargetTable_gigerms                took 0.13359 seconds
#   bestGIGatesetTable                            took 3.223329 seconds
#   bestGatesVsTargetTable_sum                    took 1.046289 seconds
#   bestGatesetErrGenBoxTable                     took 4.272094 seconds
#   metadataTable                                 took 0.002975 seconds
#   stdoutBlock                                   took 0.001551 seconds
#   profilerTable                                 took 0.002898 seconds
#   softwareEnvTable                              took 0.047163 seconds
#   exampleTable                                  took 0.128411 seconds
#   singleMetricTable_gv                          took 1.141728 seconds
#   singleMetricTable_gi                          took 0.042064 seconds
#   bestGIMetricTable                             took 7.108645 seconds
#   fiducialListTable                             took 0.001188 seconds
#   prepStrListTable                              took 0.000343 seconds
#   effectStrListTable                            took 0.000423 seconds
#   colorBoxPlotKeyPlot                           took 0.142251 seconds
#   germList2ColTable                             took 0.000335 seconds
#   progressTable                                 took 18.000184 seconds
# *** Generating plots ***
#   gramBarPlot                                   took 0.209441 seconds
#   progressBarPlot                               took 5.764995 seconds
#   progressBarPlot_sum                           took 0.003347 seconds
#   finalFitComparePlot                           took 0.112393 seconds
#   bestEstimateColorBoxPlot                      took 51.539969 seconds
#   bestEstimateTVDColorBoxPlot                   took 12.304213 seconds
#   bestEstimateColorScatterPlot                  took 7.431503 seconds
#   bestEstimateColorHistogram                    took 3.382316 seconds
#   progressTable_scl                             took 0.000118 seconds
#   progressBarPlot_scl                           took 0.000106 seconds
#   bestEstimateColorBoxPlot_scl                  took 0.000612 seconds
#   bestEstimateColorScatterPlot_scl              took 0.000773 seconds
#   bestEstimateColorHistogram_scl                took 0.000772 seconds
#   progressTable_ume                             took 0.000195 seconds
#   progressBarPlot_ume                           took 0.000201 seconds
#   bestEstimateColorBoxPlot_ume                  took 0.000895 seconds
#   bestEstimateColorScatterPlot_ume              took 0.001002 seconds
#   bestEstimateColorHistogram_ume                took 0.000802 seconds
#   dataScalingColorBoxPlot                       took 0.000151 seconds
#   unmodeledErrorBudgetTable                     took 0.000111 seconds
# *** Merging into template file ***
# *** Report Generation Complete!  Total time 137.704s ***

# %% [markdown]
# You can now open the file [../tutorial_files/gettingStartedReport/main.html](../tutorial_files/gettingStartedReport/main.html) in your browser (Firefox works best) to view the report.  **That's it!  You've just run GST!**
#
# In the cell above, `results` is a `Results` object, which is used to generate a HTML report.  For more information see the [Results object tutorial](../objects/advanced/Results.ipynb) and [report generation tutorial](../reporting/ReportGeneration.ipynb).
