# %% [markdown]
# # Getting started with pyGSTi and Gate Set Tomography

# %% [markdown]
# The `pygsti` package provides multiple levels of abstraction over the core Gate Set Tomography (GST) algorithms.  This initial tutorial will show you how to run Gate Set Tomography on some simulated (generated) data, hopefully giving you an overall sense of what it takes (and how easy it is!) to run GST.  Subsequent tutorials will delve into the details of `pygsti` objects and algorithms, and how to use them in detail.
#
# To run GST, we need three inputs:
# 1. a "**target model**" which describes the desired, or ideal, operations we want our experimental hardware to perform.  In the example below, we use one of pyGSTi's "standard" models - the on acting on a single qubit with the following operations:
#     - three gates: the identity, and $\pi/2$ rotations around the $x$- and $y$-axes.
#     - a single state preparation in the $|0\rangle$ state.
#     - a 2-outcome measurement with the label "0" associated with measuring $|0\rangle$ and "1" with measuring $|1\rangle$.
#
# 2. a list of GST sequences corresponding to the target model; essentially a list of what experiments (circuits) we need to run.  Using a standard model makes things especially straightforward here, since the building blocks, called *germ* and *fiducial* circuits, needed to make good GST circuits have already been computed.
#
# 3. data, in the form of experimental outcome counts, for each of the required sequences.  In this example we'll generate "fake" or "simulated" data from a depolarized version of our ideal model.

# %%
#Make print statements compatible with Python 2 and 3
from __future__ import print_function

#Import the pygsti module (always do this) and the standard XYI model
import pygsti
from pygsti.construction import std1Q_XYI

# 1) get the target Model
target_model = std1Q_XYI.target_model

# 2) get the building blocks needed to specify which operation sequences are needed
prep_fiducials, meas_fiducials = std1Q_XYI.prepStrs, std1Q_XYI.effectStrs
germs = std1Q_XYI.germs
maxLengths = [1,2,4,8,16,32] # roughly gives the length of the sequences used by GST

# 3) generate "fake" data from a depolarized version of target_model
mdl_datagen = target_model.depolarize(op_noise=0.01, spam_noise=0.001)
listOfExperiments = pygsti.construction.make_lsgst_experiment_list(
    target_model, prep_fiducials, meas_fiducials, germs, maxLengths)
ds = pygsti.construction.generate_fake_data(mdl_datagen, listOfExperiments, nSamples=1000,
                                            sampleError="binomial", seed=1234)

#Note: from listOfExperiments we can also create an empty dataset file
# which has columns of zeros where actual data should go. 
pygsti.io.write_empty_dataset("tutorial_files/GettingStartedDataTemplate.txt", listOfExperiments,
                              "## Columns = 1 count, count total")
# After replacing the zeros with actual data, the data set can be 
# loaded back into pyGSTi using the line below and used in the rest
# of this tutorial. 
#ds = pygsti.io.load_dataset("tutorial_files/GettingStartedDataTemplate.txt")

# %% [markdown]
# Now that we have all of the inputs, we can run GST in a standard way using the `do_stdpractice_gst` high-level driver function.  This returns a `pygsti.report.Results` object, from which we can generate a report giving us a summary of the analysis.

# %%
#Run GST and create a report
results = pygsti.do_stdpractice_gst(ds, target_model, prep_fiducials, meas_fiducials, 
                                    germs, maxLengths, verbosity=3)

pygsti.report.create_standard_report(results, filename="tutorial_files/gettingStartedReport",
                                    title="Tutorial0 Example Report", verbosity=2)
# Out:
# -- Std Practice:  Iter 1 of 3  (TP) --:
#   --- LinearOperator Sequence Creation ---
#      1702 sequences created
#      Dataset has 1702 entries: 1702 utilized, 0 requested sequences were missing
#   --- LGST ---
#     Singular values of I_tilde (truncating to first 4 of 6) =
#     4.243095501422058
#     1.3901808798412303
#     1.366465649836718
#     1.345711384664332
#     0.024975111125949443
#     0.006813806654669674
#
#     Singular values of target I_tilde (truncating to first 4 of 6) =
#     4.242640687119286
#     1.414213562373096
#     1.4142135623730956
#     1.4142135623730954
#     2.5038933168948026e-16
#     2.023452063009528e-16
#
#   --- Iterative MLGST: Iter 1 of 6  92 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 81.6754 (91 data params - 31 model params = expected mean of 60; p-value = 0.0328873)
#     Completed in 0.2s
#     2*Delta(log(L)) = 82.4971
#     Iteration 1 took 0.2s
#
#   --- Iterative MLGST: Iter 2 of 6  168 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 145.571 (167 data params - 31 model params = expected mean of 136; p-value = 0.27177)
#     Completed in 0.1s
#     2*Delta(log(L)) = 147.471
#     Iteration 2 took 0.1s
#
#   --- Iterative MLGST: Iter 3 of 6  450 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 440.19 (449 data params - 31 model params = expected mean of 418; p-value = 0.218506)
#     Completed in 0.3s
#     2*Delta(log(L)) = 445.072
#     Iteration 3 took 0.3s
#
#   --- Iterative MLGST: Iter 4 of 6  862 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 883.073 (861 data params - 31 model params = expected mean of 830; p-value = 0.0981565)
#     Completed in 0.5s
#     2*Delta(log(L)) = 890.914
#     Iteration 4 took 0.5s
#
#   --- Iterative MLGST: Iter 5 of 6  1282 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 1310.35 (1281 data params - 31 model params = expected mean of 1250; p-value = 0.114814)
#     Completed in 0.8s
#     2*Delta(log(L)) = 1318.52
#     Iteration 5 took 0.9s
#
#   --- Iterative MLGST: Iter 6 of 6  1702 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 1719.42 (1701 data params - 31 model params = expected mean of 1670; p-value = 0.195363)
#     Completed in 1.1s
#     2*Delta(log(L)) = 1727.85
#     Iteration 6 took 1.2s
#
#     Switching to ML objective (last iteration)
#     --- MLGST ---
#       Maximum log(L) = 862.67 below upper bound of -2.63408e+06
#         2*Delta(log(L)) = 1725.34 (1701 data params - 31 model params = expected mean of 1670; p-value = 0.168856)
#       Completed in 0.5s
#     2*Delta(log(L)) = 1725.34
#     Final MLGST took 0.5s
#
#   Iterative MLGST Total Time: 3.6s
#   -- Performing 'single' gauge optimization on TP estimate --
# -- Std Practice:  Iter 2 of 3  (CPTP) --:
#   --- LinearOperator Sequence Creation ---
#      1702 sequences created
#      Dataset has 1702 entries: 1702 utilized, 0 requested sequences were missing
#   --- Iterative MLGST: Iter 1 of 6  92 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 86.2545 (91 data params - 31 model params = expected mean of 60; p-value = 0.0148207)
#     Completed in 49.7s
#     2*Delta(log(L)) = 87.4462
#     Iteration 1 took 49.7s
#
#   --- Iterative MLGST: Iter 2 of 6  168 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 146.49 (167 data params - 31 model params = expected mean of 136; p-value = 0.25444)
#     Completed in 1.7s
#     2*Delta(log(L)) = 148.699
#     Iteration 2 took 1.7s
#
#   --- Iterative MLGST: Iter 3 of 6  450 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 440.728 (449 data params - 31 model params = expected mean of 418; p-value = 0.213245)
#     Completed in 1.7s
#     2*Delta(log(L)) = 445.969
#     Iteration 3 took 1.7s
#
#   --- Iterative MLGST: Iter 4 of 6  862 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 883.111 (861 data params - 31 model params = expected mean of 830; p-value = 0.0980006)
#     Completed in 2.5s
#     2*Delta(log(L)) = 890.996
#     Iteration 4 took 2.5s
#
#   --- Iterative MLGST: Iter 5 of 6  1282 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 1325.24 (1281 data params - 31 model params = expected mean of 1250; p-value = 0.0682677)
#     Completed in 2.2s
#     2*Delta(log(L)) = 1333.63
#     Iteration 5 took 2.2s
#
#   --- Iterative MLGST: Iter 6 of 6  1702 operation sequences ---:
#     --- Minimum Chi^2 GST ---
#     Sum of Chi^2 = 1837.81 (1701 data params - 31 model params = expected mean of 1670; p-value = 0.002377)
#     Completed in 4.8s
#     2*Delta(log(L)) = 1846.55
#     Iteration 6 took 4.8s
#
#     Switching to ML objective (last iteration)
#     --- MLGST ---
#       Maximum log(L) = 921.987 below upper bound of -2.63408e+06
#         2*Delta(log(L)) = 1843.97 (1701 data params - 31 model params = expected mean of 1670; p-value = 0.0017326)
#       Completed in 1.6s
#     2*Delta(log(L)) = 1843.97
#     Final MLGST took 1.6s
#
#   Iterative MLGST Total Time: 64.3s
#   --- Re-optimizing logl after robust data scaling ---
#     --- MLGST ---
#       Maximum log(L) = 921.987 below upper bound of -2.63408e+06
#         2*Delta(log(L)) = 1843.97 (1701 data params - 31 model params = expected mean of 1670; p-value = 0.0017326)
#       Completed in 0.4s
#   -- Performing 'single' gauge optimization on CPTP estimate --
#   -- Conveying 'single' gauge optimization to CPTP.Robust+ estimate --
# -- Std Practice:  Iter 3 of 3  (Target) --:
#   --- LinearOperator Sequence Creation ---
#      1702 sequences created
#      Dataset has 1702 entries: 1702 utilized, 0 requested sequences were missing
#   -- Performing 'single' gauge optimization on Target estimate --
# *** Creating workspace ***
# *** Generating switchboard ***
# Found standard clifford compilation from std1Q_XYI
# Found standard clifford compilation from std1Q_XYI
# Found standard clifford compilation from std1Q_XYI
# *** Generating tables ***
#   targetSpamBriefTable                          took 0.532788 seconds
#   targetGatesBoxTable                           took 0.26232 seconds
#   datasetOverviewTable                          took 0.068404 seconds
#   bestGatesetSpamParametersTable                took 0.001233 seconds
#   bestGatesetSpamBriefTable                     took 0.230493 seconds
#   bestGatesetSpamVsTargetTable                  took 0.143169 seconds
#   bestGatesetGaugeOptParamsTable                took 0.00073 seconds
#   bestGatesetGatesBoxTable                      took 0.283369 seconds
#   bestGatesetChoiEvalTable                      took 0.758809 seconds
#   bestGatesetDecompTable                        took 0.455107 seconds
#   bestGatesetEvalTable                          took 0.008207 seconds
#   bestGermsEvalTable                            took 0.040729 seconds
#   bestGatesetVsTargetTable                      took 0.115466 seconds
#   bestGatesVsTargetTable_gv                     took 0.43428 seconds
#   bestGatesVsTargetTable_gvgerms                took 0.180195 seconds
#   bestGatesVsTargetTable_gi                     took 0.033509 seconds
#   bestGatesVsTargetTable_gigerms                took 0.048722 seconds
#   bestGatesVsTargetTable_sum                    took 0.404023 seconds
#   bestGatesetErrGenBoxTable                     took 1.41634 seconds
#   metadataTable                                 took 0.001145 seconds
#   stdoutBlock                                   took 0.000627 seconds
#   profilerTable                                 took 0.001091 seconds
#   softwareEnvTable                              took 0.02939 seconds
#   exampleTable                                  took 0.04221 seconds
#   singleMetricTable_gv                          took 0.43312 seconds
#   singleMetricTable_gi                          took 0.032961 seconds
#   fiducialListTable                             took 0.000456 seconds
#   prepStrListTable                              took 0.000154 seconds
#   effectStrListTable                            took 0.000285 seconds
#   colorBoxPlotKeyPlot                           took 0.044975 seconds
#   germList2ColTable                             took 0.001504 seconds
#   progressTable                                 took 7.263789 seconds
# *** Generating plots ***
#   gramBarPlot                                   took 0.166266 seconds
#   progressBarPlot                               took 0.117586 seconds
#   progressBarPlot_sum                           took 0.00092 seconds
#   finalFitComparePlot                           took 0.0382 seconds
#   bestEstimateColorBoxPlot                      took 28.929922 seconds
#   bestEstimateTVDColorBoxPlot                   took 28.909446 seconds
#   bestEstimateColorScatterPlot                  took 35.212762 seconds
#   bestEstimateColorHistogram                    took 29.220708 seconds
#   progressTable_scl                             took 2.616497 seconds
#   progressBarPlot_scl                           took 0.042937 seconds
#   bestEstimateColorBoxPlot_scl                  took 10.362508 seconds
#   bestEstimateColorScatterPlot_scl              took 11.006559 seconds
#   bestEstimateColorHistogram_scl                took 9.015566 seconds
#   dataScalingColorBoxPlot                       took 0.287047 seconds
# *** Merging into template file ***
#   Rendering topSwitchboard                      took 0.000144 seconds
#   Rendering maxLSwitchboard1                    took 9.4e-05 seconds
#   Rendering targetSpamBriefTable                took 0.201299 seconds
#   Rendering targetGatesBoxTable                 took 0.174896 seconds
#   Rendering datasetOverviewTable                took 0.001098 seconds
#   Rendering bestGatesetSpamParametersTable      took 0.005759 seconds
#   Rendering bestGatesetSpamBriefTable           took 0.658161 seconds
#   Rendering bestGatesetSpamVsTargetTable        took 0.006115 seconds
#   Rendering bestGatesetGaugeOptParamsTable      took 0.00345 seconds
#   Rendering bestGatesetGatesBoxTable            took 0.339748 seconds
#   Rendering bestGatesetChoiEvalTable            took 0.323863 seconds
#   Rendering bestGatesetDecompTable              took 0.197449 seconds
#   Rendering bestGatesetEvalTable                took 0.035566 seconds
#   Rendering bestGermsEvalTable                  took 0.136267 seconds
#   Rendering bestGatesetVsTargetTable            took 0.003326 seconds
#   Rendering bestGatesVsTargetTable_gv           took 0.010189 seconds
#   Rendering bestGatesVsTargetTable_gvgerms      took 0.021861 seconds
#   Rendering bestGatesVsTargetTable_gi           took 0.008524 seconds
#   Rendering bestGatesVsTargetTable_gigerms      took 0.008242 seconds
#   Rendering bestGatesVsTargetTable_sum          took 0.009898 seconds
#   Rendering bestGatesetErrGenBoxTable           took 0.746213 seconds
#   Rendering metadataTable                       took 0.007371 seconds
#   Rendering stdoutBlock                         took 0.003374 seconds
#   Rendering profilerTable                       took 0.005669 seconds
#   Rendering softwareEnvTable                    took 0.003337 seconds
#   Rendering exampleTable                        took 0.022905 seconds
#   Rendering metricSwitchboard_gv                took 4.3e-05 seconds
#   Rendering metricSwitchboard_gi                took 3.1e-05 seconds
#   Rendering singleMetricTable_gv                took 0.015612 seconds
#   Rendering singleMetricTable_gi                took 0.008269 seconds
#   Rendering fiducialListTable                   took 0.003575 seconds
#   Rendering prepStrListTable                    took 0.002872 seconds
#   Rendering effectStrListTable                  took 0.002801 seconds
#   Rendering colorBoxPlotKeyPlot                 took 0.031088 seconds
#   Rendering germList2ColTable                   took 0.004525 seconds
#   Rendering progressTable                       took 0.014254 seconds
#   Rendering gramBarPlot                         took 0.065322 seconds
#   Rendering progressBarPlot                     took 0.059148 seconds
#   Rendering progressBarPlot_sum                 took 0.06068 seconds
#   Rendering finalFitComparePlot                 took 0.022891 seconds
#   Rendering bestEstimateColorBoxPlot            took 0.557926 seconds
#   Rendering bestEstimateTVDColorBoxPlot         took 0.537744 seconds
#   Rendering bestEstimateColorScatterPlot        took 0.982042 seconds
#   Rendering bestEstimateColorHistogram          took 0.585785 seconds
#   Rendering progressTable_scl                   took 0.006435 seconds
#   Rendering progressBarPlot_scl                 took 0.020137 seconds
#   Rendering bestEstimateColorBoxPlot_scl        took 0.186614 seconds
#   Rendering bestEstimateColorScatterPlot_scl    took 0.330425 seconds
#   Rendering bestEstimateColorHistogram_scl      took 0.196902 seconds
#   Rendering dataScalingColorBoxPlot             took 0.045242 seconds
# Output written to tutorial_files/gettingStartedReport directory
# *** Report Generation Complete!  Total time 176.266s ***

# %% [markdown]
# You can now open the file [tutorial_files/gettingStartedReport/main.html](tutorial_files/gettingStartedReport/main.html) in your browser to view the report.  **That's it!  You've just run GST!**
#
# The other tutorials in this directory will explain how to use the various objects and algorithms that comprise pyGSTi. These **tutorial notebooks are meant to be fairly pedagogical** and include details about the inner workings of and design choices within pyGSTi.  In contrast, the **"FAQ" directory contains notebooks which attempt to address specific questions as quickly and directly as possible, with little or no explanation of related topics or broader context**.
