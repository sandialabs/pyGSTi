# %% [markdown]
# ## Tutorial showing use of a `Workspace` object
# ### Part 2: Switchboards
# This tutorial introduces the `Switchboard` workspace object and demonstrates its use.  You may have gotten the sense from the last tutorial that screen real estate can quickly be taken up by plots and tables.  Wouldn't it me nice if we could interactively switch between plots or figures using buttons or sliders instead of having to scroll through endless pages of plots?  `Switchboard` to the rescue!
#
# First though, let's run GST on the standard 1Q gate set to get some results (the same ones as the first tutorial).

# %%
import numpy as np
import pygsti
from pygsti.construction import std1Q_XYI

#The usual GST setup: we're going to run GST on the standard XYI 1-qubit gateset
gs_target = std1Q_XYI.gs_target
fiducials = std1Q_XYI.fiducials
germs = std1Q_XYI.germs
maxLengths = [1,2,4,8]
listOfExperiments = pygsti.construction.make_lsgst_experiment_list(
    gs_target.gates.keys(), fiducials, fiducials, germs, maxLengths)

#Create some datasets for analysis
gs_datagen1 = gs_target.depolarize(gate_noise=0.1, spam_noise=0.001)
gs_datagen2 = gs_target.depolarize(gate_noise=0.05, spam_noise=0.01).rotate(rotate=0.01)

ds1 = pygsti.construction.generate_fake_data(gs_datagen1, listOfExperiments, nSamples=1000,
                                            sampleError="binomial", seed=1234)
ds2 = pygsti.construction.generate_fake_data(gs_datagen2, listOfExperiments, nSamples=1000,
                                            sampleError="binomial", seed=1234)
ds3 = ds1.copy_nonstatic(); ds3.add_counts_from_dataset(ds2); ds3.done_adding_data()

#Run GST on all three datasets
gs_target.set_all_parameterizations("TP")
results1 = pygsti.do_long_sequence_gst(ds1, gs_target, fiducials, fiducials, germs, maxLengths, verbosity=0)
results2 = pygsti.do_long_sequence_gst(ds2, gs_target, fiducials, fiducials, germs, maxLengths, verbosity=0)
results3 = pygsti.do_long_sequence_gst(ds3, gs_target, fiducials, fiducials, germs, maxLengths, verbosity=0)

#make some shorthand variable names for later
tgt = results1.gatesets['target']

ds1 = results1.dataset
ds2 = results2.dataset
ds3 = results3.dataset

gs1 = results1.gatesets['final estimate']
gs2 = results2.gatesets['final estimate']
gs3 = results3.gatesets['final estimate']

gss = results1.gatestring_structs['final']

# %% [markdown]
# Next we create the workspace, as before.  This time, we'll leave `autodisplay=False` (the default), to demonstrate how this gives us more control over when workspace items are displayed.  In particular, we'll build up a several workspace objects and display them all at once.

# %%
from pygsti.report import workspace
w = workspace.Workspace()  #create a new workspace
w.init_notebook_mode(connected=True) # and initialize it so it works within a notebook
# Out:
#                 <script>
#                 var waitForPlotly = setInterval( function() {
#                 if( typeof(window.Plotly) !== "undefined" ){
#                     MathJax.Hub.Config({ SVG: { font: "STIX-Web" }, displayAlign: "center" });
#                     MathJax.Hub.Queue(["setRenderer", MathJax.Hub, "SVG"]);
#                     clearInterval(waitForPlotly);
#                 }}, 250 );
#                 </script>
# <style>
#
# .dataTable td, .dataTable th {
# 	/* appearance */
# 	border: 2px solid #333;
#
# 	/* size */
# 	padding: 5px;
# 	}
#
# .dataTable {
#         /* text */
#         /*font-family: "Computer Modern Serif","times new roman",serif;*/
# 	'Helvetica Neue', Helvetica, Arial, sans-serif;
#
# 	/* no space between cells */
# 	border-spacing: 0px;
# 	border-collapse: collapse;
# 	}
#
# .dataTable a {
# 	/* link text */
# 	font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif;
# 	text-decoration: none;
# 	color: #000000;
# 	}
# .dataTable a:hover { color: #0000FF; }
#
# .dataTable tbody tr td {
# 	/* appearance */
# 	background-color: #ffffff;
# 	background-image: -moz-linear-gradient(
# 		top,
# 		rgba(255,255,255,0.4) 0%,
# 		rgba(255,255,255,0.2) 50%,
# 		rgba(255,255,255,0.1) 51%,
# 		rgba(255,255,255,0.0) 100%);
#
# 	background-image: -webkit-gradient(
# 		linear, left top, left bottom,
# 		color-stop(0%,rgba(255,255,255,0.4)),
# 		color-stop(50%,rgba(255,255,255,0.2)),
# 		color-stop(51%,rgba(255,255,255,0.1)),
# 		color-stop(100%,rgba(255,255,255,0.0)));
#
# 	/* text */
# 	color: #262c31;
#
# 	/* font */
# 	font-family: "Computer Modern Serif","times new roman",serif;
#
# 	/* font-size: 90%; */
# 	font-size: 10pt;
#
# 	/* text alignment */
# 	text-align: center;
# 	vertical-align: middle;
# 	}
#
# .dataTable tbody tr.odd td {
# 	/* appearance */
# 	background-color: #d6e0ef;
# 	background-image: -moz-linear-gradient(
# 		top,
# 		rgba(255,255,255,0.4) 0%,
# 		rgba(255,255,255,0.2) 50%,
# 		rgba(255,255,255,0.1) 51%,
# 		rgba(255,255,255,0.0) 100%);
#
# 	background-image: -webkit-gradient(
# 		linear, left top, left bottom,
# 		color-stop(0%,rgba(255,255,255,0.4)),
# 		color-stop(50%,rgba(255,255,255,0.2)),
# 		color-stop(51%,rgba(255,255,255,0.1)),
# 		color-stop(100%,rgba(255,255,255,0.0)));
# 	}
#
# .dataTable thead tr th,
# .dataTable tfoot tr td {
# 	/* appearance */
#         background-color: #333;
#
# 	/* text */
# 	color: #ffffff;
# 	font-size: 12px;
# 	font-weight: bold;
# 	text-align: center;
# 	}
#
# /* OLD
# background-color: #036;
# */
#
# /* VERY OLD
# 	background-image: -moz-linear-gradient(
# 		top,
# 		rgba(255,255,255,0.4) 0%,
# 		rgba(255,255,255,0.2) 50%,
# 		rgba(255,255,255,0.1) 51%,
# 		rgba(255,255,255,0.0) 100%);
#
# 	background-image: -webkit-gradient(
# 		linear, left top, left bottom,
# 		color-stop(0%,rgba(255,255,255,0.4)),
# 		color-stop(50%,rgba(255,255,255,0.2)),
# 		color-stop(51%,rgba(255,255,255,0.1)),
# 		color-stop(100%,rgba(255,255,255,0.0)));
# */
#
# .dataTableHeading {
# 	font-weight: bold;
# 	color: #333;
# 	margin-bottom: 5px;
# }
#
# .dataTableHeading > a {
#         text-decoration: none;
# 	color: #333;
# }
#
# .dataTableHeading > a:hover {
# 	color: #00CDF0;
# }
#
#
#
# </style>
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.12.1/themes/smoothness/jquery-ui.css">
# <style>
# .tooltipbuttons .ui-button { padding: 0; border: 0; background: transparent; }
# .tooltipbuttons .ui-icon { background-image: url("https://code.jquery.com/ui/1.12.1/themes/smoothness/images/ui-icons_222222_256x240.png"); margin-top: 0; }
# </style>
#             <script>requirejs.config({paths: { 'jquery-UI': ['https://code.jquery.com/ui/1.12.1/jquery-ui.min']},});
#               require(['jquery-UI'],function(ui) {
#               window.jQueryUI=ui;});
#             </script>
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# Note that if we create a table it doesn't get displayed automatically.

# %%
tbl1 = w.GatesVsTargetTable(gs1, tgt)

# %% [markdown]
# To see it, we need to call `display()`:

# %%
tbl1.display()
# Out:
# <script>
# require(['jquery','jquery-UI'],function($,ui) {$( function() {
#   var switchmap_table_9663 = new Array();
#   switchmap_table_9663[ [] ] = 'table_9663_0';
#   window.switchmap_table_9663 = switchmap_table_9663;
#
# $( '#table_9663' ).show()
# });
#
#  });</script><div id='table_9663' style='display: hidden'>
# <div id='table_9663_0'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074856</td></tr><tr><td>Gx</td><td>0.07094</td><td>0.070941</td><td>0.070941</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076933</td></tr></tbody></table>
# </div>
#
# </div>

# %% [markdown]
# ### Switchboards
# A `Switchboard` is essentially a collection of one or more switches along with a dictionary of "values" which depend on some or all of the switch positions.  Each value looks like a NumPy `ndarray` whose axes correspond to the switches that value depends upon.  The array can hold whatever you want: `GateSet`s, `DataSet`s, `float`s, etc., and from the perspective of the plot and table workspace objects the value looks like the thing contained in its array (e.g. a *single* `GateSet`, `DataSet`, or `float`, etc.).
#
# Let's start off simple and create a switchboard with a single switch named "My Switch" that has two positions "On" and "Off":

# %%
switchbd = w.Switchboard(["My Switch"],[["On","Off"]],["buttons"])

# %% [markdown]
# Next, add a "value" to the switchboard called "gs" (for "gate set"), with is dependent on the 0-th (and only) switch of the switchboard:

# %%
switchbd.add("gs", [0])

# %% [markdown]
# Now `switchbd` has a member, `gs`, which looks like a 1-dimensional Numpy array (since `gs` only depends on a single switch) of length 2 (because that single switch has 2 positions).

# %%
switchbd.gs.shape
# Out:
# (2,)

# %% [markdown]
# We'll use `switchbd.gs` to switch between the gate sets `gs1` and `gs2`.  We associate the "On" position with `gs1` and the "Off" position with `gs2` by simply assigning them to the corresponding locations of the array.  Note that we can use NumPy's fancy indexing to make this a breeze.

# %%
switchbd.gs[:] = [gs1,gs2]

# %% [markdown]
# Ok, now here's the magical part: even though `switchbd.gs` is really an array holding `GateSet` objects, when you provide it as an input to create a workspace item such as a plot or a table, it *behaves* like a single `GateSet` and can thus be used for any `GateSet`-type argument.  We'll use it as the first argument to `GatesVsTargetTable`.

# %%
tbl2 = w.GatesVsTargetTable(switchbd.gs, tgt)

# %% [markdown]
# Note the the second argument (`tgt`, the target gate set) in the above call is just a plain old `GateSet`, just like it's always been up to this point.  The above line creates a table, `tbl2`, that is *connected* to the switchboard `switchbd`.  Let's display both the switchboard and the table together.  Note that currently, the **switchboard must be displayed *before* any dependent plots or tables**.

# %%
switchbd.display()
tbl2.display()
# Out:
# <script>
# require(['jquery','jquery-UI'],function($,ui) {$(document).ready(function() {
#   $('#switchbd7966_0 > input').checkboxradio({ icon: false });
# }); });</script><fieldset id='switchbd7966_0'>
# <legend>My Switch: </legend>
# <label for='switchbd7966_0-0'>On</label>
# <input type='radio' name='switchbd7966_0' id='switchbd7966_0-0' value=0 checked='checked'>
# <label for='switchbd7966_0-1'>Off</label>
# <input type='radio' name='switchbd7966_0' id='switchbd7966_0-1' value=1>
# </fieldset>
# <script>
# require(['jquery','jquery-UI'],function($,ui) {$( function() {
#   var switchmap_table_6302 = new Array();
#   switchmap_table_6302[ [0] ] = 'table_6302_0';
#   switchmap_table_6302[ [1] ] = 'table_6302_1';
#   window.switchmap_table_6302 = switchmap_table_6302;
#
#   $('#switchbd7966_0').on('change', function() {table_6302_onchange_7966_0(); });
#   table_6302_onchange_7966_0();
# $( '#table_6302' ).show()
# });
#
# function table_6302_onchange_7966_0() {
#   var curSwitchPos = new Array();
#   curSwitchPos.push($("#switchbd7966_0 > input[name='switchbd7966_0']:checked").val());
#   var idToShow = switchmap_table_6302[ curSwitchPos ];
#   $( '#table_6302' ).children().hide();
#   $( '#' + idToShow ).show();
# }
#  });</script><div id='table_6302' style='display: hidden'>
# <div id='table_6302_0'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074856</td></tr><tr><td>Gx</td><td>0.07094</td><td>0.070941</td><td>0.070941</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076933</td></tr></tbody></table>
# </div>
#
# <div id='table_6302_1'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.038779</td><td>0.040832</td><td>0.040834</td></tr><tr><td>Gx</td><td>0.036812</td><td>0.037551</td><td>0.037555</td></tr><tr><td>Gy</td><td>0.037378</td><td>0.038203</td><td>0.038205</td></tr></tbody></table>
# </div>
#
# </div>

# %% [markdown]
# My pressing the "On" or "Off" button the table changes between displaying metrics for `gs1` vs. `tgt` and `gs2` vs. `tgt`, as expected.  In this simple example there was one switch controlling on table.  It is possible to have any number of switches controlling any number of tables and/or plots, and also to have multiple switchboards controlling a single plot or table.  In the following cells, more sophisticated uses of switchboards are demonstrated.

# %%
# Create a switchboard with straighforward dataset and gateset dropdown switches
switchbd2 = w.Switchboard(["dataset","gateset"], [["DS1","DS2","DS3"],["GS1","GS2","GS3"]], ["dropdown","dropdown"])
switchbd2.add("ds",(0,))
switchbd2.add("gs",(1,))
switchbd2.ds[:] = [ds1, ds2, ds3]
switchbd2.gs[:] = [gs1, gs2, gs3]

#Then create a chi2 plot that can show the goodness-of-fit between any gateset-dataset pair
gss2 = gss.copy(); gss2.germs = gss.germs[0:5] #truncate gss to only a subset of the germs
chi2plot = w.ColorBoxPlot(("chi2",), gss2, switchbd2.ds, switchbd2.gs, scale=0.75)

switchbd2.display()
chi2plot.display()
# Out:
# <script>
# require(['jquery','jquery-UI'],function($,ui) {$(document).ready(function() {
#   $('#switchbd2651_0').selectmenu();
#   $('#switchbd2651_1').selectmenu();
# }); });</script><div style='margin:2px'><fieldset>
# <label for='switchbd2651_0'>dataset</label>
# <select name='switchbd2651_0' id='switchbd2651_0'>
# <option value=0 selected='selected'>DS1</option>
# <option value=1>DS2</option>
# <option value=2>DS3</option>
# </select>
# </fieldset></div>
#
# <div style='margin:2px'><fieldset>
# <label for='switchbd2651_1'>gateset</label>
# <select name='switchbd2651_1' id='switchbd2651_1'>
# <option value=0 selected='selected'>GS1</option>
# <option value=1>GS2</option>
# <option value=2>GS3</option>
# </select>
# </fieldset></div>
# <script>
# require(['jquery','jquery-UI'],function($,ui) {$( function() {
#   var switchmap_plot_5505 = new Array();
#   switchmap_plot_5505[ [1,0] ] = '39551e0e-25cf-46db-8a5a-052bf9807f9e';
#   switchmap_plot_5505[ [0,1] ] = 'cb0d242b-f5e3-42eb-a0ef-459ce19e3163';
#   switchmap_plot_5505[ [1,2] ] = 'dc8ba1fa-fd17-4483-9c92-1529533c445f';
#   switchmap_plot_5505[ [2,0] ] = '992b27ab-3142-4288-88e4-ff3a7976be46';
#   switchmap_plot_5505[ [2,2] ] = '02133611-0db4-460e-9533-531f2bccf00a';
#   switchmap_plot_5505[ [0,2] ] = 'c51b3691-9b08-4c10-9796-aee1d63cdf31';
#   switchmap_plot_5505[ [0,0] ] = '44692e53-45b4-4627-b778-9aaefaed6a09';
#   switchmap_plot_5505[ [1,1] ] = 'a832e555-5419-40c8-b0d5-2b142bfaed0e';
#   switchmap_plot_5505[ [2,1] ] = 'f9dd6cd9-9a76-4896-9356-a675e07925e5';
#   window.switchmap_plot_5505 = switchmap_plot_5505;
#
#   $('#switchbd2651_0').on('selectmenuchange', function() {plot_5505_onchange_2651_0(); });
#   plot_5505_onchange_2651_0();
#   $('#switchbd2651_1').on('selectmenuchange', function() {plot_5505_onchange_2651_1(); });
#   plot_5505_onchange_2651_1();
# $( '#plot_5505' ).show()
# });
#
# function plot_5505_onchange_2651_0() {
#   var curSwitchPos = new Array();
#   curSwitchPos.push($('#switchbd2651_0').val());
#   curSwitchPos.push($('#switchbd2651_1').val());
#   var idToShow = switchmap_plot_5505[ curSwitchPos ];
#   $( '#plot_5505' ).children().hide();
#   $( '#' + idToShow ).show();
# }
#
# function plot_5505_onchange_2651_1() {
#   var curSwitchPos = new Array();
#   curSwitchPos.push($('#switchbd2651_0').val());
#   curSwitchPos.push($('#switchbd2651_1').val());
#   var idToShow = switchmap_plot_5505[ curSwitchPos ];
#   $( '#plot_5505' ).children().hide();
#   $( '#' + idToShow ).show();
# }
#  });</script><div id='plot_5505' style='display: hidden'>
# <div id="44692e53-45b4-4627-b778-9aaefaed6a09" style="height: 787.5px; width: 652.5px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("44692e53-45b4-4627-b778-9aaefaed6a09", [{"hoverinfo": "text", "zmax": 1, "showscale": false, "text": [["L: 1<br>germ: Gx<br>rho_i: {}<br>E_i: GyGyGy<br>2.05801", "L: 1<br>germ: Gx<br>rho_i: Gx<br>E_i: GyGyGy<br>0.855538", "L: 1<br>germ: Gx<br>rho_i: Gy<br>E_i: GyGyGy<br>0.314673", "L: 1<br>germ: Gx<br>rho_i: GxGx<br>E_i: GyGyGy<br>1.91466", "L: 1<br>germ: Gx<br>rho_i: GxGxGx<br>E_i: GyGyGy<br>1.61429", "L: 1<br>germ: Gx<br>rho_i: GyGyGy<br>E_i: GyGyGy<br>0.0397482", "", "L: 2<br>germ: Gx<br>rho_i: {}<br>E_i: GyGyGy<br>0.855538", "L: 2<br>germ: Gx<br>rho_i: Gx<br>E_i: GyGyGy<br>1.91466", "L: 2<br>germ: Gx<br>rho_i: Gy<br>E_i: GyGyGy<br>2.4974", "L: 2<br>germ: Gx<br>rho_i: GxGx<br>E_i: GyGyGy<br>1.61429", "L: 2<br>germ: Gx<br>rho_i: GxGxGx<br>E_i: GyGyGy<br>0.162313", "L: 2<br>germ: Gx<br>rho_i: GyGyGy<br>E_i: GyGyGy<br>1.7465", "", "L: 4<br>germ: Gx<br>rho_i: {}<br>E_i: GyGyGy<br>1.61429", "L: 4<br>germ: Gx<br>rho_i: Gx<br>E_i: GyGyGy<br>0.162313", "L: 4<br>germ: Gx<br>rho_i: Gy<br>E_i: GyGyGy<br>6.19837e-06", "L: 4<br>germ: Gx<br>rho_i: GxGx<br>E_i: GyGyGy<br>0.164699", "L: 4<br>germ: Gx<br>rho_i: GxGxGx<br>E_i: GyGyGy<br>0.00476538", "L: 4<br>germ: Gx<br>rho_i: GyGyGy<br>E_i: GyGyGy<br>0.250319", "", "L: 8<br>germ: Gx<br>rho_i: {}<br>E_i: GyGyGy<br>0.833561", "L: 8<br>germ: Gx<br>rho_i: Gx<br>E_i: GyGyGy<br>0.507753", "L: 8<br>germ: Gx<br>rho_i: Gy<br>E_i: GyGyGy<br>0.0982546", "L: 8<br>germ: Gx<br>rho_i: GxGx<br>E_i: GyGyGy<br>3.46982", "L: 8<br>germ: Gx<br>rho_i: GxGxGx<br>E_i: GyGyGy<br>0.418083", "L: 8<br>germ: Gx<br>rho_i: GyGyGy<br>E_i: GyGyGy<br>0.117333"], ["L: 1<br>germ: Gx<br>rho_i: {}<br>E_i: GxGxGx<br>1.05063", "L: 1<br>germ: Gx<br>rho_i: Gx<br>E_i: GxGxGx<br>0.202052", "L: 1<br>germ: Gx<br>rho_i: Gy<br>E_i: GxGxGx<br>0.427876", "L: 1<br>germ: Gx<br>rho_i: GxGx<br>E_i: GxGxGx<br>4.27431", "L: 1<br>germ: Gx<br>rho_i: GxGxGx<br>E_i: GxGxGx<br>1.7168", "L: 1<br>germ: Gx<br>rho_i: GyGyGy<br>E_i: GxGxGx<br>1.65263", "", "L: 2<br>germ: Gx<br>rho_i: {}<br>E_i: GxGxGx<br>0.202052", "L: 2<br>germ: Gx<br>rho_i: Gx<br>E_i: GxGxGx<br>4.27431", "L: 2<br>germ: Gx<br>rho_i: Gy<br>E_i: GxGxGx<br>0.763066", "L: 2<br>germ: Gx<br>rho_i: GxGx<br>E_i: GxGxGx<br>1.7168", "L: 2<br>germ: Gx<br>rho_i: GxGxGx<br>E_i: GxGxGx<br>2.05489", "L: 2<br>germ: Gx<br>rho_i: GyGyGy<br>E_i: GxGxGx<br>0.0941544", "", "L: 4<br>germ: Gx<br>rho_i: {}<br>E_i: GxGxGx<br>1.7168", "L: 4<br>germ: Gx<br>rho_i: Gx<br>E_i: GxGxGx<br>2.05489", "L: 4<br>germ: Gx<br>rho_i: Gy<br>E_i: GxGxGx<br>2.25118", "L: 4<br>germ: Gx<br>rho_i: GxGx<br>E_i: GxGxGx<br>0.922607", "L: 4<br>germ: Gx<br>rho_i: GxGxGx<br>E_i: GxGxGx<br>2.12", "L: 4<br>germ: Gx<br>rho_i: GyGyGy<br>E_i: GxGxGx<br>1.72058", "", "L: 8<br>germ: Gx<br>rho_i: {}<br>E_i: GxGxGx<br>1.72727", "L: 8<br>germ: Gx<br>rho_i: Gx<br>E_i: GxGxGx<br>0.492523", "L: 8<br>germ: Gx<br>rho_i: Gy<br>E_i: GxGxGx<br>0.156375", "L: 8<br>germ: Gx<br>rho_i: GxGx<br>E_i: GxGxGx<br>0.678415", "L: 8<br>germ: Gx<br>rho_i: GxGxGx<br>E_i: GxGxGx<br>5.57202", "L: 8<br>germ: Gx<br>rho_i: GyGyGy<br>E_i: GxGxGx<br>1.4498"], ["L: 1<br>germ: Gx<br>rho_i: {}<br>E_i: GxGx<br>0.678511", "L: 1<br>germ: Gx<br>rho_i: Gx<br>E_i: GxGx<br>1.05063", "L: 1<br>germ: Gx<br>rho_i: Gy<br>E_i: GxGx<br>0.357643", "L: 1<br>germ: Gx<br>rho_i: GxGx<br>E_i: GxGx<br>0.202052", "L: 1<br>germ: Gx<br>rho_i: GxGxGx<br>E_i: GxGx<br>4.27431", "L: 1<br>germ: Gx<br>rho_i: GyGyGy<br>E_i: GxGx<br>2.22029", "", "L: 2<br>germ: Gx<br>rho_i: {}<br>E_i: GxGx<br>1.05063", "L: 2<br>germ: Gx<br>rho_i: Gx<br>E_i: GxGx<br>0.202052", "L: 2<br>germ: Gx<br>rho_i: Gy<br>E_i: GxGx<br>0.427876", "L: 2<br>germ: Gx<br>rho_i: GxGx<br>E_i: GxGx<br>4.27431", "L: 2<br>germ: Gx<br>rho_i: GxGxGx<br>E_i: GxGx<br>1.7 ...

# %%
#Perform gauge optimizations of gs1 using different spam weights
spamWts = np.linspace(0.0,1.0,20)
gs_gaugeopts = [ pygsti.gaugeopt_to_target(gs1, tgt,{'gates': 1, 'spam': x}) for x in spamWts]

# %%
# Create a switchboard with a slider that controls the spam-weight used in gauge optimization
switchbd3 = w.Switchboard(["spam-weight"], [["%.2f" % x for x in spamWts]], ["slider"])
switchbd3.add("gsGO",(0,))
switchbd3.gsGO[:] = gs_gaugeopts

#Then create a comparison vs. target tables
tbl3 = w.GatesVsTargetTable(switchbd3.gsGO, tgt)
tbl4 = w.SpamVsTargetTable(switchbd3.gsGO, tgt)

switchbd3.display()
tbl3.display()
tbl4.display()
# Out:
# <script>
# require(['jquery','jquery-UI'],function($,ui) {$(document).ready(function() {
# var switchbd7486_0_float_values = [0.0,0.05,0.11,0.16,0.21,0.26,0.32,0.37,0.42,0.47,0.53,0.58,0.63,0.68,0.74,0.79,0.84,0.89,0.95,1.0];
# var switchbd7486_0_str_values = ['0.00','0.05','0.11','0.16','0.21','0.26','0.32','0.37','0.42','0.47','0.53','0.58','0.63','0.68','0.74','0.79','0.84','0.89','0.95','1.00'];
# window.switchbd7486_0_float_values = switchbd7486_0_float_values;
#   $('#switchbd7486_0').slider({
#      orientation: 'horizontal', range: false,
#      min: 0.000000, max: 1.000000, step: 0.010000,
#      create: function() {
#        $('#switchbd7486_0-handle').text('0.00');
#        $('#switchbd7486_0-handle').css({'width':'3.000000em','height':'1.700000em'});
#        $('#switchbd7486_0-handle').css({'margin-left':'-1.500000em','top':'-0.450000em'});
#        $('#switchbd7486_0-handle').css({'text-align':'center','line-height':'1.5em'});
#        $('#switchbd7486_0').css({'margin-left':'1.500000em', 'margin-top':'0.4em'});
#      },
#      slide: function(event, ui) {
#         var includeLeft = event.keyCode != $.ui.keyCode.RIGHT;
#         var includeRight = event.keyCode != $.ui.keyCode.LEFT;
#         var iValue = findNearest(includeLeft, includeRight, ui.value);
#         $('#switchbd7486_0').slider('value', switchbd7486_0_float_values[iValue]);
#         $('#switchbd7486_0-handle').text(switchbd7486_0_str_values[iValue]);
#         return false;    },
#   });function findNearest(includeLeft, includeRight, value) {
#   var nearest = null;
#   var diff = null;
#   for (var i = 0; i < switchbd7486_0_float_values.length; i++) {
#     if ((includeLeft && switchbd7486_0_float_values[i] <= value) ||
#         (includeRight && switchbd7486_0_float_values[i] >= value)) {
#       var newDiff = Math.abs(value - switchbd7486_0_float_values[i]);
#       if (diff == null || newDiff < diff) {
#         nearest = i;
#         diff = newDiff;
#       }
#     }
#   }
#   return nearest;
# }
# window.findNearest_switchbd7486_0 = findNearest;
#
# }); });</script><div id='switchbd7486_0-container' style='margin:2px'><fieldset>
# <label for='switchbd7486_0' style='float:left'>spam-weight</label>
# <div name='switchbd7486_0' id='switchbd7486_0' style='width:80%;float:left'>
# <div id='switchbd7486_0-handle' class='ui-slider-handle'></div></div>
# </fieldset></div>
# <script>
# require(['jquery','jquery-UI'],function($,ui) {$( function() {
#   var switchmap_table_9478 = new Array();
#   switchmap_table_9478[ [4] ] = 'table_9478_4';
#   switchmap_table_9478[ [13] ] = 'table_9478_13';
#   switchmap_table_9478[ [6] ] = 'table_9478_6';
#   switchmap_table_9478[ [15] ] = 'table_9478_15';
#   switchmap_table_9478[ [17] ] = 'table_9478_17';
#   switchmap_table_9478[ [19] ] = 'table_9478_19';
#   switchmap_table_9478[ [12] ] = 'table_9478_12';
#   switchmap_table_9478[ [14] ] = 'table_9478_14';
#   switchmap_table_9478[ [0] ] = 'table_9478_0';
#   switchmap_table_9478[ [2] ] = 'table_9478_2';
#   switchmap_table_9478[ [8] ] = 'table_9478_8';
#   switchmap_table_9478[ [1] ] = 'table_9478_1';
#   switchmap_table_9478[ [10] ] = 'table_9478_10';
#   switchmap_table_9478[ [3] ] = 'table_9478_3';
#   switchmap_table_9478[ [5] ] = 'table_9478_5';
#   switchmap_table_9478[ [7] ] = 'table_9478_7';
#   switchmap_table_9478[ [16] ] = 'table_9478_16';
#   switchmap_table_9478[ [9] ] = 'table_9478_9';
#   switchmap_table_9478[ [18] ] = 'table_9478_18';
#   switchmap_table_9478[ [11] ] = 'table_9478_11';
#   window.switchmap_table_9478 = switchmap_table_9478;
#
#   $('#switchbd7486_0').on('slide', function() {table_9478_onchange_7486_0(); });
#   table_9478_onchange_7486_0();
# $( '#table_9478' ).show()
# });
#
# function table_9478_onchange_7486_0() {
#   var curSwitchPos = new Array();
#   curSwitchPos.push(findNearest_switchbd7486_0(true,true,$('#switchbd7486_0').slider('option', 'value')));
#   var idToShow = switchmap_table_9478[ curSwitchPos ];
#   $( '#table_9478' ).children().hide();
#   $( '#' + idToShow ).show();
# }
#  });</script><div id='table_9478' style='display: hidden'>
# <div id='table_9478_0'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074856</td></tr><tr><td>Gx</td><td>0.07094</td><td>0.070941</td><td>0.070941</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076933</td></tr></tbody></table>
# </div>
#
# <div id='table_9478_1'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074856</td></tr><tr><td>Gx</td><td>0.070939</td><td>0.070941</td><td>0.070941</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076933</td></tr></tbody></table>
# </div>
#
# <div id='table_9478_2'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074856</td></tr><tr><td>Gx</td><td>0.070939</td><td>0.070941</td><td>0.070941</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076933</td></tr></tbody></table>
# </div>
#
# <div id='table_9478_3'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074856</td></tr><tr><td>Gx</td><td>0.070939</td><td>0.070941</td><td>0.070941</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076933</td></tr></tbody></table>
# </div>
#
# <div id='table_9478_4'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074856</td></tr><tr><td>Gx</td><td>0.070939</td><td>0.070941</td><td>0.070942</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076933</td></tr></tbody></table>
# </div>
#
# <div id='table_9478_5'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074856</td></tr><tr><td>Gx</td><td>0.070939</td><td>0.070942</td><td>0.070942</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076933</td></tr></tbody></table>
# </div>
#
# <div id='table_9478_6'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074857</td></tr><tr><td>Gx</td><td>0.070939</td><td>0.070942</td><td>0.070942</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076933</td></tr></tbody></table>
# </div>
#
# <div id='table_9478_7'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074857</td></tr><tr><td>Gx</td><td>0.070939</td><td>0.070942</td><td>0.070942</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076933</td></tr></tbody></table>
# </div>
#
# <div id='table_9478_8'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074857</td></tr><tr><td>Gx</td><td>0.070939</td><td>0.070942</td><td>0.070942</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076933</td></tr></tbody></table>
# </div>
#
# <div id='table_9478_9'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074857</td></tr><tr><td>Gx</td><td>0.070939</td><td>0.070942</td><td>0.070943</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076933</td></tr></tbody></table>
# </div>
#
# <div id='table_9478_10'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074857</td></tr><tr><td>Gx</td><td>0.070939</td><td>0.070943</td><td>0.070943</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076933</td></tr></tbody></table>
# </div>
#
# <div id='table_9478_11'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074857</td></tr><tr><td>Gx</td><td>0.070939</td><td>0.070943</td><td>0.070943</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076934</td></tr></tbody></table>
# </div>
#
# <div id='table_9478_12'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074857</td></tr><tr><td>Gx</td><td>0.070939</td><td>0.070943</td><td>0.070944</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076934</td></tr></tbody></table>
# </div>
#
# <div id='table_9478_13'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074857</td></tr><tr><td>Gx</td><td>0.070939</td><td>0.070943</td><td>0.070944</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076934</td></tr></tbody></table>
# </div>
#
# <div id='table_9478_14'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelity </th><th> 1/2 Trace Distance </th><th> 1/2 Diamond-Norm </th></tr></thead><tbody><tr><td>Gi</td><td>0.074758</td><td>0.074836</td><td>0.074857</td></tr><tr><td>Gx</td><td>0.070939</td><td>0.070944</td><td>0.070945</td></tr><tr><td>Gy</td><td>0.076925</td><td>0.076929</td><td>0.076934</td></tr></tbody></table>
# </div>
#
# <div id='table_9478_15'>
# <table class=dataTable><thead><tr><th> Gate </th><th> Process Infidelit
# <script>
# require(['jquery','jquery-UI'],function($,ui) {$( function() {
#   var switchmap_table_708 = new Array();
#   switchmap_table_708[ [4] ] = 'table_708_4';
#   switchmap_table_708[ [13] ] = 'table_708_13';
#   switchmap_table_708[ [6] ] = 'table_708_6';
#   switchmap_table_708[ [15] ] = 'table_708_15';
#   switchmap_table_708[ [17] ] = 'table_708_17';
#   switchmap_table_708[ [19] ] = 'table_708_19';
#   switchmap_table_708[ [12] ] = 'table_708_12';
#   switchmap_table_708[ [14] ] = 'table_708_14';
#   switchmap_table_708[ [0] ] = 'table_708_0';
#   switchmap_table_708[ [2] ] = 'table_708_2';
#   switchmap_table_708[ [8] ] = 'table_708_8';
#   switchmap_table_708[ [1] ] = 'table_708_1';
#   switchmap_table_708[ [10] ] = 'table_708_10';
#   switchmap_table_708[ [3] ] = 'table_708_3';
#   switchmap_table_708[ [5] ] = 'table_708_5';
#   switchmap_table_708[ [7] ] = 'table_708_7';
#   switchmap_table_708[ [16] ] = 'table_708_16';
#   switchmap_table_708[ [9] ] = 'table_708_9';
#   switchmap_table_708[ [18] ] = 'table_708_18';
#   switchmap_table_708[ [11] ] = 'table_708_11';
#   window.switchmap_table_708 = switchmap_table_708;
#
#   $('#switchbd7486_0').on('slide', function() {table_708_onchange_7486_0(); });
#   table_708_onchange_7486_0();
# $( '#table_708' ).show()
# });
#
# function table_708_onchange_7486_0() {
#   var curSwitchPos = new Array();
#   curSwitchPos.push(findNearest_switchbd7486_0(true,true,$('#switchbd7486_0').slider('option', 'value')));
#   var idToShow = switchmap_table_708[ curSwitchPos ];
#   $( '#table_708' ).children().hide();
#   $( '#' + idToShow ).show();
# }
#  });</script><div id='table_708' style='display: hidden'>
# <div id='table_708_0'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.000329</td><td>0.001948</td></tr><tr><td>E<sub>0</sub></td><td>0.000863</td><td>0.004191</td></tr><tr><td>E<sub>C</sub></td><td>-0.000335</td><td>0.004191</td></tr></tbody></table>
# </div>
#
# <div id='table_708_1'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.000306</td><td>0.001873</td></tr><tr><td>E<sub>0</sub></td><td>0.000845</td><td>0.004114</td></tr><tr><td>E<sub>C</sub></td><td>-0.000312</td><td>0.004114</td></tr></tbody></table>
# </div>
#
# <div id='table_708_2'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.000289</td><td>0.001805</td></tr><tr><td>E<sub>0</sub></td><td>0.00083</td><td>0.004043</td></tr><tr><td>E<sub>C</sub></td><td>-0.000296</td><td>0.004043</td></tr></tbody></table>
# </div>
#
# <div id='table_708_3'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.000309</td><td>0.0018</td></tr><tr><td>E<sub>0</sub></td><td>0.000844</td><td>0.00406</td></tr><tr><td>E<sub>C</sub></td><td>-0.000315</td><td>0.00406</td></tr></tbody></table>
# </div>
#
# <div id='table_708_4'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.000302</td><td>0.001756</td></tr><tr><td>E<sub>0</sub></td><td>0.000838</td><td>0.004019</td></tr><tr><td>E<sub>C</sub></td><td>-0.000309</td><td>0.004019</td></tr></tbody></table>
# </div>
#
# <div id='table_708_5'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.000296</td><td>0.001714</td></tr><tr><td>E<sub>0</sub></td><td>0.000832</td><td>0.003979</td></tr><tr><td>E<sub>C</sub></td><td>-0.000303</td><td>0.003979</td></tr></tbody></table>
# </div>
#
# <div id='table_708_6'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.00029</td><td>0.001674</td></tr><tr><td>E<sub>0</sub></td><td>0.000827</td><td>0.00394</td></tr><tr><td>E<sub>C</sub></td><td>-0.000297</td><td>0.00394</td></tr></tbody></table>
# </div>
#
# <div id='table_708_7'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.000284</td><td>0.001635</td></tr><tr><td>E<sub>0</sub></td><td>0.000821</td><td>0.003902</td></tr><tr><td>E<sub>C</sub></td><td>-0.000292</td><td>0.003902</td></tr></tbody></table>
# </div>
#
# <div id='table_708_8'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.000278</td><td>0.001599</td></tr><tr><td>E<sub>0</sub></td><td>0.000816</td><td>0.003865</td></tr><tr><td>E<sub>C</sub></td><td>-0.000286</td><td>0.003865</td></tr></tbody></table>
# </div>
#
# <div id='table_708_9'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.000273</td><td>0.001564</td></tr><tr><td>E<sub>0</sub></td><td>0.00081</td><td>0.003828</td></tr><tr><td>E<sub>C</sub></td><td>-0.000281</td><td>0.003828</td></tr></tbody></table>
# </div>
#
# <div id='table_708_10'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.000268</td><td>0.00153</td></tr><tr><td>E<sub>0</sub></td><td>0.000805</td><td>0.003793</td></tr><tr><td>E<sub>C</sub></td><td>-0.000276</td><td>0.003793</td></tr></tbody></table>
# </div>
#
# <div id='table_708_11'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.000263</td><td>0.001498</td></tr><tr><td>E<sub>0</sub></td><td>0.000799</td><td>0.003758</td></tr><tr><td>E<sub>C</sub></td><td>-0.000272</td><td>0.003758</td></tr></tbody></table>
# </div>
#
# <div id='table_708_12'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.000258</td><td>0.001468</td></tr><tr><td>E<sub>0</sub></td><td>0.000794</td><td>0.003724</td></tr><tr><td>E<sub>C</sub></td><td>-0.000267</td><td>0.003724</td></tr></tbody></table>
# </div>
#
# <div id='table_708_13'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.000254</td><td>0.001438</td></tr><tr><td>E<sub>0</sub></td><td>0.000789</td><td>0.003691</td></tr><tr><td>E<sub>C</sub></td><td>-0.000263</td><td>0.003691</td></tr></tbody></table>
# </div>
#
# <div id='table_708_14'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.000249</td><td>0.00141</td></tr><tr><td>E<sub>0</sub></td><td>0.000784</td><td>0.003659</td></tr><tr><td>E<sub>C</sub></td><td>-0.000258</td><td>0.003659</td></tr></tbody></table>
# </div>
#
# <div id='table_708_15'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.000245</td><td>0.001382</td></tr><tr><td>E<sub>0</sub></td><td>0.000781</td><td>0.003624</td></tr><tr><td>E<sub>C</sub></td><td>-0.000255</td><td>0.003624</td></tr></tbody></table>
# </div>
#
# <div id='table_708_16'>
# <table class=dataTable><thead><tr><th> Prep/POVM </th><th> State Infidelity </th><th> 1/2 Trace Distance </th></tr></thead><tbody><tr><td>&rho;<sub>0</sub></td><td>0.000241</td><td>0.001356</td></tr><tr><td>E<sub>0</sub></td><td>0.000776</td><td>0.003592</td></tr><tr><td>E<sub>C</sub></td><td>-0.00025</td><td>0.003592</td

# %%
# Create a slider showing the color box plot at different GST iterations
switchbd4 = w.Switchboard(["max(L)"], [list(map(str,gss.Ls))], ["slider"])
switchbd4.add("gs",(0,))
switchbd4.add("gss",(0,))
switchbd4.gs[:] = results1.gatesets['iteration estimates']
switchbd4.gss[:] = results1.gatestring_structs['iteration']
            
#Then create a logl plot that can show the goodness-of-fit at different iterations
logLProgress = w.ColorBoxPlot(("logl",), switchbd4.gss, ds1, switchbd4.gs, scale=0.75)

switchbd4.display()
logLProgress.display()
# Out:
# <script>
# require(['jquery','jquery-UI'],function($,ui) {$(document).ready(function() {
# var switchbd7659_0_float_values = [1.0,2.0,4.0,8.0];
# var switchbd7659_0_str_values = ['1','2','4','8'];
# window.switchbd7659_0_float_values = switchbd7659_0_float_values;
#   $('#switchbd7659_0').slider({
#      orientation: 'horizontal', range: false,
#      min: 1.000000, max: 8.000000, step: 0.070000,
#      create: function() {
#        $('#switchbd7659_0-handle').text('1');
#        $('#switchbd7659_0-handle').css({'width':'3.000000em','height':'1.700000em'});
#        $('#switchbd7659_0-handle').css({'margin-left':'-1.500000em','top':'-0.450000em'});
#        $('#switchbd7659_0-handle').css({'text-align':'center','line-height':'1.5em'});
#        $('#switchbd7659_0').css({'margin-left':'1.500000em', 'margin-top':'0.4em'});
#      },
#      slide: function(event, ui) {
#         var includeLeft = event.keyCode != $.ui.keyCode.RIGHT;
#         var includeRight = event.keyCode != $.ui.keyCode.LEFT;
#         var iValue = findNearest(includeLeft, includeRight, ui.value);
#         $('#switchbd7659_0').slider('value', switchbd7659_0_float_values[iValue]);
#         $('#switchbd7659_0-handle').text(switchbd7659_0_str_values[iValue]);
#         return false;    },
#   });function findNearest(includeLeft, includeRight, value) {
#   var nearest = null;
#   var diff = null;
#   for (var i = 0; i < switchbd7659_0_float_values.length; i++) {
#     if ((includeLeft && switchbd7659_0_float_values[i] <= value) ||
#         (includeRight && switchbd7659_0_float_values[i] >= value)) {
#       var newDiff = Math.abs(value - switchbd7659_0_float_values[i]);
#       if (diff == null || newDiff < diff) {
#         nearest = i;
#         diff = newDiff;
#       }
#     }
#   }
#   return nearest;
# }
# window.findNearest_switchbd7659_0 = findNearest;
#
# }); });</script><div id='switchbd7659_0-container' style='margin:2px'><fieldset>
# <label for='switchbd7659_0' style='float:left'>max(L)</label>
# <div name='switchbd7659_0' id='switchbd7659_0' style='width:80%;float:left'>
# <div id='switchbd7659_0-handle' class='ui-slider-handle'></div></div>
# </fieldset></div>
# <script>
# require(['jquery','jquery-UI'],function($,ui) {$( function() {
#   var switchmap_plot_2693 = new Array();
#   switchmap_plot_2693[ [0] ] = 'f64e5e4d-5a4a-4c7b-a614-42c2f667535f';
#   switchmap_plot_2693[ [1] ] = 'b632ccfe-da7c-40fa-9ae6-4bde8a5953c7';
#   switchmap_plot_2693[ [2] ] = '950e309e-2352-4290-a0d3-d59da389acb3';
#   switchmap_plot_2693[ [3] ] = '4bbaa3ef-0079-4c6b-8865-b3358e618a79';
#   window.switchmap_plot_2693 = switchmap_plot_2693;
#
#   $('#switchbd7659_0').on('slide', function() {plot_2693_onchange_7659_0(); });
#   plot_2693_onchange_7659_0();
# $( '#plot_2693' ).show()
# });
#
# function plot_2693_onchange_7659_0() {
#   var curSwitchPos = new Array();
#   curSwitchPos.push(findNearest_switchbd7659_0(true,true,$('#switchbd7659_0').slider('option', 'value')));
#   var idToShow = switchmap_plot_2693[ curSwitchPos ];
#   $( '#plot_2693' ).children().hide();
#   $( '#' + idToShow ).show();
# }
#  });</script><div id='plot_2693' style='display: hidden'>
# <div id="f64e5e4d-5a4a-4c7b-a614-42c2f667535f" style="height: 652.5px; width: 247.5px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f64e5e4d-5a4a-4c7b-a614-42c2f667535f", [{"hoverinfo": "text", "zmax": 1, "showscale": false, "text": [["L: 1<br>germ: Gx<br>rho_i: {}<br>E_i: GyGyGy<br>1.10616", "L: 1<br>germ: Gx<br>rho_i: Gx<br>E_i: GyGyGy<br>0.874655", "L: 1<br>germ: Gx<br>rho_i: Gy<br>E_i: GyGyGy<br>1.63729", "L: 1<br>germ: Gx<br>rho_i: GxGx<br>E_i: GyGyGy<br>0.30457", "L: 1<br>germ: Gx<br>rho_i: GxGxGx<br>E_i: GyGyGy<br>4.38534", "L: 1<br>germ: Gx<br>rho_i: GyGyGy<br>E_i: GyGyGy<br>0.32253"], ["L: 1<br>germ: Gx<br>rho_i: {}<br>E_i: GxGxGx<br>0.736796", "L: 1<br>germ: Gx<br>rho_i: Gx<br>E_i: GxGxGx<br>1.2097", "L: 1<br>germ: Gx<br>rho_i: Gy<br>E_i: GxGxGx<br>0.722794", "L: 1<br>germ: Gx<br>rho_i: GxGx<br>E_i: GxGxGx<br>3.91642", "L: 1<br>germ: Gx<br>rho_i: GxGxGx<br>E_i: GxGxGx<br>1.23536", "L: 1<br>germ: Gx<br>rho_i: GyGyGy<br>E_i: GxGxGx<br>1.26753"], ["L: 1<br>germ: Gx<br>rho_i: {}<br>E_i: GxGx<br>0.0245191", "L: 1<br>germ: Gx<br>rho_i: Gx<br>E_i: GxGx<br>0.736796", "L: 1<br>germ: Gx<br>rho_i: Gy<br>E_i: GxGx<br>0.797562", "L: 1<br>germ: Gx<br>rho_i: GxGx<br>E_i: GxGx<br>1.2097", "L: 1<br>germ: Gx<br>rho_i: GxGxGx<br>E_i: GxGx<br>3.91642", "L: 1<br>germ: Gx<br>rho_i: GyGyGy<br>E_i: GxGx<br>1.93846"], ["L: 1<br>germ: Gx<br>rho_i: {}<br>E_i: Gy<br>3.1911", "L: 1<br>germ: Gx<br>rho_i: Gx<br>E_i: Gy<br>0.473692", "L: 1<br>germ: Gx<br>rho_i: Gy<br>E_i: Gy<br>0.484406", "L: 1<br>germ: Gx<br>rho_i: GxGx<br>E_i: Gy<br>1.56597", "L: 1<br>germ: Gx<br>rho_i: GxGxGx<br>E_i: Gy<br>0.553162", "L: 1<br>germ: Gx<br>rho_i: GyGyGy<br>E_i: Gy<br>0.287292"], ["L: 1<br>germ: Gx<br>rho_i: {}<br>E_i: Gx<br>0.748585", "L: 1<br>germ: Gx<br>rho_i: Gx<br>E_i: Gx<br>0.0245191", "L: 1<br>germ: Gx<br>rho_i: Gy<br>E_i: Gx<br>0.484731", "L: 1<br>germ: Gx<br>rho_i: GxGx<br>E_i: Gx<br>0.736796", "L: 1<br>germ: Gx<br>rho_i: GxGxGx<br>E_i: Gx<br>1.2097", "L: 1<br>germ: Gx<br>rho_i: GyGyGy<br>E_i: Gx<br>0.00155958"], ["L: 1<br>germ: Gx<br>rho_i: {}<br>E_i: {}<br>0.155345", "L: 1<br>germ: Gx<br>rho_i: Gx<br>E_i: {}<br>0.748585", "L: 1<br>germ: Gx<br>rho_i: Gy<br>E_i: {}<br>0.863758", "L: 1<br>germ: Gx<br>rho_i: GxGx<br>E_i: {}<br>0.0245191", "L: 1<br>germ: Gx<br>rho_i: GxGxGx<br>E_i: {}<br>0.736796", "L: 1<br>germ: Gx<br>rho_i: GyGyGy<br>E_i: {}<br>1.49438"], ["", "", "", "", "", ""], ["L: 1<br>germ: Gy<br>rho_i: {}<br>E_i: GyGyGy<br>0.103276", "L: 1<br>germ: Gy<br>rho_i: Gx<br>E_i: GyGyGy<br>1.37008", "L: 1<br>germ: Gy<br>rho_i: Gy<br>E_i: GyGyGy<br>1.15712", "L: 1<br>germ: Gy<br>rho_i: GxGx<br>E_i: GyGyGy<br>3.03458", "L: 1<br>germ: Gy<br>rho_i: GxGxGx<br>E_i: GyGyGy<br>2.2466", "L: 1<br>germ: Gy<br>rho_i: GyGyGy<br>E_i: GyGyGy<br>2.0755"], ["L: 1<br>germ: Gy<br>rho_i: {}<br>E_i: GxGxGx<br>0.797562", "L: 1<br>germ: Gy<br>rho_i: Gx<br>E_i: GxGxGx<br>0.861827", "L: 1<br>germ: Gy<br>rho_i: Gy<br>E_i: GxGxGx<br>0.154309", "L: 1<br>germ: Gy<br>rho_i: GxGx<br>E_i: GxGxGx<br>0.297655", "L: 1<br>germ: Gy<br>rho_i: GxGxGx<br>E_i: GxGxGx<br>2.19023", "L: 1<br>germ: Gy<br>rho_i: GyGyGy<br>E_i: GxGxGx<br>0.69423"], ["L: 1<br>germ: Gy<br>rho_i: {}<br>E_i: GxGx<br>0.484731", "L: 1<br>germ: Gy<br>rho_i: Gx<br>E_i: GxGx<br>0.490602", "L: 1<br>germ: Gy<br>rho_i: Gy<br>E_i: GxGx<br>0.690547", "L: 1<br>germ: Gy<br>rho_i: GxGx<br>E_i: GxGx<br>0.0226564", "L: 1<br>germ: Gy<br>rho_i: GxGxGx<br>E_i: GxGx<br>0.0465669", "L: 1<br>germ: Gy<br>rho_i: GyGyGy<br>E_i: GxGx<br>0.248769"], ["L: 1<br>germ: Gy<br>rho_i: {}<br>E_i: Gy<br>1.06872", "L: 1<br>germ: Gy<br>rho_i: Gx<br>E_i: Gy<br>3.26287", "L: 1<br>germ: Gy<br>rho_i: Gy<br>E_i: Gy<br>0.0185078", "L: 1<br>germ: Gy<br>rho_i: GxGx<br>E_i: Gy<br>0.00235841", "L: 1<br>germ: Gy<br>rho_i: GxGxGx<br>E_i: Gy<br>3.88058", "L: 1<br>germ: Gy<br>rho_i: GyGyGy<br>E_i: Gy<br>1.15712"], ["L: 1 ...
