# %% [markdown]
# # Getting started with pyGSTi and Gate Set Tomography

# %% [markdown]
# The `pygsti` package provides multiple levels of abstraction over the core Gate Set Tomography (GST) algorithms.  This initial tutorial will show you how to run Gate Set Tomography on some simulated (generated) data, hopefully giving you an overall sense of what it takes (and how easy it is!) to run GST.  Subsequent tutorials will delve into the details of `pygsti` objects and algorithms, and how to use them in detail.
#
# To run GST, we need three inputs:
# 1. a "**target gate set**" which describes the desired, or ideal, operations we want our experimental hardware to perform.  In the example below, we use one of pyGSTi's "standard" gate sets - the on acting on a single qubit with the following operations:
#     - three gates: the identity, and $\pi/2$ rotations around the $x$- and $y$-axes.
#     - a single state preparation in the $|0\rangle$ state.
#     - a 2-outcome measurement with the label "0" associated with measuring $|0\rangle$ and "1" with measuring $|1\rangle$.
#
# 2. a list of GST sequences corresponding to the target gate set; essentially a list of what experiments (= gate sequences) we need to run.  Using a standard gate set makes things especially straightforward here, since the building blocks, called *germ* and *fiducial* sequences needed to make good GST sequences have already been computed.
#
# 3. data, in the form of experimental outcome counts, for each of the required sequences.  In this example we'll generate "fake" or "simulated" data from a depolarized version of our ideal gate set.

# %%
#Make print statements compatible with Python 2 and 3
from __future__ import print_function

#Import the pygsti module (always do this) and the standard XYI gate set
import pygsti
from pygsti.construction import std1Q_XYI

# 1) get the target GateSet
gs_target = std1Q_XYI.gs_target

# 2) get the building blocks needed to specify which gate sequences are needed
prep_fiducials, meas_fiducials = std1Q_XYI.prepStrs, std1Q_XYI.effectStrs
germs = std1Q_XYI.germs
maxLengths = [1,2,4,8,16,32] # roughly gives the length of the sequences used by GST

# 3) generate "fake" data from a depolarized version of gs_target
gs_datagen = gs_target.depolarize(gate_noise=0.1, spam_noise=0.001)
listOfExperiments = pygsti.construction.make_lsgst_experiment_list(
    gs_target, prep_fiducials, meas_fiducials, germs, maxLengths)
ds = pygsti.construction.generate_fake_data(gs_datagen, listOfExperiments, nSamples=1000,
                                            sampleError="binomial", seed=1234)

#Note: from listOfExperiments we can also create an empty dataset file
# which has columns of zeros where actual data should go. 
pygsti.io.write_empty_dataset("tutorial_files/GettingStartedDataTemplate.txt", listOfExperiments,
                              "## Columns = 1 count, count total")
# After replacing the zeros with actual data, the data set can be 
# loaded back into pyGSTi using the line below and used in the rest
# of this tutorial. 
#ds = pygsti.io.load_dataset("tutorial_files/GettingStartedDataTemplate.txt")

# %% [markdown]
# Now that we have all of the inputs, we can run GST in a standard way using the `do_stdpractice_gst` high-level driver function.  This returns a `pygsti.report.Results` object, from which we can generate a report giving us a summary of the analysis.

# %%
#Run GST and create a report
results = pygsti.do_stdpractice_gst(ds, gs_target, prep_fiducials, meas_fiducials, 
                                    germs, maxLengths, verbosity=4)
pygsti.report.create_standard_report(results, filename="tutorial_files/gettingStartedReport",
                                    title="Tutorial0 Example Report", verbosity=2)
# Out:
# -- Std Practice:  Iter 1 of 3  (TP) --:
#   --- Gate Sequence Creation ---
#      1702 sequences created
#      Dataset has 1702 entries: 1702 utilized, 0 requested sequences were missing
#   --- LGST ---
#     Singular values of I_tilde (truncating to first 4 of 6) =
#     4.244260747379201
#     1.1584455050153553
#     0.9653318308376435
#     0.9299255834269221
#     0.04811754926043677
#     0.03165892099831828
#
#     Singular values of target I_tilde (truncating to first 4 of 6) =
#     4.242640687119285
#     1.4142135623730954
#     1.4142135623730947
#     1.4142135623730945
#     3.1723744950054595e-16
#     1.0852733691121267e-16
#
#       Resulting gate set:
#
#       rho0 = TPParameterizedSPAMVec with dimension 4
#        0.71-0.01   0 0.75
#
#
#       Mdefault = TPPOVM with effect vectors:
#       0: FullyParameterizedSPAMVec with dimension 4
#        0.73   0 0.02 0.64
#
#       1: ComplementSPAMVec with dimension 4
#        0.68   0-0.02-0.64
#
#
#
#       Gi =
#       TPParameterizedGate with shape (4, 4)
#        1.00   0   0   0
#        0.02 0.88-0.05-0.02
#          0 0.02 0.89   0
#          0-0.02-0.03 0.92
#
#
#       Gx =
#       TPParameterizedGate with shape (4, 4)
#        1.00   0   0   0
#       -0.01 0.87-0.02   0
#       -0.01   0   0-1.00
#       -0.06-0.01 0.82   0
#
#
#       Gy =
#       TPParameterizedGate with shape (4, 4)
#        1.00   0   0   0
#          0-0.03   0 1.03
#          0-0.02 0.90 0.02
#       -0.06-0.83-0.02   0
#
#
#
#
#   --- Iterative MLGST: Iter 1 of 6  92 gate strings ---:
#     --- Minimum Chi^2 GST ---
#       Created evaluation tree with 1 subtrees.  Will divide 1 procs into 1 (subtree-processing)
#        groups of ~1 procs each, to distribute over 43 params (taken as 1 param groups of ~43 params).
#       --- Outer Iter 0: norm_f = 205.561, mu=0, |J|=1061.08
#       --- Outer Iter 1: norm_f = 91.1988, mu=83.4491, |J|=1005.72
#       --- Outer Iter 2: norm_f = 90.3053, mu=27.8164, |J|=1001.71
#       --- Outer Iter 3: norm_f = 90.3013, mu=9.27213, |J|=1001.68
#       Least squares message = Both actual and predicted relative reductions in the sum of squares are at most 1e-06
#     Sum of Chi^2 = 90.3013 (91 data params - 31 model params = expected mean of 60; p-value = 0.00692057)
#     Completed in 0.1s
#     2*Delta(log(L)) = 90.6748
#     Iteration 1 took 0.1s
#
#   --- Iterative MLGST: Iter 2 of 6  168 gate strings ---:
#     --- Minimum Chi^2 GST ---
#       Created evaluation tree with 1 subtrees.  Will divide 1 procs into 1 (subtree-processing)
#        groups of ~1 procs each, to distribute over 43 params (taken as 1 param groups of ~43 params).
#       --- Outer Iter 0: norm_f = 234.777, mu=0, |J|=1372.1
#       --- Outer Iter 1: norm_f = 169.529, mu=137.083, |J|=1384.65
#       --- Outer Iter 2: norm_f = 169.257, mu=45.6944, |J|=1384.37
#       --- Outer Iter 3: norm_f = 169.256, mu=15.2315, |J|=1384.39
#       Least squares message = Both actual and predicted relative reductions in the sum of squares are at most 1e-06
#     Sum of Chi^2 = 169.256 (167 data params - 31 model params = expected mean of 136; p-value = 0.0279499)
#     Completed in 0.1s
#     2*Delta(log(L)) = 169.699
#     Iteration 2 took 0.1s
#
#   --- Iterative MLGST: Iter 3 of 6  450 gate strings ---:
#     --- Minimum Chi^2 GST ---
#       Created evaluation tree with 1 subtrees.  Will divide 1 procs into 1 (subtree-processing)
#        groups of ~1 procs each, to distribute over 43 params (taken as 1 param groups of ~43 params).
#       --- Outer Iter 0: norm_f = 598.664, mu=0, |J|=2277.49
#       --- Outer Iter 1: norm_f = 484.231, mu=345.426, |J|=2292.84
#       --- Outer Iter 2: norm_f = 483.947, mu=115.142, |J|=2292.55
#       Least squares message = Both actual and predicted relative reductions in the sum of squares are at most 1e-06
#     Sum of Chi^2 = 483.947 (449 data params - 31 model params = expected mean of 418; p-value = 0.0141314)
#     Completed in 0.2s
#     2*Delta(log(L)) = 484.712
#     Iteration 3 took 0.2s
#
#   --- Iterative MLGST: Iter 4 of 6  862 gate strings ---:
#     --- Minimum Chi^2 GST ---
#       Created evaluation tree with 1 subtrees.  Will divide 1 procs into 1 (subtree-processing)
#        groups of ~1 procs each, to distribute over 43 params (taken as 1 param groups of ~43 params).
#       --- Outer Iter 0: norm_f = 920.75, mu=0, |J|=3279.82
#       --- Outer Iter 1: norm_f = 894.084, mu=634.502, |J|=3295.35
#       --- Outer Iter 2: norm_f = 894.017, mu=211.501, |J|=3296.11
#       Least squares message = Both actual and predicted relative reductions in the sum of squares are at most 1e-06
#     Sum of Chi^2 = 894.017 (861 data params - 31 model params = expected mean of 830; p-value = 0.0607105)
#     Completed in 0.4s
#     2*Delta(log(L)) = 894.869
#     Iteration 4 took 0.4s
#
#   --- Iterative MLGST: Iter 5 of 6  1282 gate strings ---:
#     --- Minimum Chi^2 GST ---
#       Created evaluation tree with 1 subtrees.  Will divide 1 procs into 1 (subtree-processing)
#        groups of ~1 procs each, to distribute over 43 params (taken as 1 param groups of ~43 params).
#       --- Outer Iter 0: norm_f = 1361.03, mu=0, |J|=4255.48
#       --- Outer Iter 1: norm_f = 1345.13, mu=916.832, |J|=4255.34
#       --- Outer Iter 2: norm_f = 1345.11, mu=305.611, |J|=4255.47
#       Least squares message = Both actual and predicted relative reductions in the sum of squares are at most 1e-06
#     Sum of Chi^2 = 1345.11 (1281 data params - 31 model params = expected mean of 1250; p-value = 0.0307923)
#     Completed in 0.6s
#     2*Delta(log(L)) = 1346.07
#     Iteration 5 took 0.6s
#
#   --- Iterative MLGST: Iter 6 of 6  1702 gate strings ---:
#     --- Minimum Chi^2 GST ---
#       Created evaluation tree with 1 subtrees.  Will divide 1 procs into 1 (subtree-processing)
#        groups of ~1 procs each, to distribute over 43 params (taken as 1 param groups of ~43 params).
#       --- Outer Iter 0: norm_f = 1789.67, mu=0, |J|=5159.79
#       --- Outer Iter 1: norm_f = 1784.51, mu=1196.77, |J|=5155.46
#       --- Outer Iter 2: norm_f = 1784.51, mu=398.923, |J|=5155.82
#       Least squares message = Both actual and predicted relative reductions in the sum of squares are at most 1e-06
#     Sum of Chi^2 = 1784.51 (1701 data params - 31 model params = expected mean of 1670; p-value = 0.0256298)
#     Completed in 0.9s
#     2*Delta(log(L)) = 1785.64
#     Iteration 6 took 1.0s
#
#     Switching to ML objective (last iteration)
#     --- MLGST ---
#       --- Outer Iter 0: norm_f = 892.818, mu=0, |J|=3645.48
#       --- Outer Iter 1: norm_f = 892.765, mu=598.268, |J|=3647.91
#       Least squares message = Both actual and predicted relative reductions in the sum of squares are at most 1e-06
#       Maximum log(L) = 892.765 below upper bound of -2.84686e+06
#         2*Delta(log(L)) = 1785.53 (1701 data params - 31 model params = expected mean of 1670; p-value = 0.0246389)
#       Completed in 0.4s
#     2*Delta(log(L)) = 1785.53
#     Final MLGST took 0.4s
#
#   Iterative MLGST Total Time: 2.8s
#   --- Re-optimizing logl after robust data scaling ---
#     --- MLGST ---
#       --- Outer Iter 0: norm_f = 892.765, mu=0, |J|=3647.91
#       Least squares message = Both actual and predicted relative reductions in the sum of squares are at most 1e-06
#       Maximum log(L) = 892.765 below upper bound of -2.84686e+06
#         2*Delta(log(L)) = 1785.53 (1701 data params - 31 model params = expected mean of 1670; p-value = 0.0246389)
#       Completed in 0.2s
#   -- Performing 'single' gauge optimization on TP estimate --
#       -- Adding Gauge Optimized (single) --
#   -- Conveying 'single' gauge optimization to TP.Robust+ estimate --
#       -- Adding Gauge Optimized (single) --
# -- Std Practice:  Iter 2 of 3  (CPTP) --:
#   --- Gate Sequence Creation ---
#      1702 sequences created
#      Dataset has 1702 entries: 1702 utilized, 0 requested sequences were missing
#   --- Iterative MLGST: Iter 1 of 6  92 gate strings ---:
#     --- Minimum Chi^2 GST ---
#       Created evaluation tree with 1 subtrees.  Will divide 1 procs into 1 (subtree-processing)
#        groups of ~1 procs each, to distribute over 43 params (taken as 1 param groups of ~43 params).
#       --- Outer Iter 0: norm_f = 1.13518e+07, mu=0, |J|=21245.6
#       --- Outer Iter 1: norm_f = 892.626, mu=50045.8, |J|=992.27
#       --- Outer Iter 2: norm_f = 777.606, mu=16681.9, |J|=942.752
#       --- Outer Iter 3: norm_f = 766.145, mu=5560.65, |J|=928.24
#       --- Outer Iter 4: norm_f = 762.746, mu=1853.55, |J|=926.876
#       --- Outer Iter 5: norm_f = 761.66, mu=617.85, |J|=927.018
#       --- Outer Iter 6: norm_f = 761.538, mu=205.95, |J|=927.091
#       --- Outer Iter 7: norm_f = 761.132, mu=68.65, |J|=927.021
#       --- Outer Iter 8: norm_f = 714.794, mu=183.067, |J|=915.539
#       --- Outer Iter 9: norm_f = 589.588, mu=61.0222, |J|=862.146
#       --- Outer Iter 10: norm_f = 539.917, mu=175.075, |J|=897.897
#       --- Outer Iter 11: norm_f = 160.126, mu=58.3585, |J|=959.895
#       --- Outer Iter 12: norm_f = 156.923, mu=96.0882, |J|=948.442
#       --- Outer Iter 13: norm_f = 145.784, mu=32.0294, |J|=938.637
#       --- Outer Iter 14: norm_f = 130.708, mu=62.3841, |J|=916.897
#       --- Outer Iter 15: norm_f = 107.408, mu=49.4674, |J|=927.024
#       --- Outer Iter 16: norm_f = 96.7959, mu=16.4891, |J|=944.028
#       --- Outer Iter 17: norm_f = 94.9735, mu=18.4977, |J|=942.775
#       --- Outer Iter 18: norm_f = 94.3412, mu=21.3977, |J|=938.417
#       --- Outer Iter 19: norm_f = 91.0094, mu=9.49456, |J|=943.867
#       --- Outer Iter 20: norm_f = 90.3268, mu=3.16485, |J|=946.849
#       --- Outer Iter 21: norm_f = 90.3013, mu=1.05495, |J|=947.565
#       Least squares message = Both actual and predicted relative reductions in the sum of squares are at most 1e-06
#     Sum of Chi^2 = 90.3013 (91 data params - 31 model params = expected mean of 60; p-value = 0.00692056)
#     Completed in 0.7s
#     2*Delta(log(L)) = 90.675
#     Iteration 1 took 0.7s
#
#   --- Iterative MLGST: Iter 2 of 6  168 gate strings ---:
#     --- Minimum Chi^2 GST ---
#       Created evaluation tree with 1 subtrees.  Will divide 1 procs into 1 (subtree-processing)
#        groups of ~1 procs each, to distribute over 43 params (taken as 1 param groups of ~43 params).
#       --- Outer Iter 0: norm_f = 234.736, mu=0, |J|=1254.26
#       --- Outer Iter 1: norm_f = 176.326, mu=137.081, |J|=1255.68
#       --- Outer Iter 2: norm_f = 171.773, mu=105.556, |J|=1256.99
#       --- Outer Iter 3: norm_f = 169.558, mu=35.1855, |J|=1261.19
#       --- Outer Iter 4: norm_f = 169.318, mu=21.0931, |J|=1262.39
#       --- Outer Iter 5: norm_f = 169.261, mu=7.03102, |J|=1263.52
#       --- Outer Iter 6: norm_f = 169.256, mu=2.34367, |J|=1263.84
#       --- Outer Iter 7: norm_f = 169.256, mu=0.781225, |J|=1263.92
#       Least squares message = Both actual and predicted relative reductions in the sum of squares are at most 1e-06
#     Sum of Chi^2 = 169.256 (167 data params - 31 model params = expected mean of 136; p-value = 0.02795)
#     Completed in 0.4s
#     2*Delta(log(L)) = 169.699
#     Iteration 2 took 0.4s
#
#   --- Iterative MLGST: Iter 3 of 6  450 gate strings ---:
#     --- Minimum Chi^2 GST ---
#       Created evaluation tree with 1 subtrees.  Will divide 1 procs into 1 (subtree-processing)
#        groups of ~1 procs each, to distribute over 43 params (taken as 1 param groups of ~43 params).
#       --- Outer Iter 0: norm_f = 598.695, mu=0, |J|=1989.39
#       --- Outer Iter 1: norm_f = 492.907, mu=345.426, |J|=1994.96
#       --- Outer Iter 2: norm_f = 488.091, mu=288.722, |J|=1995.86
#       --- Outer Iter 3: norm_f = 485.321, mu=201.55, |J|=1997.98
#       --- Outer Iter 4: norm_f = 484.188, mu=87.6922, |J|=1999.95
#       --- Outer Iter 5: norm_f = 483.96, mu=29.2307, |J|=2001.14
#       --- Outer Iter 6: norm_f = 483.947, mu=9.74357, |J|=2001.56
#       Least squares message = Both actual and predicted relative reductions in the sum of squares are at most 1e-06
#     Sum of Chi^2 = 483.947 (449 data params - 31 model params = expected mean of 418; p-value = 0.0141317)
#     Completed in 0.5s
#     2*Delta(log(L)) = 484.713
#     Iteration 3 took 0.5s
#
#   --- Iterative MLGST: Iter 4 of 6  862 gate strings ---:
#     --- Minimum Chi^2 GST ---
#       Created evaluation tree with 1 subtrees.  Will divide 1 procs into 1 (subtree-processing)
#        groups of ~1 procs each, to distribute over 43 params (taken as 1 param groups of ~43 params).
#       --- Outer Iter 0: norm_f = 920.692, mu=0, |J|=2705.65
#       --- Outer Iter 1: norm_f = 895.033, mu=634.5, |J|=2710.19
#       --- Outer Iter 2: norm_f = 894.138, mu=211.5, |J|=2710.53
#       --- Outer Iter 3: norm_f = 894.022, mu=70.5, |J|=2710.77
#       --- Outer Iter 4: norm_f = 894.017, mu=23.5, |J|=2710.91
#       Least squares message = Both actual and predicted relative reductions in the sum of squares are at most 1e-06
#     Sum of Chi^2 = 894.017 (861 data params - 31 model params = expected mean of 830; p-value = 0.0607107)
#     Completed in 0.7s
#     2*Delta(log(L)) = 894.87
#     Iteration 4 took 0.7s
#
#   --- Iterative MLGST: Iter 5 of 6  1282 gate strings ---:
#     --- Minimum Chi^2 GST ---
#       Created evaluation tree with 1 subtrees.  Will divide 1 procs into 1 (subtree-processing)
#        groups of ~1 procs each, to distribute over 43 params (taken as 1 param groups of ~43 params).
#       --- Outer Iter 0: norm_f = 1361.05, mu=0, |J|=3186.74
#       --- Outer Iter 1: norm_f = 1345.24, mu=916.828, |J|=3189.47
#       --- Outer Iter 2: norm_f = 1345.12, mu=305.609, |J|=3190.47
#       --- Outer Iter 3: norm_f = 1345.11, mu=101.87, |J|=3190.61
#       Least squares message = Both actual and predicted relative reductions in the sum of squares are at most 1e-06
#     Sum of Chi^2 = 1345.11 (1281 data params - 31 model params = expected mean of 1250; p-value = 0.0307923)
#     Completed in 0.9s
#     2*Delta(log(L)) = 1346.07
#     Iteration 5 took 0.9s
#
#   --- Iterative MLGST: Iter 6 of 6  1702 gate strings ---:
#     --- Minimum Chi^2 GST ---
#       Created evaluation tree with 1 subtrees.  Will divide 1 procs into 1 (subtree-processing)
#        groups of ~1 procs each, to distribute over 43 params (taken as 1 param groups of ~43 params).
#       --- Outer Iter 0: norm_f = 1789.68, mu=0, |J|=3535.86
#       --- Outer Iter 1: norm_f = 1784.61, mu=1196.77, |J|=3536.92
#       --- Outer Iter 2: norm_f = 1784.52, mu=398.922, |J|=3537.74
#       --- Outer Iter 3: norm_f = 1784.51, mu=132.974, |J|=3538.07
#       Least squares message = Both actual and predicted relative reductions in the sum of squares are at most 1e-06
#     Sum of Chi^2 = 1784.51 (1701 data params - 31 model params = expected mean of 1670; p-value = 0.0256293)
#     Completed in 1.1s
#     2*Delta(log(L)) = 1785.64
#     Iteration 6 took 1.1s
#
#     Switching to ML objective (last iteration)
#     --- MLGST ---
#       --- Outer Iter 0: norm_f = 892.819, mu=0, |J|=2501.6
#       --- Outer Iter 1: norm_f = 892.765, mu=598.267, |J|=2503.49
#       Least squares message = Both actual and predicted relative reductions in the sum of squares are at most 1e-06
#       Maximum log(L) = 892.765 below upper bound of -2.84686e+06
#         2*Delta(log(L)) = 1785.53 (1701 data params - 31 model params = expected mean of 1670; p-value = 0.0246386)
#       Completed in 0.5s
#     2*Delta(log(L)) = 1785.53
#     Final MLGST took 0.5s
#
#   Iterative MLGST Total Time: 4.8s
#   --- Re-optimizing logl after robust data scaling ---
#     --- MLGST ---
#       --- Outer Iter 0: norm_f = 892.765, mu=0, |J|=2503.49
#       Least squares message = Both actual and predicted relative reductions in the sum of squares are at most 1e-06
#       Maximum log(L) = 892.765 below upper bound of -2.84686e+06
#         2*Delta(log(L)) = 1785.53 (1701 data params - 31 model params = expected mean of 1670; p-value = 0.0246386)
#       Completed in 0.3s
#   -- Performing 'single' gauge optimization on CPTP estimate --
#       -- Adding Gauge Optimized (single) --
#   -- Conveying 'single' gauge optimization to CPTP.Robust+ estimate --
#       -- Adding Gauge Optimized (single) --
# -- Std Practice:  Iter 3 of 3  (Target) --:
#   --- Gate Sequence Creation ---
#      1702 sequences created
#      Dataset has 1702 entries: 1702 utilized, 0 requested sequences were missing
#   -- Performing 'single' gauge optimization on Target estimate --
#       -- Adding Gauge Optimized (single) --
# *** Creating workspace ***
# *** Generating switchboard ***
# Found standard clifford compilation from std1Q_XYI
# Found standard clifford compilation from std1Q_XYI
# Found standard clifford compilation from std1Q_XYI
# *** Generating tables ***
#   targetSpamBriefTable                          took 0.531645 seconds
#   targetGatesBoxTable                           took 0.497032 seconds
#   datasetOverviewTable                          took 0.099734 seconds
#   bestGatesetSpamParametersTable                took 0.001184 seconds
#   bestGatesetSpamBriefTable                     took 0.463576 seconds
#   bestGatesetSpamVsTargetTable                  took 0.119326 seconds
#   bestGatesetGaugeOptParamsTable                took 0.001522 seconds
#   bestGatesetGatesBoxTable                      took 1.0379 seconds
#   bestGatesetChoiEvalTable                      took 1.073292 seconds
#   bestGatesetDecompTable                        took 0.65484 seconds
#   bestGatesetEvalTable                          took 0.006411 seconds
#   bestGermsEvalTable                            took 0.035644 seconds
#   bestGatesetVsTargetTable                      took 0.225203 seconds
#   bestGatesVsTargetTable_gv                     took 0.292316 seconds
#   bestGatesVsTargetTable_gvgerms                took 0.194403 seconds
#   bestGatesVsTargetTable_gi                     took 0.023224 seconds
#   bestGatesVsTargetTable_gigerms                took 0.045213 seconds
#   bestGatesVsTargetTable_sum                    took 0.270121 seconds
#   bestGatesetErrGenBoxTable                     took 2.185338 seconds
#   metadataTable                                 took 0.076216 seconds
#   stdoutBlock                                   took 0.000945 seconds
#   profilerTable                                 took 0.001273 seconds
#   softwareEnvTable                              took 0.03326 seconds
#   exampleTable                                  took 0.057494 seconds
#   singleMetricTable_gv                          took 0.337145 seconds
#   singleMetricTable_gi                          took 0.021151 seconds
#   fiducialListTable                             took 0.000465 seconds
#   prepStrListTable                              took 0.000149 seconds
#   effectStrListTable                            took 0.000147 seconds
#   colorBoxPlotKeyPlot                           took 0.061989 seconds
#   germList2ColTable                             took 0.000236 seconds
#   progressTable                                 took 5.421907 seconds
# *** Generating plots ***
#   gramBarPlot                                   took 0.215992 seconds
#   progressBarPlot                               took 5.148373 seconds
#   progressBarPlot_sum                           took 0.000727 seconds
#   finalFitComparePlot                           took 1.504914 seconds
#   bestEstimateColorBoxPlot                      took 19.085798 seconds
#   bestEstimateTVDColorBoxPlot                   took 18.147118 seconds
#   bestEstimateColorScatterPlot                  took 24.566311 seconds
#   bestEstimateColorHistogram                    took 19.027781 seconds
#   progressTable_scl                             took 3.59656 seconds
#   progressBarPlot_scl                           took 3.565081 seconds
#   bestEstimateColorBoxPlot_scl                  took 12.48356 seconds
#   bestEstimateColorScatterPlot_scl              took 16.113616 seconds
#   bestEstimateColorHistogram_scl                took 12.366276 seconds
#   dataScalingColorBoxPlot                       took 0.259699 seconds
# *** Merging into template file ***
#   Rendering bestGatesVsTargetTable_gv           took 0.009648 seconds
#   Rendering bestGatesetDecompTable              took 0.023068 seconds
#   Rendering bestGatesetGaugeOptParamsTable      took 0.00159 seconds
#   Rendering germList2ColTable                   took 0.002646 seconds
#   Rendering bestGatesVsTargetTable_gi           took 0.006826 seconds
#   Rendering fiducialListTable                   took 0.001802 seconds
#   Rendering targetSpamBriefTable                took 0.020901 seconds
#   Rendering softwareEnvTable                    took 0.002107 seconds
#   Rendering progressTable_scl                   took 0.008667 seconds
#   Rendering bestEstimateTVDColorBoxPlot         took 0.180461 seconds
#   Rendering bestGatesVsTargetTable_gigerms      took 0.008371 seconds
#   Rendering progressBarPlot_scl                 took 0.002803 seconds
#   Rendering topSwitchboard                      took 0.000114 seconds
#   Rendering bestEstimateColorBoxPlot_scl        took 0.114655 seconds
#   Rendering bestGatesetSpamParametersTable      took 0.003 seconds
#   Rendering bestGatesetErrGenBoxTable           took 0.053915 seconds
#   Rendering singleMetricTable_gv                took 0.009899 seconds
#   Rendering progressBarPlot                     took 0.004466 seconds
#   Rendering progressBarPlot_sum                 took 0.004129 seconds
#   Rendering singleMetricTable_gi                took 0.007378 seconds
#   Rendering bestGatesetChoiEvalTable            took 0.026891 seconds
#   Rendering colorBoxPlotKeyPlot                 took 0.003736 seconds
#   Rendering bestEstimateColorScatterPlot        took 0.230142 seconds
#   Rendering bestGatesetVsTargetTable            took 0.001427 seconds
#   Rendering maxLSwitchboard1                    took 9.7e-05 seconds
#   Rendering bestGatesetSpamBriefTable           took 0.037438 seconds
#   Rendering bestGermsEvalTable                  took 0.159436 seconds
#   Rendering prepStrListTable                    took 0.001417 seconds
#   Rendering bestEstimateColorHistogram_scl      took 0.086028 seconds
#   Rendering profilerTable                       took 0.002685 seconds
#   Rendering dataScalingColorBoxPlot             took 0.030179 seconds
#   Rendering metricSwitchboard_gv                took 4e-05 seconds
#   Rendering bestGatesetGatesBoxTable            took 0.026805 seconds
#   Rendering progressTable                       took 0.012195 seconds
#   Rendering bestEstimateColorScatterPlot_scl    took 0.143184 seconds
#   Rendering bestGatesetEvalTable                took 0.035191 seconds
#   Rendering bestGatesVsTargetTable_gvgerms      took 0.019465 seconds
#   Rendering bestGatesVsTargetTable_sum          took 0.007571 seconds
#   Rendering datasetOverviewTable                took 0.000576 seconds
#   Rendering targetGatesBoxTable                 took 0.016832 seconds
#   Rendering bestEstimateColorHistogram          took 0.12326 seconds
#   Rendering metricSwitchboard_gi                took 4.2e-05 seconds
#   Rendering gramBarPlot                         took 0.004381 seconds
#   Rendering effectStrListTable                  took 0.00144 seconds
#   Rendering bestGatesetSpamVsTargetTable        took 0.004303 seconds
#   Rendering exampleTable                        took 0.002516 seconds
#   Rendering finalFitComparePlot                 took 0.001596 seconds
#   Rendering stdoutBlock                         took 0.001558 seconds
#   Rendering bestEstimateColorBoxPlot            took 0.165534 seconds
#   Rendering metadataTable                       took 0.006392 seconds
# Output written to tutorial_files/gettingStartedReport directory
# *** Report Generation Complete!  Total time 151.842s ***

# %% [markdown]
# You can now open the file [tutorial_files/gettingStartedReport/main.html](tutorial_files/gettingStartedReport/main.html) in your browser to view the report.  **That's it!  You've just run GST!**
#
# The other tutorials in this directory will explain how to use the various objects and algorithms that comprise pyGSTi. These **tutorial notebooks are meant to be fairly pedagogical** and include details about the inner workings of and design choices within pyGSTi.  In contrast, the **"FAQ" directory contains notebooks with attempt to address specific questions as quickly and directly as possible, with little or no explanation of related topics or broader context**.
