# %% [markdown]
# # Instruments and Intermediate Measurements Tutorial
# This tutorial will demonstrate how perform tomography on models which, in addition to normal gates, contain *quantum instruments*.  Quantum instruments are maps that act on a qubit state (density matrix) and produce a qubit state along with a classical outcome.  That is, instruments are maps from $\mathcal{B}(\mathcal{H})$, the space of density matrices, to $\mathcal{B}(\mathcal{H}) \otimes K(n)$, where $K(n)$ is a classical space of $n$ elements.
#
# In pyGSTi, instruments are represented as collections of gates, one for each classical "outcome" of the instrument.  This tutorial will demonstrate how to add instruments to `Model` objects, compute probabilities using such `Model`s, and ultimately perform tomography on them.  We'll start with a few familiar imports:

# %%
import pygsti
from pygsti.modelpacks import smq1Q_XYI as std
import numpy as np
from pygsti.modelmembers.instruments import Instrument
from pprint import pprint

# %% [markdown]
# ## Instrument construction
# Next, we'll add an instrument to our "standard" model - a 1-qubit model containing $I$, $X(\pi/2)$, and $Y(\pi/2)$ gates.  The ideal instrument will be named `"Iz"` (all instrument names must begin with `"I"`), and consist of perfect projectors onto the 0 and 1 states.  Instead of labelling the associated outcomes "0" and "1", which might me most logical, we'll name them "p0" and "p1" so it's easier to distinguish them from the final POVM outcomes which *are* labelled "0" and "1".

# %%
#Make a copy so we don't modify the original
mdl_ideal = std.target_model()

# Create and add the ideal instrument
E0 = mdl_ideal.effects['0']
E1 = mdl_ideal.effects['1']
Gmz_plus  = np.dot(E0,E0.T) # note effect vectors are stored as column vectors
Gmz_minus = np.dot(E1,E1.T)
inst = Instrument({'p0': Gmz_plus, 'p1': Gmz_minus})
mdl_ideal[('Iz',0)] = inst

# %% [markdown]
# In order to generate some simulated data later on, we'll now create a noisy version of `mdl_ideal` by depolarizing the state preparation, gates, and POVM, and also rotating the basis that is measured by the instrument and POVM.

# %%
mdl_noisy = mdl_ideal.depolarize(op_noise=0.005, spam_noise=0.01)
mdl_noisy = mdl_noisy.rotate(max_rotate=0.025, seed=2048)
mdl_noisy.effects.depolarize(0.01)
mdl_ideal.convert_members_inplace('CPTPLND')
mdl_noisy.convert_members_inplace('CPTPLND')
# Out:
# /Users/riley/quantum/pygsti-repo/pygsti/modelmembers/instruments/__init__.py:217: DubiousTargetWarning: Target CPTR operator p0 has Kraus rank 2 > 1.
#   _warnings.warn(msg, _DubiousTargetWarning)
# /Users/riley/quantum/pygsti-repo/pygsti/modelmembers/instruments/__init__.py:217: DubiousTargetWarning: Target CPTR operator p1 has Kraus rank 2 > 1.
#   _warnings.warn(msg, _DubiousTargetWarning)

# %% [markdown]
# ## Generating probabilities
# Instrument labels (e.g. `"Iz"`) may be included within `Circuit` objects, and `Model` objects are able to compute probabilities for them just like normal (non-instrument) operation sequences.  The difference is that probabilities are labeled by tuples of instrument and POVM outcomes - referred to as **"outcome tuples"** - one for each instrument and one for the final POVM:

# %%
for mdl in [mdl_ideal, mdl_noisy]:
    pprint(dict(mdl.probabilities( pygsti.circuits.Circuit(( ('Gxpi2',0) , ('Iz',0) )) )))
    print()
# Out:
# {('p0', '0'): np.float64(0.5000000000000004),
#  ('p0', '1'): np.float64(-8.395995698750204e-18),
#  ('p1', '0'): np.float64(-1.7920203524146168e-17),
#  ('p1', '1'): np.float64(0.5000000000000001)}
#
# {('p0', '0'): np.float64(0.481367923790963),
#  ('p0', '1'): np.float64(0.0024189342904068554),
#  ('p1', '0'): np.float64(0.0025810657095932145),
#  ('p1', '1'): np.float64(0.5136320762090365)}

# %%
for mdl in [mdl_ideal, mdl_noisy]:
    pprint(dict(mdl.probabilities( pygsti.circuits.Circuit(( ('Iz',0), ('Gxpi2',0) , ('Iz',0) )) )))
    print()
# Out:
# {('p0', 'p0', '0'): np.float64(0.5000000000000003),
#  ('p0', 'p0', '1'): np.float64(-2.4654835462913652e-17),
#  ('p0', 'p1', '0'): np.float64(2.133210794294821e-17),
#  ('p0', 'p1', '1'): np.float64(0.5000000000000001),
#  ('p1', 'p0', '0'): np.float64(1.625883976416348e-17),
#  ('p1', 'p0', '1'): np.float64(7.180984831322017e-34),
#  ('p1', 'p1', '0'): np.float64(-5.582956019008447e-34),
#  ('p1', 'p1', '1'): np.float64(1.6258839764163485e-17)}
#
# {('p0', 'p0', '0'): np.float64(0.4775917799207901),
#  ('p0', 'p0', '1'): np.float64(0.002399958693069308),
#  ('p0', 'p1', '0'): np.float64(0.0025624981205110728),
#  ('p0', 'p1', '1'): np.float64(0.5099371259816915),
#  ('p1', 'p0', '0'): np.float64(0.0038579004920827257),
#  ('p1', 'p0', '1'): np.float64(1.938643463358172e-05),
#  ('p1', 'p1', '0'): np.float64(1.8156751786106926e-05),
#  ('p1', 'p1', '1'): np.float64(0.003613193605435256)}

# %% [markdown]
# In fact, pyGSTi *always* labels probabilties using outcome tuples, it's just that in the non-instrument case they're always 1-tuples and by `OutcomeLabelDict` magic can be treated as if they were just strings:

# %%
probs = mdl_ideal.probabilities( pygsti.circuits.Circuit([('Gxpi2',0)]) )
print("probs = ",dict(probs))
print("probs['0'] = ", probs['0']) #This works...
print("probs[('0',)] = ", probs[('0',)]) # and so does this.
# Out:
# probs =  {('0',): np.float64(0.5000000000000006), ('1',): np.float64(0.5000000000000001)}
# probs['0'] =  0.5000000000000006
# probs[('0',)] =  0.5000000000000006

# %% [markdown]
# ## Performing tomography
# Now let's perform tomography on a model that includes instruments.
# First, we'll build an experiment design. This notebook's experiment design makes a minor modification to the default design for our working modelpack (smq1Q_XYI).

# %%
germs = std.germs()
germs += [pygsti.circuits.Circuit([('Iz', 0)])]
ed = std.create_gst_experiment_design(max_max_length=8, germs=germs)

# %% [markdown]
# ### Simulated data generation
# Next, we generate data using `mdl_noisy` in exactly the same way as we would for any other model. We write the data to disk so you can see how datasets look when they include measurement data.

# %%
ds = pygsti.data.simulate_data(mdl_noisy, ed.all_circuits_needing_data, 10_000, 'multinomial', seed=2018)
pygsti.io.write_dataset("../../tutorial_files/intermediate_meas_dataset.txt", ds)

# %% [markdown]
# Notice the format of [intermediate_meas_dataset.txt](../../tutorial_files/intermediate_meas_dataset.txt), which includes a column for each distinct outcome tuple.  Since not all experiments contain data for all outcome tuples, the `"--"` is used as a placeholder.  Now that the data is generated, we run LGST or LSGST just like we would for any other model:
#
# ### Running the GST fit and generating a report

# %%
from pygsti.protocols import StandardGST, ProtocolData
gst_modes = ('full TP', 'H+s', 'GLND', 'H+S+d')
gst = StandardGST(
    modes=gst_modes, target_model=mdl_ideal, verbosity=3
)
pd = ProtocolData(ed, ds)
res = gst.run(pd)
# Out:
# -- Std Practice:  Iter 1 of 4  (full TP) --:
#     Precomputing CircuitOutcomeProbabilityArray layouts for each iteration.
#   --- Iterative GST: Iter 1 of 4  128 circuits ---:
#     --- chi2 GST ---
#     Sum of Chi^2 = 127.455 (200 data params - 71 (approx) model params = expected mean of 129; p-value = 0.521935)
#     Completed in 0.1s
#     Iteration 1 took 7.7s
#
#   --- Iterative GST: Iter 2 of 4  240 circuits ---:
#     --- chi2 GST ---
#     Sum of Chi^2 = 384.528 (528 data params - 71 (approx) model params = expected mean of 457; p-value = 0.994043)
#     Completed in 0.1s
#     Iteration 2 took 0.1s
#
#   --- Iterative GST: Iter 3 of 4  393 circuits ---:
#     --- chi2 GST ---
#     Sum of Chi^2 = 939.124 (1761 data params - 71 (approx) model params = expected mean of 1690; p-value = 1)
#     Completed in 0.2s
#     Iteration 3 took 0.2s
#
#   --- Iterative GST: Iter 4 of 4  592 circuits ---:
#     --- chi2 GST ---
#     Sum of Chi^2 = 1919.15 (20320 data params - 71 (approx) model params = expected mean of 20249; p-value = 1)
#     Completed in 1.2s
#     Iteration 4 took 1.2s
#
#     Last iteration:
#     --- dlogl GST ---
#     2*Delta(log(L)) = 14131 (20320 data params - 71 (approx) model params = expected mean of 20249; p-value = 1)
#     Completed in 10.4s
#     Final optimization took 10.4s
#
# -- Std Practice:  Iter 2 of 4  (H+s) --:
#     Precomputing CircuitOutcomeProbabilityArray layouts for each iteration.
#   --- Iterative GST: Iter 1 of 4  128 circuits ---:
#     --- chi2 GST ---
#     Sum of Chi^2 = 156.951 (200 data params - 48 (approx) model params = expected mean of 152; p-value = 0.374828)
#     Completed in 0.6s
#     Iteration 1 took 8.2s
#
#   --- Iterative GST: Iter 2 of 4  240 circuits ---:
#     --- chi2 GST ---
#     Sum of Chi^2 = 417.613 (528 data params - 48 (approx) model params = expected mean of 480; p-value = 0.981523)
#     Completed in 0.5s
#     Iteration 2 took 0.5s
#
#   --- Iterative GST: Iter 3 of 4  393 circuits ---:
#     --- chi2 GST ---
#     Sum of Chi^2 = 979.49 (1761 data params - 48 (approx) model params = expected mean of 1713; p-value = 1)
#     Completed in 0.5s
#     Iteration 3 took 0.5s
#
#   --- Iterative GST: Iter 4 of 4  592 circuits ---:
#     --- chi2 GST ---
#     Sum of Chi^2 = 1958.71 (20320 data params - 48 (approx) model params = expected mean of 20272; p-value = 1)
#     Completed in 1.6s
#     Iteration 4 took 1.7s
#
#     Last iteration:
#     --- dlogl GST ---
#     2*Delta(log(L)) = 14169.2 (20320 data params - 48 (approx) model params = expected mean of 20272; p-value = 1)
#     Completed in 1.3s
#     Final optimization took 1.3s
#
# -- Std Practice:  Iter 3 of 4  (GLND) --:
#     Precomputing CircuitOutcomeProbabilityArray layouts for each iteration.
#   --- Iterative GST: Iter 1 of 4  128 circuits ---:
#     --- chi2 GST ---
#     Sum of Chi^2 = 144.857 (200 data params - 96 (approx) model params = expected mean of 104; p-value = 0.00502756)
#     Completed in 0.8s
#     Iteration 1 took 8.4s
#
#   --- Iterative GST: Iter 2 of 4  240 circuits ---:
#     --- chi2 GST ---
#     Sum of Chi^2 = 404.604 (528 data params - 96 (approx) model params = expected mean of 432; p-value = 0.823731)
#     Completed in 0.6s
#     Iteration 2 took 0.7s
#
#   --- Iterative GST: Iter 3 of 4  393 circuits ---:
#     --- chi2 GST ---
#     Sum of Chi^2 = 955.4 (1761 data params - 96 (approx) model params = expected mean of 1665; p-value = 1)
#     Completed in 1.0s
#     Iteration 3 took 1.0s
#
#   --- Iterative GST: Iter 4 of 4  592 circuits ---:
#     --- chi2 GST ---
#     Sum of Chi^2 = 1940.58 (20320 data params - 96 (approx) model params = expected mean of 20224; p-value = 1)
#     Completed in 2.7s
#     Iteration 4 took 2.7s
#
#     Last iteration:
#     --- dlogl GST ---
#     2*Delta(log(L)) = 14151.2 (20320 data params - 96 (approx) model params = expected mean of 20224; p-value = 1)
#     Completed in 1.9s
#     Final optimization took 1.9s
#
# -- Std Practice:  Iter 4 of 4  (H+S+d) --:
#     Precomputing CircuitOutcomeProbabilityArray layouts for each iteration.
#   --- Iterative GST: Iter 1 of 4  128 circuits ---:
#     --- chi2 GST ---
#     Sum of Chi^2 = 163.698 (200 data params - 56 (approx) model params = expected mean of 144; p-value = 0.124961)
#     Completed in 0.8s
#     Iteration 1 took 8.4s
#
#   --- Iterative GST: Iter 2 of 4  240 circuits ---:
#     --- chi2 GST ---
#     Sum of Chi^2 = 425.176 (528 data params - 56 (approx) model params = expected mean of 472; p-value = 0.940102)
#     Completed in 0.5s
#     Iteration 2 took 0.5s
#
#   --- Iterative GST: Iter 3 of 4  393 circuits ---:
#     --- chi2 GST ---
#     Sum of Chi^2 = 983.069 (1761 data params - 56 (approx) model params = expected mean of 1705; p-value = 1)
#     Completed in 0.6s
#     Iteration 3 took 0.7s
#
#   --- Iterative GST: Iter 4 of 4  592 circuits ---:
#     --- chi2 GST ---
#     Sum of Chi^2 = 1962.98 (20320 data params - 56 (approx) model params = expected mean of 20264; p-value = 1)
#     Completed in 1.1s
#     Iteration 4 took 1.2s
#
#     Last iteration:
#     --- dlogl GST ---
#     2*Delta(log(L)) = 14173.5 (20320 data params - 56 (approx) model params = expected mean of 20264; p-value = 1)
#     Completed in 1.3s
#     Final optimization took 1.3s

# %%
from pygsti.report import construct_standard_report
report_dir = '../../tutorial_files/cptp-instrument-report'
report_object = construct_standard_report(res, title='CPTP intrument GST')
report_object.write_html(report_dir, auto_open=True)
# Out:
# Running idle tomography
# Computing switchable properties
# Found standard clifford compilation from smq1Q_XYI
# Found standard clifford compilation from smq1Q_XYI
# Found standard clifford compilation from smq1Q_XYI
# Found standard clifford compilation from smq1Q_XYI
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.4995426590182109+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:167: NumericalDomainWarning:
#
# The input matrix b has trace (0.5+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.500457340981789+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.5000000000000001+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:167: NumericalDomainWarning:
#
# The input matrix b has trace (0.4999999999999999+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.5+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.5000000000013143+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:167: NumericalDomainWarning:
#
# The input matrix b has trace (0.4999999999999999+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.4999999999986856+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.5000000000000001+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:167: NumericalDomainWarning:
#
# The input matrix b has trace (0.4999999999999999+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.5+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:193: NumericalDomainWarning:
#
#
#             Input matrix has smallest eigenvalue -0.0010827485376709437, and so is not
#             PSD up to tolerance 1.4901161193847656e-08.
#             We'll project out the bad eigenspaces to only work with the PSD part.
#
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:193: NumericalDomainWarning:
#
#
#             Input matrix has smallest eigenvalue -0.001838381204941453, and so is not
#             PSD up to tolerance 1.4901161193847656e-08.
#             We'll project out the bad eigenspaces to only work with the PSD part.
#
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:193: NumericalDomainWarning:
#
#
#             Input matrix has smallest eigenvalue -0.00045327231076429885, and so is not
#             PSD up to tolerance 1.4901161193847656e-08.
#             We'll project out the bad eigenspaces to only work with the PSD part.
#
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:193: NumericalDomainWarning:
#
#
#             Input matrix has smallest eigenvalue -8.7340124160873e-07, and so is not
#             PSD up to tolerance 1.4901161193847656e-08.
#             We'll project out the bad eigenspaces to only work with the PSD part.
#
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:193: NumericalDomainWarning:
#
#
#             Input matrix has smallest eigenvalue -0.0009218764396157825, and so is not
#             PSD up to tolerance 1.4901161193847656e-08.
#             We'll project out the bad eigenspaces to only work with the PSD part.
#
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:193: NumericalDomainWarning:
#
#
#             Input matrix has smallest eigenvalue -9.009512347483998e-07, and so is not
#             PSD up to tolerance 1.4901161193847656e-08.
#             We'll project out the bad eigenspaces to only work with the PSD part.
#
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:193: NumericalDomainWarning:
#
#
#             Input matrix has smallest eigenvalue -0.0017050794890953746, and so is not
#             PSD up to tolerance 1.4901161193847656e-08.
#             We'll project out the bad eigenspaces to only work with the PSD part.
#
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:193: NumericalDomainWarning:
#
#
#             Input matrix has smallest eigenvalue -0.0031691876632774247, and so is not
#             PSD up to tolerance 1.4901161193847656e-08.
#             We'll project out the bad eigenspaces to only work with the PSD part.
#
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:193: NumericalDomainWarning:
#
#
#             Input matrix has smallest eigenvalue -7.22576347140898e-06, and so is not
#             PSD up to tolerance 1.4901161193847656e-08.
#             We'll project out the bad eigenspaces to only work with the PSD part.
#
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:193: NumericalDomainWarning:
#
#
#             Input matrix has smallest eigenvalue -7.76911381002885e-08, and so is not
#             PSD up to tolerance 1.4901161193847656e-08.
#             We'll project out the bad eigenspaces to only work with the PSD part.
#
#
# /Users/riley/quantum/pygsti-repo/pygsti/report/workspacetables.py:2741: RuntimeWarning:
#
# divide by zero encountered in log
#
# /Users/riley/quantum/pygsti-repo/pygsti/forwardsims/mapforwardsim.py:745: ForwardSimulatorSuitabilityWarning:
#
#
#             Generating dense process matrix representations of circuits or gates
#             can be inefficient and should be avoided for the purposes of forward
#             simulation/calculation of circuit outcome probability distributions
#             when using the MapForwardSimulator. This operator is small enough
#             that it could be computed with MatrixForwardSimulator instead.
#
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.4995426590182109+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:167: NumericalDomainWarning:
#
# The input matrix b has trace (0.5+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.500457340981789+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.5000000000000001+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:167: NumericalDomainWarning:
#
# The input matrix b has trace (0.4999999999999999+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.5+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.5000000000013143+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:167: NumericalDomainWarning:
#
# The input matrix b has trace (0.4999999999999999+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.4999999999986856+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.5000000000000001+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:167: NumericalDomainWarning:
#
# The input matrix b has trace (0.4999999999999999+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.5+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/forwardsims/mapforwardsim.py:745: ForwardSimulatorSuitabilityWarning:
#
#
#             Generating dense process matrix representations of circuits or gates
#             can be inefficient and should be avoided for the purposes of forward
#             simulation/calculation of circuit outcome probability distributions
#             when using the MapForwardSimulator. This operator is small enough
#             that it could be computed with MatrixForwardSimulator instead.
#
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.4995426590182109+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:167: NumericalDomainWarning:
#
# The input matrix b has trace (0.5+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.500457340981789+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.5000000000000001+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:167: NumericalDomainWarning:
#
# The input matrix b has trace (0.4999999999999999+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.5+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.5000000000013143+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!
#
# /Users/riley/quantum/pygsti-repo/pygsti/tools/optools.py:165: NumericalDomainWarning:
#
# The input matrix a has trace (0.4999999999986856+0j), which deviates from 1 by more than 1.4901161193847656e-08. Beware result!

# %% [markdown]
# **Thats it!**  You've done tomography on a model with intermediate measurments (instruments).
#
# As a bonus, the code below checks for violation of complete positivity of the instrument operations from the two fits. We see that the CPTP fit has no violation, while the full TP fit has small violations.

# %%
# for mdl in [res.estimates['full TP'].models['stdgaugeopt'], res.estimates['CPTPLND'].models['stdgaugeopt']]:
for mode in gst_modes:
    print("Mode: ", mode)
    mdl = res.estimates[mode].models['final iteration estimate']
    for instlbl, inst in mdl.instruments.items():
        print(instlbl, ' -- ', inst.num_params, 'parameters', type(inst))
        for ioplbl, iop in inst.items():
            violation = max(0, pygsti.tools.sum_of_negative_choi_eigenvalues_gate(iop.to_dense(), 'pp'))
            print(ioplbl + ': ' + str(violation) )
        print()
# Out:
# Mode:  full TP
# Iz:0  --  28 parameters <class 'pygsti.modelmembers.instruments.tpinstrument.TPInstrument'>
# p0: 0.0009159823959658564
# p1: 3.4186661110919814e-05
#
# Mode:  H+s
# Iz:0  --  18 parameters <class 'pygsti.modelmembers.instruments.instrument.Instrument'>
# p0: 0
# p1: 0
#
# Mode:  GLND
# Iz:0  --  36 parameters <class 'pygsti.modelmembers.instruments.instrument.Instrument'>
# p0: 1.768620914474518e-14
# p1: 6.328065220660684e-15
#
# Mode:  H+S+d
# Iz:0  --  21 parameters <class 'pygsti.modelmembers.instruments.instrument.Instrument'>
# p0: 0
# p1: 0

# %%
for mode in gst_modes:
    print('-' * 40)
    print("Mode: ", mode)
    print('-' * 40)
    mdl = res.estimates[mode].models['final iteration estimate']
    for instlbl, inst in mdl.instruments.items():
        print(instlbl, ' -- ', inst.num_params, 'parameters')
    mdl._print_gpindices()
# Out:
# ----------------------------------------
# Mode:  full TP
# ----------------------------------------
# Iz:0  --  28 parameters
# PRINTING MODEL GPINDICES!!!
# >>> rho0 [TPState]: 3 params, indices=slice(0, 3, None)
# >>> Mdefault [TPPOVM]: 4 params, indices=slice(np.int64(3), np.int64(7), None)
#   >>> Sub0 [FullPOVMEffect]: 4 params, indices=slice(np.int64(3), np.int64(7), None)
#     >>> Sub0 [FullState]: 4 params, indices=slice(np.int64(3), np.int64(7), None)
#   >>> Sub1 [ComplementPOVMEffect]: 4 params, indices=slice(np.int64(3), np.int64(7), None)
#     >>> Sub0 [FullPOVMEffect]: 4 params, indices=slice(np.int64(3), np.int64(7), None)
#       >>> Sub0 [FullState]: 4 params, indices=slice(np.int64(3), np.int64(7), None)
# >>> [] [FullTPOp]: 12 params, indices=slice(np.int64(7), np.int64(19), None)
# >>> Gxpi2:0 [FullTPOp]: 12 params, indices=slice(np.int64(19), np.int64(31), None)
# >>> Gypi2:0 [FullTPOp]: 12 params, indices=slice(np.int64(31), np.int64(43), None)
# >>> Iz:0 [TPInstrument]: 28 params, indices=slice(np.int64(43), np.int64(71), None)
#   >>> Sub0 [TPInstrumentOp]: 28 params, indices=slice(np.int64(43), np.int64(71), None)
#     >>> Sub0 [FullTPOp]: 12 params, indices=slice(np.int64(43), np.int64(55), None)
#     >>> Sub1 [FullArbitraryOp]: 16 params, indices=slice(np.int64(55), np.int64(71), None)
#   >>> Sub1 [TPInstrumentOp]: 28 params, indices=slice(np.int64(43), np.int64(71), None)
#     >>> Sub0 [FullTPOp]: 12 params, indices=slice(np.int64(43), np.int64(55), None)
#     >>> Sub1 [FullArbitraryOp]: 16 params, indices=slice(np.int64(55), np.int64(71), None)
# ----------------------------------------
# Mode:  H+s
# ----------------------------------------
# Iz:0  --  18 parameters
# PRINTING MODEL GPINDICES!!!
# >>> rho0 [ComposedState]: 6 params, indices=slice(np.int64(0), np.int64(6), None)
#   >>> Sub0 [ExpErrorgenOp]: 6 params, indices=slice(np.int64(0), np.int64(6), None)
#     >>> Sub0 [LindbladErrorgen]: 6 params, indices=slice(np.int64(0), np.int64(6), None)
#   >>> Sub1 [StaticPureState]: 0 params, indices=slice(0, 0, None)
# >>> Mdefault [ComposedPOVM]: 6 params, indices=slice(np.int64(6), np.int64(12), None)
#   >>> Sub0 [ExpErrorgenOp]: 6 params, indices=slice(np.int64(6), np.int64(12), None)
#     >>> Sub0 [LindbladErrorgen]: 6 params, indices=slice(np.int64(6), np.int64(12), None)
#   >>> Sub1 [UnconstrainedPOVM]: 0 params, indices=slice(0, 0, None)
#     >>> Sub0 [StaticPOVMEffect]: 0 params, indices=slice(0, 0, None)
#       >>> Sub0 [StaticState]: 0 params, indices=slice(0, 0, None)
#     >>> Sub1 [StaticPOVMEffect]: 0 params, indices=slice(0, 0, None)
#       >>> Sub0 [StaticState]: 0 params, indices=slice(0, 0, None)
# >>> [] [ComposedOp]: 6 params, indices=slice(np.int64(12), np.int64(18), None)
#   >>> Sub0 [StaticUnitaryOp]: 0 params, indices=slice(0, 0, None)
#   >>> Sub1 [ExpErrorgenOp]: 6 params, indices=slice(np.int64(12), np.int64(18), None)
#     >>> Sub0 [LindbladErrorgen]: 6 params, indices=slice(np.int64(12), np.int64(18), None)
# >>> Gxpi2:0 [ComposedOp]: 6 params, indices=slice(np.int64(18), np.int64(24), None)
#   >>> Sub0 [StaticUnitaryOp]: 0 params, indices=slice(0, 0, None)
#   >>> Sub1 [ExpErrorgenOp]: 6 params, indices=slice(np.int64(18), np.int64(24), None)
#     >>> Sub0 [LindbladErrorgen]: 6 params, indices=slice(np.int64(18), np.int64(24), None)
# >>> Gypi2:0 [ComposedOp]: 6 params, indices=slice(np.int64(24), np.int64(30), None)
#   >>> Sub0 [StaticUnitaryOp]: 0 params, indices=slice(0, 0, None)
#   >>> Sub1 [ExpErrorgenOp]: 6 params, indices=slice(np.int64(24), np.int64(30), None)
#     >>> Sub0 [LindbladErrorgen]: 6 params, indices=slice(np.int64(24), np.int64(30), None)
# >>> Iz:0 [Instrument]: 18 params, indices=slice(np.int64(30), np.int64(48), None)
#   >>> Sub0 [ComposedOp]: 12 params, indices=slice(np.int64(30), np.int64(42), None)
#     >>> Sub0 [RootConjOperator]: 6 params, indices=slice(np.int64(30), np.int64(36), None)
#       >>> Sub0 [ComposedPOVMEffect]: 6 params, indices=slice(np.int64(30), np.int64(36), None)
#         >>> Sub0 [ExpErrorgenOp]: 6 params, indices=slice(np.int64(30), np.int64(36), None)
#           >>> Sub0 [LindbladErrorgen]: 6 params, indices=slice(np.int64(30), np.int64(36), None)
#         >>> Sub1 [StaticPOVMEffect]: 0 params, indices=slice(0, 0, None)
#           >>> Sub0 [StaticState]: 0 params, indices=slice(0, 0, None)
#     >>> Sub1 [ComposedOp]: 6 params, indices=slice(np.int64(36), np.int64(42), None)
#       >>> Sub0 [StaticUnitaryOp]: 0 params, indices=slice(0, 0, None)
#       >>> Sub1 [ExpErrorgenOp]: 6 params, indices=slice(np.int64(36), np.int64(42), None)
#         >>> Sub0 [LindbladErrorgen]: 6 params, indices=slice(np.int64(36), np.int64(42), None)
#   >>> Sub1 [ComposedOp]: 12 params, indices=[30 31 32 33 34 35 42 43 44 45 46 47]
#     >>> Sub0 [RootConjOperator]: 6 params, indices=[30 31 32 33 34 35]
#       >>> Sub0 [ComposedPOVMEffect]: 6 params, indices=[30 31 32 33 34 35]
#         >>> Sub0 [ExpErrorgenOp]: 6 params, indices=[30 31 32 33 34 35]
#           >>> Sub0 [LindbladErrorgen]: 6 params, indices=[30 31 32 33 34 35]
#         >>> Sub1 [StaticPOVMEffect]: 0 params, indices=slice(0, 0, None)
#           >>> Sub0 [StaticState]: 0 params, indices=slice(0, 0, None)
#     >>> Sub1 [ComposedOp]: 6 params, indices=[42 43 44 45 46 47]
#       >>> Sub0 [StaticUnitaryOp]: 0 params, indices=slice(0, 0, None)
#       >>> Sub1 [ExpErrorgenOp]: 6 params, indices=[42 43 44 45 46 47]
#         >>> Sub0 [LindbladErrorgen]: 6 params, indices=[42 43 44 45 46 47]
# ----------------------------------------
# Mode:  GLND
# ----------------------------------------
# Iz:0  --  36 parameters
# PRINTING MODEL GPINDICES!!!
# >>> rho0 [ComposedState]: 12 params, indices=slice(np.int64(0), np.int64(12), None)
#   >>> Sub0 [ExpErrorgenOp]: 12 params, indices=slice(np.int64(0), np.int64(12), None)
#     >>> Sub0 [LindbladErrorgen]: 12 params, indices=slice(np.int64(0), np.int64(12), None)
#   >>> Sub1 [StaticPureState]: 0 params, indices=slice(0, 0, None)
# >>> Mdefault [ComposedPOVM]: 12 params, indices=slice(np.int64(12), np.int64(24), None)
#   >>> Sub0 [ExpErrorgenOp]: 12 params, indices=slice(np.int64(12), np.int64(24), None)
#     >>> Sub0 [LindbladErrorgen]: 12 params, indices=slice(np.int64(12), np.int64(24), None)
#   >>> Sub1 [UnconstrainedPOVM]: 0 params, indices=slice(0, 0, None)
#     >>> Sub0 [StaticPOVMEffect]: 0 params, indices=slice(0, 0, None)
#       >>> Sub0 [StaticState]: 0 params, indices=slice(0, 0, None)
#     >>> Sub1 [StaticPOVMEffect]: 0 params, indices=slice(0, 0, None)
#       >>> Sub0 [StaticState]: 0 params, indices=slice(0, 0, None)
# >>> [] [ComposedOp]: 12 params, indices=slice(np.int64(24), np.int64(36), None)
#   >>> Sub0 [StaticUnitaryOp]: 0 params, indices=slice(0, 0, None)
#   >>> Sub1 [ExpErrorgenOp]: 12 params, indices=slice(np.int64(24), np.int64(36), None)
#     >>> Sub0 [LindbladErrorgen]: 12 params, indices=slice(np.int64(24), np.int64(36), None)
# >>> Gxpi2:0 [ComposedOp]: 12 params, indices=slice(np.int64(36), np.int64(48), None)
#   >>> Sub0 [StaticUnitaryOp]: 0 params, indices=slice(0, 0, None)
#   >>> Sub1 [ExpErrorgenOp]: 12 params, indices=slice(np.int64(36), np.int64(48), None)
#     >>> Sub0 [LindbladErrorgen]: 12 params, indices=slice(np.int64(36), np.int64(48), None)
# >>> Gypi2:0 [ComposedOp]: 12 params, indices=slice(np.int64(48), np.int64(60), None)
#   >>> Sub0 [StaticUnitaryOp]: 0 params, indices=slice(0, 0, None)
#   >>> Sub1 [ExpErrorgenOp]: 12 params, indices=slice(np.int64(48), np.int64(60), None)
#     >>> Sub0 [LindbladErrorgen]: 12 params, indices=slice(np.int64(48), np.int64(60), None)
# >>> Iz:0 [Instrument]: 36 params, indices=slice(np.int64(60), np.int64(96), None)
#   >>> Sub0 [ComposedOp]: 24 params, indices=slice(np.int64(60), np.int64(84), None)
#     >>> Sub0 [RootConjOperator]: 12 params, indices=slice(np.int64(60), np.int64(72), None)
#       >>> Sub0 [ComposedPOVMEffect]: 12 params, indices=slice(np.int64(60), np.int64(72), None)
#         >>> Sub0 [ExpErrorgenOp]: 12 params, indices=slice(np.int64(60), np.int64(72), None)
#           >>> Sub0 [LindbladErrorgen]: 12 params, indices=slice(np.int64(60), np.int64(72), None)
#         >>> Sub1 [StaticPOVMEffect]: 0 params, indices=slice(0, 0, None)
#           >>> Sub0 [StaticState]: 0 params, indices=slice(0, 0, None)
#     >>> Sub1 [ComposedOp]: 12 params, indices=slice(np.int64(72), np.int64(84), None)
#       >>> Sub0 [StaticUnitaryOp]: 0 params, indices=slice(0, 0, None)
#       >>> Sub1 [ExpErrorgenOp]: 12 params, indices=slice(np.int64(72), np.int64(84), None)
#         >>> Sub0 [LindbladErrorgen]: 12 params, indices=slice(np.int64(72), np.int64(84), None)
#   >>> Sub1 [ComposedOp]: 24 params, indices=[60 61 62 63 64 65 66 67 68 69 70 71 84 85 86 87 88 89 90 91 92 93 94 95]
#     >>> Sub0 [RootConjOperator]: 12 params, indices=[60 61 62 63 64 65 66 67 68 69 70 71]
#       >>> Sub0 [ComposedPOVMEffect]: 12 params, indices=[60 61 62 63 64 65 66 67 68 69 70 71]
#         >>> Sub0 [ExpErrorgenOp]: 12 params, indices=[60 61 62 63 64 65 66 67 68 69 70 71]
#           >>> Sub0 [LindbladErrorgen]: 12 params, indices=[60 61 62 63 64 65 66 67 68 69 70 71]
#         >>> Sub1 [StaticPOVMEffect]: 0 params, indices=slice(0, 0, None)
#           >>> Sub0 [StaticState]: 0 params, indices=slice(0, 0, None)
#     >>> Sub1 [ComposedOp]: 12 params, indices=[84 85 86 87 88 89 90 91 92 93 94 95]
#       >>> Sub0 [StaticUnitaryOp]: 0 params, indices=slice(0, 0, None)
#       >>> Sub1 [ExpErrorgenOp]: 12 params, indices=[84 85 86 87 88 89 90 91 92 93 94 95]
#         >>> Sub0 [LindbladErrorgen]: 12 params, indices=[84 85 86 87 88 89 90 91 92 93 94 95]
# ----------------------------------------
# Mode:  H+S+d
# ----------------------------------------
# Iz:0  --  21 parameters
# PRINTING MODEL GPINDICES!!!
# >>> rho0 [ComposedState]: 7 params, indices=slice(np.int64(0), np.int64(7), None)
#   >>> Sub0 [ExpErrorgenOp]: 7 params, indices=slice(np.int64(0), np.int64(7), None)
#     >>> Sub0 [LindbladErrorgen]: 7 params, indices=slice(np.int64(0), np.int64(7), None)
#   >>> Sub1 [StaticPureState]: 0 params, indices=slice(0, 0, None)
# >>> Mdefault [ComposedPOVM]: 7 params, indices=slice(np.int64(7), np.int64(14), None)
#   >>> Sub0 [ExpErrorgenOp]: 7 params, indices=slice(np.int64(7), np.int64(14), None)
#     >>> Sub0 [LindbladErrorgen]: 7 params, indices=slice(np.int64(7), np.int64(14), None)
#   >>> Sub1 [UnconstrainedPOVM]: 0 params, indices=slice(0, 0, None)
#     >>> Sub0 [StaticPOVMEffect]: 0 params, indices=slice(0, 0, None)
#       >>> Sub0 [StaticState]: 0 params, indices=slice(0, 0, None)
#     >>> Sub1 [StaticPOVMEffect]: 0 params, indices=slice(0, 0, None)
#       >>> Sub0 [StaticState]: 0 params, indices=slice(0, 0, None)
# >>> [] [ComposedOp]: 7 params, indices=slice(np.int64(14), np.int64(21), None)
#   >>> Sub0 [StaticUnitaryOp]: 0 params, indices=slice(0, 0, None)
#   >>> Sub1 [ExpErrorgenOp]: 7 params, indices=slice(np.int64(14), np.int64(21), None)
#     >>> Sub0 [LindbladErrorgen]: 7 params, indices=slice(np.int64(14), np.int64(21), None)
# >>> Gxpi2:0 [ComposedOp]: 7 params, indices=slice(np.int64(21), np.int64(28), None)
#   >>> Sub0 [StaticUnitaryOp]: 0 params, indices=slice(0, 0, None)
#   >>> Sub1 [ExpErrorgenOp]: 7 params, indices=slice(np.int64(21), np.int64(28), None)
#     >>> Sub0 [LindbladErrorgen]: 7 params, indices=slice(np.int64(21), np.int64(28), None)
# >>> Gypi2:0 [ComposedOp]: 7 params, indices=slice(np.int64(28), np.int64(35), None)
#   >>> Sub0 [StaticUnitaryOp]: 0 params, indices=slice(0, 0, None)
#   >>> Sub1 [ExpErrorgenOp]: 7 params, indices=slice(np.int64(28), np.int64(35), None)
#     >>> Sub0 [LindbladErrorgen]: 7 params, indices=slice(np.int64(28), np.int64(35), None)
# >>> Iz:0 [Instrument]: 21 params, indices=slice(np.int64(35), np.int64(56), None)
#   >>> Sub0 [ComposedOp]: 14 params, indices=slice(np.int64(35), np.int64(49), None)
#     >>> Sub0 [RootConjOperator]: 7 params, indices=slice(np.int64(35), np.int64(42), None)
#       >>> Sub0 [ComposedPOVMEffect]: 7 params, indices=slice(np.int64(35), np.int64(42), None)
#         >>> Sub0 [ExpErrorgenOp]: 7 params, indices=slice(np.int64(35), np.int64(42), None)
#           >>> Sub0 [LindbladErrorgen]: 7 params, indices=slice(np.int64(35), np.int64(42), None)
#         >>> Sub1 [StaticPOVMEffect]: 0 params, indices=slice(0, 0, None)
#           >>> Sub0 [StaticState]: 0 params, indices=slice(0, 0, None)
#     >>> Sub1 [ComposedOp]: 7 params, indices=slice(np.int64(42), np.int64(49), None)
#       >>> Sub0 [StaticUnitaryOp]: 0 params, indices=slice(0, 0, None)
#       >>> Sub1 [ExpErrorgenOp]: 7 params, indices=slice(np.int64(42), np.int64(49), None)
#         >>> Sub0 [LindbladErrorgen]: 7 params, indices=slice(np.int64(42), np.int64(49), None)
#   >>> Sub1 [ComposedOp]: 14 params, indices=[35 36 37 38 39 40 41 49 50 51 52 53 54 55]
#     >>> Sub0 [RootConjOperator]: 7 params, indices=[35 36 37 38 39 40 41]
#       >>> Sub0 [ComposedPOVMEffect]: 7 params, indices=[35 36 37 38 39 40 41]
#         >>> Sub0 [ExpErrorgenOp]: 7 params, indices=[35 36 37 38 39 40 41]
#           >>> Sub0 [LindbladErrorgen]: 7 params, indices=[35 36 37 38 39 40 41]
#         >>> Sub1 [StaticPOVMEffect]: 0 params, indices=slice(0, 0, None)
#           >>> Sub0 [StaticState]: 0 params, indices=slice(0, 0, None)
#     >>> Sub1 [ComposedOp]: 7 params, indices=[49 50 51 52 53 54 55]
#       >>> Sub0 [StaticUnitaryOp]: 0 params, indices=slice(0, 0, None)
#       >>> Sub1 [ExpErrorgenOp]: 7 params, indices=[49 50 51 52 53 54 55]
#         >>> Sub0 [LindbladErrorgen]: 7 params, indices=[49 50 51 52 53 54 55]
