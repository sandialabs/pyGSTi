# %% [markdown]
# # Parallel GST using MPI
# The purpose of this tutorial is to demonstrate how to compute GST estimates in parallel (using multiple CPUs or "processors").  The core PyGSTi computational routines are written to take advantage of multiple processors via the MPI communication framework, and so one must have a version of MPI and the `mpi4py` python package installed in order use run pyGSTi calculations in parallel.
#
# Since `mpi4py` doesn't play nicely with Jupyter notebooks, this tutorial is a bit more clunky than the others.  In it, we will create a standalone Python script that imports `mpi4py` and execute it.
#
# We will use as an example the same "standard" single-qubit model of the first tutorial.  We'll first create a dataset, and then a script to be run in parallel which loads the data.  The creation of a simulated data is performed in the same way as the first tutorial.   Since *random* numbers are generated and used as simulated counts within the call to `generate_fake_data`, it is important that this is *not* done in a parallel environment, or different CPUs may get different data sets.  (This isn't an issue in the typical situation when the data is obtained experimentally.)

# %%
#Import pyGSTi and the "stardard 1-qubit quantities for a model with X(pi/2), Y(pi/2), and idle gates"
import pygsti
from pygsti.construction import std1Q_XYI

#Create a data set
target_model = std1Q_XYI.target_model
fiducials = std1Q_XYI.fiducials
germs = std1Q_XYI.germs
maxLengths = [1,2,4,8,16,32]

mdl_datagen = target_model.depolarize(op_noise=0.1, spam_noise=0.001)
listOfExperiments = pygsti.construction.make_lsgst_experiment_list(target_model.operations.keys(), fiducials, fiducials, germs, maxLengths)
ds = pygsti.construction.generate_fake_data(mdl_datagen, listOfExperiments, nSamples=1000,
                                            sampleError="binomial", seed=1234)
pygsti.io.write_dataset("example_files/mpi_example_dataset.txt", ds)

# %% [markdown]
# Next, we'll write a Python script that will load in the just-created `DataSet`, run GST on it, and write the output to a file.  The only major difference between the contents of this script and previous examples is that the script imports `mpi4py` and passes a MPI comm object (`comm`) to the `do_long_sequence_gst` function.  Since parallel computing is best used for computationaly intensive GST calculations, we also demonstrate how to set a per-processor memory limit to tell pyGSTi to partition its computations so as to not exceed this memory usage.  Lastly, note the use of the `gaugeOptParams` argument of `do_long_sequence_gst`, which can be used to weight different model members differently during gauge optimization.

# %%
mpiScript = """
import time
import pygsti
from pygsti.construction import std1Q_XYI

#get MPI comm
from mpi4py import MPI
comm = MPI.COMM_WORLD

print("Rank %d started" % comm.Get_rank())

#define target model, fiducials, and germs as before
target_model = std1Q_XYI.target_model
fiducials = std1Q_XYI.fiducials
germs = std1Q_XYI.germs
maxLengths = [1,2,4,8,16,32]

#tell gauge optimization to weight the operation matrix
# elements 100x more heavily than the SPAM vector elements, and
# to specifically weight the Gx gate twice as heavily as the other
# gates.
goParams = {'itemWeights':{'spam': 0.01, 'gates': 1.0, 'Gx': 2.0} }

#Specify a per-core memory limit (useful for larger GST calculations)
memLim = 2.1*(1024)**3  # 2.1 GB

#Perform TP-constrained GST
target_model.set_all_parameterizations("TP")
    
#load the dataset
ds = pygsti.io.load_dataset("example_files/mpi_example_dataset.txt")

start = time.time()
results = pygsti.do_long_sequence_gst(ds, target_model, fiducials, fiducials,
                                      germs, maxLengths,memLimit=memLim,
                                      gaugeOptParams=goParams, comm=comm,
                                      verbosity=2)
end = time.time()
print("Rank %d finished in %.1fs" % (comm.Get_rank(), end-start))
if comm.Get_rank() == 0:
    import pickle
    pickle.dump(results, open("example_files/mpi_example_results.pkl","wb"))
"""
with open("example_files/mpi_example_script.py","w") as f:
    f.write(mpiScript)

# %% [markdown]
# Next, we run the script with 3 processors using `mpiexec`.  The `mpiexec` executable should have been installed with your MPI distribution -- if it doesn't exist, try replacing `mpiexec` with `mpirun`.

# %%
! mpiexec -n 3 python3 "example_files/mpi_example_script.py"
# Out:
# Rank 0 started
# Rank 1 started
# Rank 2 started
# --- Circuit Creation ---
#    1702 sequences created
#    Dataset has 1702 entries: 1702 utilized, 0 requested sequences were missing
# --- LGST ---
#   Singular values of I_tilde (truncating to first 4 of 6) =
#   4.244089943192679
#   1.1594632778409208
#   0.9651516670737965
#   0.9297628363691268
#   0.049256811347238104
#   0.025150658372136828
#
#   Singular values of target I_tilde (truncating to first 4 of 6) =
#   4.242640687119286
#   1.414213562373096
#   1.4142135623730956
#   1.4142135623730954
#   2.5038933168948026e-16
#   2.023452063009528e-16
#
# --- Iterative MLGST: Iter 1 of 6  92 operation sequences ---:
#   --- Minimum Chi^2 GST ---
#   Memory limit = 2.10GB
#   Cur, Persist, Gather = 0.13, 0.00, 0.21 GB
#   Finding num_nongauge_params is too expensive: using total params.
#   Sum of Chi^2 = 95.7297 (91 data params - 43 model params = expected mean of 48; p-value = 5.13941e-05)
#   Completed in 0.2s
#   2*Delta(log(L)) = 96.1163
#   Iteration 1 took 0.2s
#
# --- Iterative MLGST: Iter 2 of 6  168 operation sequences ---:
#   --- Minimum Chi^2 GST ---
#   Memory limit = 2.10GB
#   Cur, Persist, Gather = 0.13, 0.00, 0.21 GB
#   Finding num_nongauge_params is too expensive: using total params.
#   Sum of Chi^2 = 162.192 (167 data params - 43 model params = expected mean of 124; p-value = 0.0120809)
#   Completed in 0.2s
#   2*Delta(log(L)) = 162.56
#   Iteration 2 took 0.2s
#
# --- Iterative MLGST: Iter 3 of 6  450 operation sequences ---:
#   --- Minimum Chi^2 GST ---
#   Memory limit = 2.10GB
#   Cur, Persist, Gather = 0.13, 0.00, 0.21 GB
#   Finding num_nongauge_params is too expensive: using total params.
#   Sum of Chi^2 = 484.676 (449 data params - 43 model params = expected mean of 406; p-value = 0.00435191)
#   Completed in 0.3s
#   2*Delta(log(L)) = 485.572
#   Iteration 3 took 0.3s
#
# --- Iterative MLGST: Iter 4 of 6  862 operation sequences ---:
#   --- Minimum Chi^2 GST ---
#   Memory limit = 2.10GB
#   Cur, Persist, Gather = 0.14, 0.00, 0.21 GB
#   Finding num_nongauge_params is too expensive: using total params.
#   Sum of Chi^2 = 895.303 (861 data params - 43 model params = expected mean of 818; p-value = 0.0307097)
#   Completed in 0.6s
#   2*Delta(log(L)) = 896.23
#   Iteration 4 took 0.6s
#
# --- Iterative MLGST: Iter 5 of 6  1282 operation sequences ---:
#   --- Minimum Chi^2 GST ---
#   Memory limit = 2.10GB
#   Cur, Persist, Gather = 0.14, 0.00, 0.21 GB
#   Finding num_nongauge_params is too expensive: using total params.
#   Sum of Chi^2 = 1350.86 (1281 data params - 43 model params = expected mean of 1238; p-value = 0.0133489)
#   Completed in 0.9s
#   2*Delta(log(L)) = 1351.9
#   Iteration 5 took 0.9s
#
# --- Iterative MLGST: Iter 6 of 6  1702 operation sequences ---:
#   --- Minimum Chi^2 GST ---
#   Memory limit = 2.10GB
#   Cur, Persist, Gather = 0.15, 0.00, 0.21 GB
#   Finding num_nongauge_params is too expensive: using total params.
#   Sum of Chi^2 = 1800.55 (1701 data params - 43 model params = expected mean of 1658; p-value = 0.00777432)
#   Completed in 1.3s
#   2*Delta(log(L)) = 1801.81
#   Iteration 6 took 1.4s
#
#   Switching to ML objective (last iteration)
#   --- MLGST ---
#   Memory: limit = 2.10GB(cur, persist, gthr = 0.15, 0.00, 0.21 GB)
#   Finding num_nongauge_params is too expensive: using total params.
#     Maximum log(L) = 900.852 below upper bound of -2.84686e+06
#       2*Delta(log(L)) = 1801.7 (1701 data params - 43 model params = expected mean of 1658; p-value = 0.00737681)
#     Completed in 0.5s
#   2*Delta(log(L)) = 1801.7
#   Final MLGST took 0.5s
#
# Iterative MLGST Total Time: 4.0s
#   -- Adding Gauge Optimized (go0) --
# --- Re-optimizing logl after robust data scaling ---
#   --- MLGST ---
#   Memory: limit = 2.10GB(cur, persist, gthr = 0.15, 0.00, 0.21 GB)
#   Finding num_nongauge_params is too expensive: using total params.
#     Maximum log(L) = 900.852 below upper bound of -2.84686e+06
#       2*Delta(log(L)) = 1801.7 (1701 data params - 43 model params = expected mean of 1658; p-value = 0.00737681)
#     Completed in 0.3s
#   -- Adding Gauge Optimized (go0) --
# Rank 0 finished in 5.5s
# Rank 2 finished in 5.6s
# Rank 1 finished in 5.5s

# %% [markdown]
# Notice in the above that output within `do_long_sequence_gst` is not duplicated (only the first processor outputs to stdout) so that the output looks identical to running on a single processor.  Finally, we just need to read the pickled `Results` object from file and proceed with any post-processing analysis.  In this case, we'll just create a  report.

# %%
import pickle
results = pickle.load(open("example_files/mpi_example_results.pkl","rb"))
pygsti.report.create_standard_report(results, "example_files/mpi_example_brief",
                                    title="MPI Example Report", verbosity=2, auto_open=True)
# Out:
# *** Creating workspace ***
# *** Generating switchboard ***
# Found standard clifford compilation from std1Q_XYI
# *** Generating tables ***
#   targetSpamBriefTable                          took 0.298994 seconds
#   targetGatesBoxTable                           took 0.107017 seconds
#   datasetOverviewTable                          took 0.07309 seconds
#   bestGatesetSpamParametersTable                took 0.000446 seconds
#   bestGatesetSpamBriefTable                     took 0.129496 seconds
#   bestGatesetSpamVsTargetTable                  took 0.124513 seconds
#   bestGatesetGaugeOptParamsTable                took 0.000342 seconds
#   bestGatesetGatesBoxTable                      took 0.112081 seconds
#   bestGatesetChoiEvalTable                      took 0.246212 seconds
#   bestGatesetDecompTable                        took 0.129572 seconds
#   bestGatesetEvalTable                          took 0.002308 seconds
#   bestGermsEvalTable                            took 0.014575 seconds
#   bestGatesetVsTargetTable                      took 0.047486 seconds
#   bestGatesVsTargetTable_gv                     took 0.162747 seconds
#   bestGatesVsTargetTable_gvgerms                took 0.070623 seconds
#   bestGatesVsTargetTable_gi                     took 0.011195 seconds
#   bestGatesVsTargetTable_gigerms                took 0.020324 seconds
#   bestGatesVsTargetTable_sum                    took 0.216664 seconds
#   bestGatesetErrGenBoxTable                     took 0.439404 seconds
#   metadataTable                                 took 0.059773 seconds
#   stdoutBlock                                   took 0.000702 seconds
#   profilerTable                                 took 0.000593 seconds
#   softwareEnvTable                              took 0.025881 seconds
#   exampleTable                                  took 0.1532 seconds
#   singleMetricTable_gv                          took 0.149808 seconds
#   singleMetricTable_gi                          took 0.010911 seconds
#   fiducialListTable                             took 0.000738 seconds
#   prepStrListTable                              took 0.000182 seconds
#   effectStrListTable                            took 0.000174 seconds
#   colorBoxPlotKeyPlot                           took 0.04576 seconds
#   germList2ColTable                             took 0.000207 seconds
#   progressTable                                 took 2.897452 seconds
# *** Generating plots ***
#   gramBarPlot                                   took 0.059668 seconds
#   progressBarPlot                               took 0.039053 seconds
#   progressBarPlot_sum                           took 0.000355 seconds
#   finalFitComparePlot                           took 0.03586 seconds
#   bestEstimateColorBoxPlot                      took 11.008662 seconds
#   bestEstimateTVDColorBoxPlot                   took 10.664428 seconds
#   bestEstimateColorScatterPlot                  took 12.368831 seconds
#   bestEstimateColorHistogram                    took 10.597549 seconds
#   progressTable_scl                             took 2.843667 seconds
#   progressBarPlot_scl                           took 0.038798 seconds
#   bestEstimateColorBoxPlot_scl                  took 11.120606 seconds
#   bestEstimateColorScatterPlot_scl              took 12.226489 seconds
#   bestEstimateColorHistogram_scl                took 10.534059 seconds
#   dataScalingColorBoxPlot                       took 0.289186 seconds
# *** Merging into template file ***
#   Rendering topSwitchboard                      took 0.000144 seconds
#   Rendering maxLSwitchboard1                    took 8.2e-05 seconds
#   Rendering targetSpamBriefTable                took 0.078879 seconds
#   Rendering targetGatesBoxTable                 took 0.071165 seconds
#   Rendering datasetOverviewTable                took 0.001186 seconds
#   Rendering bestGatesetSpamParametersTable      took 0.001308 seconds
#   Rendering bestGatesetSpamBriefTable           took 0.144004 seconds
#   Rendering bestGatesetSpamVsTargetTable        took 0.001561 seconds
#   Rendering bestGatesetGaugeOptParamsTable      took 0.000617 seconds
#   Rendering bestGatesetGatesBoxTable            took 0.111732 seconds
#   Rendering bestGatesetChoiEvalTable            took 0.105934 seconds
#   Rendering bestGatesetDecompTable              took 0.069082 seconds
#   Rendering bestGatesetEvalTable                took 0.012667 seconds
#   Rendering bestGermsEvalTable                  took 0.042262 seconds
#   Rendering bestGatesetVsTargetTable            took 0.001101 seconds
#   Rendering bestGatesVsTargetTable_gv           took 0.00373 seconds
#   Rendering bestGatesVsTargetTable_gvgerms      took 0.007046 seconds
#   Rendering bestGatesVsTargetTable_gi           took 0.002492 seconds
#   Rendering bestGatesVsTargetTable_gigerms      took 0.002687 seconds
#   Rendering bestGatesVsTargetTable_sum          took 0.003104 seconds
#   Rendering bestGatesetErrGenBoxTable           took 0.239157 seconds
#   Rendering metadataTable                       took 0.002576 seconds
#   Rendering stdoutBlock                         took 0.001016 seconds
#   Rendering profilerTable                       took 0.001852 seconds
#   Rendering softwareEnvTable                    took 0.002576 seconds
#   Rendering exampleTable                        took 0.022976 seconds
#   Rendering metricSwitchboard_gv                took 4.9e-05 seconds
#   Rendering metricSwitchboard_gi                took 3.7e-05 seconds
#   Rendering singleMetricTable_gv                took 0.005824 seconds
#   Rendering singleMetricTable_gi                took 0.003991 seconds
#   Rendering fiducialListTable                   took 0.002527 seconds
#   Rendering prepStrListTable                    took 0.002202 seconds
#   Rendering effectStrListTable                  took 0.002434 seconds
#   Rendering colorBoxPlotKeyPlot                 took 0.025765 seconds
#   Rendering germList2ColTable                   took 0.004365 seconds
#   Rendering progressTable                       took 0.004619 seconds
#   Rendering gramBarPlot                         took 0.190225 seconds
#   Rendering progressBarPlot                     took 0.018523 seconds
#   Rendering progressBarPlot_sum                 took 0.021915 seconds
#   Rendering finalFitComparePlot                 took 0.016494 seconds
#   Rendering bestEstimateColorBoxPlot            took 0.176641 seconds
#   Rendering bestEstimateTVDColorBoxPlot         took 0.172611 seconds
#   Rendering bestEstimateColorScatterPlot        took 0.309277 seconds
#   Rendering bestEstimateColorHistogram          took 0.183992 seconds
#   Rendering progressTable_scl                   took 0.00489 seconds
#   Rendering progressBarPlot_scl                 took 0.018803 seconds
#   Rendering bestEstimateColorBoxPlot_scl        took 0.175936 seconds
#   Rendering bestEstimateColorScatterPlot_scl    took 0.319054 seconds
#   Rendering bestEstimateColorHistogram_scl      took 0.196185 seconds
#   Rendering dataScalingColorBoxPlot             took 0.044174 seconds
# Output written to example_files/mpi_example_brief directory
# Opening example_files/mpi_example_brief/main.html...
# *** Report Generation Complete!  Total time 90.7789s ***
