# %% [markdown]
# # Parity benchmarking
# This notebook demonstrates how to compute the "weight-X disturbance" error metric between a *reference* and *test* data set using pyGSTi to benchmark a 4-qubit parity check.

# %%
import numpy as np
import scipy as sp
import itertools
from matplotlib import pyplot as plt
import seaborn as sns
import time
import cvxpy
sns.set_style('white')
# %matplotlib inline

import pygsti.extras.paritybenchmarking as pb
#Note: if you don't want to install pyGSTi to run this notebook,
# just grab the pygsti/extras/paritybenchmarking/disturbancecalc.py file, put it
# in the same directory as this notebook, and use this line instead of the one above:
# import disturbancecalc as pb

installed_solvers = cvxpy.installed_solvers()
SOLVER = 'MOSEK' # prefer MOSEK (commercial solver, free for research) if available.
if SOLVER not in installed_solvers:
    SOLVER = 'CLARABEL'  # fallback

# %% [markdown]
# ## Setup
# Here's some setup so we can easily work with probability distributions as arrays of probabilities, indexed by bitstring.

# %%
n_bits = 4
n_data_points = 10000

class ProbabilityDistribution(np.ndarray):
    @classmethod
    def from_array(cls, ar):
        ret = cls(int(round(np.log2(len(ar)))))
        ret[:] = ar[:]
        return ret

    def __new__(cls, n_bits):
        self = super().__new__(cls, (2**n_bits,), float, np.zeros(2**n_bits, 'd'))
        self.n_bits = n_bits
        self.bs = ["".join(x) for x in itertools.product(*([('0', '1')] * n_bits))]
        self.bi = {s: i for i,s in enumerate(self.bs)}
        return self
  
    def __getitem__(self, key):
        if isinstance(key, str):
            return super().__getitem__(self.bi[key])
        else:
            return super().__getitem__(key)
    
    def __setitem__(self, key, val):
        if isinstance(key, str):
            return super().__setitem__(self.bi[key], val)
        else:
            return super().__setitem__(key, val)
        
    def display(self, my_name='', other_distributions=None):
        if other_distributions is None: other_distributions = {}
        other_names = list(other_distributions.keys())
        print('     ', ', '.join([my_name] + other_names))
        print('\n'.join(["%s: %s" % (s, '  '.join([('%.3f' % x) for x in [v] + [other_distributions[nm][s] for nm in other_names]]))
                         for s,v in zip(self.bs, self)]))
    
    def __str__(self):
        return '\n'.join(["%s: %g" % (s, v) for s,v in zip(self.bs, self)]) + '\n'
    
    def __array_finalize__(self, obj):  # needed for creating new array instances
        if obj is None: return
        self.n_bits = getattr(obj, 'n_bits', None)
        self.bi = getattr(obj, 'bi', None)
        self.bs = getattr(obj, 'bs', None)
        
    def copy(self):
        ret = ProbabilityDistribution(self.n_bits)
        ret[:] = self[:]
        return ret

# %% [markdown]
# ## The main demo: a simple example
# Let's start with an example problem, computing the weight-1 to weight-4 disturbances based on some data.  This demonstrates the main interface to using the `disturbancecalc.py` code: the `compute_disturbances` function.

# %%
# Define the ideal distribution
p_ideal = ProbabilityDistribution(n_bits)
p_ideal['0000'] = .5
p_ideal['1111'] = .5


# Define the "reference" distribution.  In this case, we just set it equal to the ideal distribution
p_ref = p_ideal.copy()

# Define several elementary errors that can happen to a single bit:
ident1bit = np.identity(2)  # do nothing to a single bit
flip1bit = np.array([[0, 1],[1, 0]])  # flip a single bit
set1bit = np.array([[0, 0], [1, 1]])  # set a single bit (to 1)
reset1bit = np.array([[1, 1], [0, 0]])  # reset a single bit (to 0)

# Define, for example, and for use later on, several 4-bit errors.
def kron4(a, b, c, d):
    return np.kron(a, np.kron(b, np.kron(c, d)))
ident4bit = np.identity(16)
flip4bit = kron4(flip1bit, flip1bit, flip1bit, flip1bit)
fliplastbit = kron4(ident1bit, ident1bit, ident1bit, flip1bit)
setlastbit = np.kron(ident1bit, np.kron(ident1bit, np.kron(ident1bit, reset1bit)))
set4bit = kron4(set1bit, set1bit, set1bit, set1bit)

# Construct, for our example, a particular stochastic map that represents
# the "error" or "noise" that occurs during the parity check experiment.
parity_check_noise = 0.90 * ident4bit + 0.05 * set4bit + 0.05 * fliplastbit
#parity_check_noise = 0.90 * ident4bit + 0.1 * fliplastbit  # another possibility

# The "test" distribution is thus defined by applying the above map to p_ref:
p_test = ProbabilityDistribution.from_array(np.dot(parity_check_noise, p_ref))

# We can now simulate data corresponding to these probability distributions.
# Here we don't include proper finite sample error for simplicity, we just
# round to the nearest integer:
data_ref = np.array( p_ref * n_data_points, dtype='int')  # no finite sample error
data_test = np.array(p_test * n_data_points, dtype='int')  # no finite sample error

# This is what you would do to simulate finite sampling error:
# data_ref = np.random.multinomial(n_data_points, p_ref)
# data_test = np.random.multinomial(n_data_points, p_test)

# Before computing the disturbances, let's take a look at the probability distributions:
p_ideal.display('ideal', {'ref': p_ref, 'test': p_test})
# Out:
#       ideal, ref, test
# 0000: 0.500  0.500  0.450
# 0001: 0.000  0.000  0.025
# 0010: 0.000  0.000  0.000
# 0011: 0.000  0.000  0.000
# 0100: 0.000  0.000  0.000
# 0101: 0.000  0.000  0.000
# 0110: 0.000  0.000  0.000
# 0111: 0.000  0.000  0.000
# 1000: 0.000  0.000  0.000
# 1001: 0.000  0.000  0.000
# 1010: 0.000  0.000  0.000
# 1011: 0.000  0.000  0.000
# 1100: 0.000  0.000  0.000
# 1101: 0.000  0.000  0.000
# 1110: 0.000  0.000  0.025
# 1111: 0.500  0.500  0.500

# %%
# The actual disturbance computation
disturbances = pb.compute_disturbances(n_bits, data_ref, data_test, solver=SOLVER)
# Out:
# Computing base disturbances
# Analyzing bootstrap sample 1 of 20... (1.2s)
# Analyzing bootstrap sample 2 of 20... (0.8s)
# Analyzing bootstrap sample 3 of 20... (0.8s)
# Analyzing bootstrap sample 4 of 20... (0.5s)
# Analyzing bootstrap sample 5 of 20... (0.9s)
# Analyzing bootstrap sample 6 of 20... (1.0s)
# Analyzing bootstrap sample 7 of 20... (0.8s)
# Analyzing bootstrap sample 8 of 20... (0.7s)
# Analyzing bootstrap sample 9 of 20... (1.4s)
# Analyzing bootstrap sample 10 of 20... (1.0s)
# Analyzing bootstrap sample 11 of 20... (1.1s)
# Analyzing bootstrap sample 12 of 20... (0.9s)
# Analyzing bootstrap sample 13 of 20... (0.6s)
# Analyzing bootstrap sample 14 of 20... (0.5s)
# Analyzing bootstrap sample 15 of 20... (0.6s)
# Analyzing bootstrap sample 16 of 20... (0.4s)
# Analyzing bootstrap sample 17 of 20... (1.3s)
# Analyzing bootstrap sample 18 of 20... (0.7s)
# Analyzing bootstrap sample 19 of 20... (0.8s)
# Analyzing bootstrap sample 20 of 20... (0.8s)

# %%
# This shows how the returned `disturbances` list is interpreted (see the dostring too)
for i,d in enumerate(disturbances):
    print("Weight-%d disturbance = %g +/- %g" % (i+1,d[0],d[1]))
# Out:
# Weight-1 disturbance = 0.025 +/- 0.00465097
# Weight-2 disturbance = 4.36618e-10 +/- 0.000396265
# Weight-3 disturbance = 0.025 +/- 0.0047363
# Weight-4 disturbance = 5.84577e-11 +/- 0.00454531

# %% [markdown]
# **That's all there is to computing the disturbance metrics!**  From this point on, this notebook demonstrates the more recent OVD-based corrections to the disturbances and then shows some of the other things the QPL has done to test and verify that the disturbance metrics are computed correctly and behave as they're supposed to.
#
# -----------------
#
# ## OVD-corrected disturbances
# To make the disturbance metrics more robust to SPAM noise, you can apply a scaling factor that is the ratio of the original variation distance (OVD) to the usual total variational distance (TVD) between the reference and test distributions.  The ratio can be computed independently, or, for convenience, methods exist which perform the scaling internally.  Both are demonstrated below.

# %%
# Consider an example where the parity check circuit produces the same error
# (`parity_check_noise` from above) but with SPAM noise, so that p_ref is no longer perfect.

# We construct SPAM noise that is the tensor produce to a low-probability bit flip on the final qubit:
lowprobflip1bit = 0.95 * ident1bit + 0.05 * flip1bit
spam_noise = kron4(ident1bit, ident1bit, ident1bit, lowprobflip1bit)
            
# The "reference" distribution is then defined by applying the above map to p_ideal:
p_ref = ProbabilityDistribution.from_array(np.dot(spam_noise, p_ideal))

# And the "test" distribution is defined by applying the same parity_check_noise from before to p_ref:
p_test = ProbabilityDistribution.from_array(np.dot(parity_check_noise, p_ref))

#We can then simulate data and view these distributions like we did before:
data_ref = np.array( p_ref * n_data_points, dtype='int')  # no finite sample error
data_test = np.array(p_test * n_data_points, dtype='int')  # no finite sample error

# This is what you would do to simulate finite sampling error:
# data_ref = np.random.multinomial(n_data_points, p_ref)
# data_test = np.random.multinomial(n_data_points, p_test)

p_ideal.display('ideal', {'ref': p_ref, 'test': p_test})
# Out:
#       ideal, ref, test
# 0000: 0.500  0.475  0.429
# 0001: 0.000  0.025  0.046
# 0010: 0.000  0.000  0.000
# 0011: 0.000  0.000  0.000
# 0100: 0.000  0.000  0.000
# 0101: 0.000  0.000  0.000
# 0110: 0.000  0.000  0.000
# 0111: 0.000  0.000  0.000
# 1000: 0.000  0.000  0.000
# 1001: 0.000  0.000  0.000
# 1010: 0.000  0.000  0.000
# 1011: 0.000  0.000  0.000
# 1100: 0.000  0.000  0.000
# 1101: 0.000  0.000  0.000
# 1110: 0.000  0.025  0.046
# 1111: 0.500  0.475  0.479

# %%
# We next go on to compute the OVD/TVD ratio, the usual TVD-based disturbances, and the OVD-corrected disturbances.
r = ovd_over_tvd = pb.compute_ovd_over_tvd_ratio(n_bits, data_ref, data_test, p_ideal)
print("OVD/TVD ratio = ",r)
# Out:
# OVD/TVD ratio =  1.0526315789473677

# %%
# Usual TVD-based disturbances
disturbances = pb.compute_disturbances(n_bits, data_ref, data_test, solver=SOLVER)
# Out:
# Computing base disturbances
# Analyzing bootstrap sample 1 of 20... (0.9s)
# Analyzing bootstrap sample 2 of 20... (1.5s)
# Analyzing bootstrap sample 3 of 20... (1.0s)
# Analyzing bootstrap sample 4 of 20... (0.8s)
# Analyzing bootstrap sample 5 of 20... (0.8s)
# Analyzing bootstrap sample 6 of 20... (0.9s)
# Analyzing bootstrap sample 7 of 20... (0.8s)
# Analyzing bootstrap sample 8 of 20... (1.0s)
# Analyzing bootstrap sample 9 of 20... (1.5s)
# Analyzing bootstrap sample 10 of 20... (1.1s)
# Analyzing bootstrap sample 11 of 20... (1.1s)
# Analyzing bootstrap sample 12 of 20... (0.9s)
# Analyzing bootstrap sample 13 of 20... (1.2s)
# Analyzing bootstrap sample 14 of 20... (1.0s)
# Analyzing bootstrap sample 15 of 20... (1.0s)
# Analyzing bootstrap sample 16 of 20... (1.8s)
# Analyzing bootstrap sample 17 of 20... (1.1s)
# Analyzing bootstrap sample 18 of 20... (1.3s)
# Analyzing bootstrap sample 19 of 20... (1.1s)
# Analyzing bootstrap sample 20 of 20... (1.3s)

# %%
# This shows how the returned `disturbances` list is interpreted (see the dostring too)
for i,d in enumerate(disturbances):
    print("Weight-%d disturbance = %g +/- %g" % (i+1,d[0],d[1]))
# Out:
# Weight-1 disturbance = 0.0212092 +/- 0.00399529
# Weight-2 disturbance = -1.00287e-10 +/- 0.000443842
# Weight-3 disturbance = 0.025005 +/- 0.00703083
# Weight-4 disturbance = 5.94367e-10 +/- 0.000597759

# %%
ovd_corrected_disturbances = pb.compute_ovd_corrected_disturbances(n_bits, data_ref, data_test, p_ideal, solver=SOLVER)
# Out:
# Computing base disturbances
# Analyzing bootstrap sample 1 of 20... (1.0s)
# Analyzing bootstrap sample 2 of 20... (0.9s)
# Analyzing bootstrap sample 3 of 20... (1.3s)
# Analyzing bootstrap sample 4 of 20... (1.3s)
# Analyzing bootstrap sample 5 of 20... (1.4s)
# Analyzing bootstrap sample 6 of 20... (0.9s)
# Analyzing bootstrap sample 7 of 20... (0.8s)
# Analyzing bootstrap sample 8 of 20... (0.7s)
# Analyzing bootstrap sample 9 of 20... (1.9s)
# Analyzing bootstrap sample 10 of 20... (1.0s)
# Analyzing bootstrap sample 11 of 20... (0.9s)
# Analyzing bootstrap sample 12 of 20... (1.2s)
# Analyzing bootstrap sample 13 of 20... (1.1s)
# Analyzing bootstrap sample 14 of 20... (1.0s)
# Analyzing bootstrap sample 15 of 20... (0.9s)
# Analyzing bootstrap sample 16 of 20... (1.7s)
# Analyzing bootstrap sample 17 of 20... (0.9s)
# Analyzing bootstrap sample 18 of 20... (1.0s)
# Analyzing bootstrap sample 19 of 20... (0.9s)
# Analyzing bootstrap sample 20 of 20... (1.0s)

# %%
# This shows how the returned `disturbances` list is interpreted (see the dostring too)
for i,d in enumerate(ovd_corrected_disturbances):
    if i < 4:
        print("Weight-%d OVD-corrected disturbance = %g +/- %g" % (i+1,d[0],d[1]))
    else:
        print("OVD/TVD ratio = %g +/- %g" % (d[0],d[1]))
# Out:
# Weight-1 OVD-corrected disturbance = 0.0223255 +/- 0.00421432
# Weight-2 OVD-corrected disturbance = -1.05565e-10 +/- 0.000464134
# Weight-3 OVD-corrected disturbance = 0.0263211 +/- 0.00722947
# Weight-4 OVD-corrected disturbance = 6.2565e-10 +/- 0.000623183
# OVD/TVD ratio = 1.05263 +/- 0.0120014

# %% [markdown]
# In the above example, we note:
#
# 1. the OVD/ratio is close to 1, and so the OVD-corrected vs uncorrected numbers are similar.  More precisely, the ratio is ~1.05, and so the corrected values are slightly larger than the uncorrected values.
#
# 2. the correction moves the disturbances closer to those the values given earlier when there was no SPAM error.
#
# -----
#
# ### One more OVD-corrected disturbance example
# It's also possible to have SPAM noise *increase* the disturbances rather than reduce them.  In the example below, which uses SPAM noise that afflicts all the qubits equally, the presence of the SPAM noise actually makes the disturbance values larger than they would be without the noise.  In this case `r` is (slightly) less than 1, and the OVD-corrected disturbances are smaller than the uncorrected ones.

# %%
#All the steps here are similar to the example above, except the SPAM noise is different
lowprobflip1bit = 0.98 * ident1bit + 0.02 * flip1bit
spam_noise = kron4(lowprobflip1bit, lowprobflip1bit, lowprobflip1bit, lowprobflip1bit)
            
p_ref = ProbabilityDistribution.from_array(np.dot(spam_noise, p_ideal))
p_test = ProbabilityDistribution.from_array(np.dot(parity_check_noise, p_ref))

data_ref = np.array( p_ref * n_data_points, dtype='int')  # no finite sample error
data_test = np.array(p_test * n_data_points, dtype='int')  # no finite sample error

p_ideal.display('ideal', {'ref': p_ref, 'test': p_test})
# Out:
#       ideal, ref, test
# 0000: 0.500  0.461  0.416
# 0001: 0.000  0.009  0.032
# 0010: 0.000  0.009  0.008
# 0011: 0.000  0.000  0.001
# 0100: 0.000  0.009  0.008
# 0101: 0.000  0.000  0.001
# 0110: 0.000  0.000  0.001
# 0111: 0.000  0.009  0.008
# 1000: 0.000  0.009  0.008
# 1001: 0.000  0.000  0.001
# 1010: 0.000  0.000  0.001
# 1011: 0.000  0.009  0.008
# 1100: 0.000  0.000  0.001
# 1101: 0.000  0.009  0.008
# 1110: 0.000  0.009  0.032
# 1111: 0.500  0.461  0.466

# %%
r = ovd_over_tvd = pb.compute_ovd_over_tvd_ratio(n_bits, data_ref, data_test, p_ideal)
print("OVD/TVD ratio = ",r)

#We don't do any bootstrap samples so the calculation is faster, but there are no error bars
disturbances = pb.compute_disturbances(n_bits, data_ref, data_test, solver=SOLVER, num_bootstrap_samples=0)
ovd_corrected_disturbances = pb.compute_ovd_corrected_disturbances(n_bits, data_ref, data_test, p_ideal, solver=SOLVER, num_bootstrap_samples=0)
print()

for i,d in enumerate(disturbances):
    print("Weight-%d disturbance = %g" % (i+1,d[0]))
    
print()
    
for i,d in enumerate(ovd_corrected_disturbances):
    if i < 4:
        print("Weight-%d OVD-corrected disturbance = %g" % (i+1,d[0]))
    else:
        print("OVD/TVD ratio = %g" % (d[0]))
# Out:
# OVD/TVD ratio =  0.9575080822905789
# Computing base disturbances
# Computing base disturbances
#
# Weight-1 disturbance = 0.025605
# Weight-2 disturbance = 0.00363512
# Weight-3 disturbance = 0.0224012
# Weight-4 disturbance = 3.26684e-10
#
# Weight-1 OVD-corrected disturbance = 0.024517
# Weight-2 OVD-corrected disturbance = 0.00348066
# Weight-3 OVD-corrected disturbance = 0.0214493
# Weight-4 OVD-corrected disturbance = 3.12802e-10
# OVD/TVD ratio = 0.957508

# %% [markdown]
# ## Testing and verification
#
# ### Test problems.
# Below we put what we did above in the "main demo" section into a function so it's easier to run, and perform a bunch of simple tests to ensure that the disturbance behavior agrees with our intuition.

# %%
def gen_data(p_test_dict, p_ref_dict = None, include_finite_sample_error=False, seed=12345):
    # Define the reference distribution - in this case, it's equal to the target distribution
    p_ref = ProbabilityDistribution(n_bits)
    for k,v in p_ref_dict.items(): p_ref[k] = v
        
    if include_finite_sample_error:
        np.random.seed(seed)
        data_ref = np.random.multinomial(n_data_points, p_ref)
    else:
        data_ref = np.array( p_ref * n_data_points, dtype='int')  # no finite sample error
   
    # Define the reference distribution - we get this by moving 
    p_test = ProbabilityDistribution(n_bits)
    for k,v in p_test_dict.items(): p_test[k] = v
        
    if include_finite_sample_error:
        data_test = np.random.multinomial(n_data_points, p_test)
    else:
        data_test = np.array( p_test * n_data_points, dtype='int')  # no finite sample error
        
    return data_ref, data_test
        

def test(p_test_dict, p_ref_dict = None, include_finite_sample_error=False, seed=12345, confidence_percent=68):
    if p_ref_dict is None:
        p_ref_dict = {'0000': 0.5, '1111': 0.5}
    
    data_ref, data_test = gen_data(p_test_dict, p_ref_dict, include_finite_sample_error, seed)
    disturbances = pb.compute_disturbances(n_bits, data_ref, data_test, verbosity=0, solver=SOLVER)
    print("TEST (finite sampling = %s)" % include_finite_sample_error)
    print("p_ref = ", p_ref_dict)
    print("p_test = ", p_test_dict)
    for i,d in enumerate(disturbances):
        if d[1] is None:
            print("Weight-%d disturbance = %g" % (i+1,d[0]))
        else:
            print("Weight-%d disturbance = %g +/- %g" % (i+1,d[0],d[1]))
    print()

# %% [markdown]
# #### No finite sample error
# The tests below have no sample error.  In other words, we've just constructed fake "data" where the observed frequencies are equal to known probabilities for which we know what the disturbance metrics should be.  So these tests are crafted to make it easy to interpret the outcome disturbances, and to make sure (for instance) that if we've constructed a pair of distributions that differ by a weight-2 error, we get a nonzero weight-2 disturbance (but approximately zero for the other disturbance metrics).

# %%
#Simple tests - no finite sample error
test({'0000': 0.45, '0001': 0.05, '1111': 0.5}) # weight 1 movement 
test({'0000': 0.45, '0011': 0.05, '1111': 0.5}) # weight 2 movement 
test({'0000': 0.45, '0111': 0.05, '1111': 0.5}) # weight 3 movement
test({'0000': 0.45, '1111': 0.55}) # weight 4 movement
# Out:
# TEST (finite sampling = False)
# p_ref =  {'0000': 0.5, '1111': 0.5}
# p_test =  {'0000': 0.45, '0001': 0.05, '1111': 0.5}
# Weight-1 disturbance = 0.05 +/- 0.00495104
# Weight-2 disturbance = 2.40234e-11 +/- 0.000383227
# Weight-3 disturbance = 0 +/- 0.00461981
# Weight-4 disturbance = 0 +/- 0.00482324
#
# TEST (finite sampling = False)
# p_ref =  {'0000': 0.5, '1111': 0.5}
# p_test =  {'0000': 0.45, '0011': 0.05, '1111': 0.5}
# Weight-1 disturbance = 0 +/- 0.00050273
# Weight-2 disturbance = 0.05 +/- 0.00184698
# Weight-3 disturbance = 1.15975e-11 +/- 0.00014762
# Weight-4 disturbance = 0 +/- 0.00401723
#
# TEST (finite sampling = False)
# p_ref =  {'0000': 0.5, '1111': 0.5}
# p_test =  {'0000': 0.45, '0111': 0.05, '1111': 0.5}
# Weight-1 disturbance = 0 +/- 0.0056122
# Weight-2 disturbance = 0 +/- 0.000407978
# Weight-3 disturbance = 0.05 +/- 0.00538431
# Weight-4 disturbance = 1.41699e-11 +/- 0.00422324
#
# TEST (finite sampling = False)
# p_ref =  {'0000': 0.5, '1111': 0.5}
# p_test =  {'0000': 0.45, '1111': 0.55}
# Weight-1 disturbance = 0 +/- 0.000301337
# Weight-2 disturbance = 1.38778e-17 +/- 0.000396924
# Weight-3 disturbance = -1.38778e-17 +/- 0.000313212
# Weight-4 disturbance = 0.05 +/- 0.00629856

# %%
#More complex tests
test({'0000': 0.40, '0001': 0.05, '1111': 0.55}) # weight 1+4 movement 
test({'0000': 0.40, '0011': 0.05, '1111': 0.55}) # weight 2+4 movement 
test({'0000': 0.40, '0111': 0.05, '1111': 0.55}) # weight 3+4 movement
# Out:
# TEST (finite sampling = False)
# p_ref =  {'0000': 0.5, '1111': 0.5}
# p_test =  {'0000': 0.4, '0001': 0.05, '1111': 0.55}
# Weight-1 disturbance = 0.05 +/- 0.00242524
# Weight-2 disturbance = 3.50071e-11 +/- 0.000386218
# Weight-3 disturbance = 6.93889e-18 +/- 0.000269542
# Weight-4 disturbance = 0.05 +/- 0.00670484
#
# TEST (finite sampling = False)
# p_ref =  {'0000': 0.5, '1111': 0.5}
# p_test =  {'0000': 0.4, '0011': 0.05, '1111': 0.55}
# Weight-1 disturbance = 0 +/- 0.000313449
# Weight-2 disturbance = 0.05 +/- 0.0018408
# Weight-3 disturbance = -1.38778e-17 +/- 0.000306557
# Weight-4 disturbance = 0.05 +/- 0.00655977
#
# TEST (finite sampling = False)
# p_ref =  {'0000': 0.5, '1111': 0.5}
# p_test =  {'0000': 0.4, '0111': 0.05, '1111': 0.55}
# Weight-1 disturbance = 0 +/- 0.000264267
# Weight-2 disturbance = 0 +/- 0.000408104
# Weight-3 disturbance = 0.05 +/- 0.00198749
# Weight-4 disturbance = 0.05 +/- 0.00689546

# %%
#Different magnitudes of weight-2+4 movement
test({'0000': 0.30, '0011': 0.1, '1111': 0.6})
test({'0000': 0.35, '0011': 0.08, '1111': 0.57})
test({'0000': 0.40, '0011': 0.08, '1111': 0.52})
# Out:
# TEST (finite sampling = False)
# p_ref =  {'0000': 0.5, '1111': 0.5}
# p_test =  {'0000': 0.3, '0011': 0.1, '1111': 0.6}
# Weight-1 disturbance = 0 +/- 0.000318961
# Weight-2 disturbance = 0.1 +/- 0.00303484
# Weight-3 disturbance = 1.38778e-17 +/- 0.00023772
# Weight-4 disturbance = 0.1 +/- 0.00560226
#
# TEST (finite sampling = False)
# p_ref =  {'0000': 0.5, '1111': 0.5}
# p_test =  {'0000': 0.35, '0011': 0.08, '1111': 0.57}
# Weight-1 disturbance = 0 +/- 0.000319018
# Weight-2 disturbance = 0.080008 +/- 0.0026334
# Weight-3 disturbance = 0 +/- 0.000245853
# Weight-4 disturbance = 0.069957 +/- 0.00610214
#
# TEST (finite sampling = False)
# p_ref =  {'0000': 0.5, '1111': 0.5}
# p_test =  {'0000': 0.4, '0011': 0.08, '1111': 0.52}
# Weight-1 disturbance = 0 +/- 0.000313449
# Weight-2 disturbance = 0.08 +/- 0.00217509
# Weight-3 disturbance = -6.93889e-18 +/- 0.000267097
# Weight-4 disturbance = 0.02 +/- 0.0064487

# %% [markdown]
# #### With finite sample error
# Now we add finite sample error.  In other words, we start with *known* probability distributions (constructed by hand like the ones above), then simulate N=10^4 samples from those distributions, and analyze the resulting empirical frequency distributions.  The point here is to (1) make sure that the estimated weight-2 disturbances are fairly close to the true ones, and (2) check that the error bar calculations correctly quantify the estimation error (i.e., provide valid confidence regions).
#
# We begin (next cell) by just making sure the results make sense.

# %%
#Simple tests - *with* finite sample error
test({'0000': 0.45, '0001': 0.05, '1111': 0.5}, include_finite_sample_error=True) # weight 1 movement 
test({'0000': 0.45, '0011': 0.05, '1111': 0.5}, include_finite_sample_error=True) # weight 2 movement 
test({'0000': 0.45, '0111': 0.05, '1111': 0.5}, include_finite_sample_error=True) # weight 3 movement
test({'0000': 0.45, '1111': 0.55}, include_finite_sample_error=True) # weight 4 movement
# Out:
# TEST (finite sampling = True)
# p_ref =  {'0000': 0.5, '1111': 0.5}
# p_test =  {'0000': 0.45, '0001': 0.05, '1111': 0.5}
# Weight-1 disturbance = 0.0519 +/- 0.00251072
# Weight-2 disturbance = 5.70851e-10 +/- 0.000372746
# Weight-3 disturbance = -2.75531e-12 +/- 0.0014296
# Weight-4 disturbance = 0.0099 +/- 0.00622999
#
# TEST (finite sampling = True)
# p_ref =  {'0000': 0.5, '1111': 0.5}
# p_test =  {'0000': 0.45, '0011': 0.05, '1111': 0.5}
# Weight-1 disturbance = 1.38778e-17 +/- 0.000366248
# Weight-2 disturbance = 0.0525 +/- 0.00182999
# Weight-3 disturbance = -3.32639e-12 +/- 0.000276382
# Weight-4 disturbance = 0.0093 +/- 0.00591743
#
# TEST (finite sampling = True)
# p_ref =  {'0000': 0.5, '1111': 0.5}
# p_test =  {'0000': 0.45, '0111': 0.05, '1111': 0.5}
# Weight-1 disturbance = 0 +/- 0.000761718
# Weight-2 disturbance = 6.93889e-18 +/- 0.0004081
# Weight-3 disturbance = 0.05 +/- 0.00204997
# Weight-4 disturbance = 0.0118 +/- 0.00652008
#
# TEST (finite sampling = True)
# p_ref =  {'0000': 0.5, '1111': 0.5}
# p_test =  {'0000': 0.45, '1111': 0.55}
# Weight-1 disturbance = 0 +/- 0.000301337
# Weight-2 disturbance = 0 +/- 0.000396924
# Weight-3 disturbance = 2.77556e-17 +/- 0.000313212
# Weight-4 disturbance = 0.0618 +/- 0.00629546

# %% [markdown]
# #### Check error bars
# Finally, we check that the error bars on the disturbances capture the "true" value of the disturbance an appropriate fraction of the time.  The histograms at the end of each of the cells below should show that the mean deviation/errorbar-lengths is around 1.0 (it should be $\chi^2_1$-distributed).  **Note: these tests run a lot of calculations and can take a while to run.**  (Increasing `num_checks` will give better estimates of the distribution but will take longer.)

# %%
def test_errorbars(p_test_dict, p_ref_dict = None, num_checks=20, confidence_percent=68):
    if p_ref_dict is None:
        p_ref_dict = {'0000': 0.5, '1111': 0.5}
    
    data_ref, data_test = gen_data(p_test_dict, p_ref_dict, False)
    base_disturbances = pb.compute_disturbances(n_bits, data_ref, data_test, num_bootstrap_samples=0,
                                                verbosity=0, solver=SOLVER)
    for i,d in enumerate(base_disturbances):
        print("Base weight-%d disturbance = %g" % (i+1,d[0]))
    
    deviation_over_ebs = {i: [] for i in range(4)}
    seeds = [ np.random.randint(1000000000) for i in range(num_checks) ]
    for i,s in enumerate(seeds):
        print("Check %d of %d" % (i+1, num_checks))
        data_ref, data_test = gen_data(p_test_dict, p_ref_dict, True, seed=s)
        try:
            disturbances = pb.compute_disturbances(n_bits, data_ref, data_test, num_bootstrap_samples=10,
                                                   verbosity=0, solver=SOLVER)
        except Exception as e:
            print("EXCEPTION: ", str(e))
            continue

        for i,(d,dbase) in enumerate(zip(disturbances, base_disturbances)):
            deviation_over_eb = abs((d[0] - dbase[0]) / (d[1] + 1e-6))  # add 1e-6 to avoid divide-by-zero errors
            deviation_over_ebs[i].append(deviation_over_eb)
            print("Weight-%d disturbance = %g +/- %g  (deviation=%s)" % (i+1,d[0],d[1],deviation_over_eb))
    
    print("Percentanges within %d%% confidence region:" % confidence_percent)
    for i, pts in deviation_over_ebs.items():
        print("Weight %d: " % (i+1), pts)
        plt.figure()
        plt.title("Weight %d ResidualTVD deviation distribution" % (i+1))
        plt.xlabel("deviation / error_bar_length")
        plt.ylabel("counts")
        plt.hist(pts) 
    print()

# %%
test_errorbars({'0000': 0.45, '0001': 0.05, '1111': 0.5}) # weight 1 movement
# Out:
# Base weight-1 disturbance = 0.05
# Base weight-2 disturbance = 2.40234e-11
# Base weight-3 disturbance = 0
# Base weight-4 disturbance = 0
# Check 1 of 20
# Weight-1 disturbance = 0.0486 +/- 0.00290654  (deviation=0.4815065137857093)
# Weight-2 disturbance = 4.82984e-10 +/- 0.000431117  (deviation=1.062121121890128e-06)
# Weight-3 disturbance = 1.99493e-17 +/- 0.0029575  (deviation=6.743059061628619e-15)
# Weight-4 disturbance = 0.0033 +/- 0.00478348  (deviation=0.689730138301771)
# Check 2 of 20
# Weight-1 disturbance = 0.0487 +/- 0.00225731  (deviation=0.575652814665491)
# Weight-2 disturbance = 2.13652e-11 +/- 0.00044299  (deviation=5.987121348571531e-09)
# Weight-3 disturbance = 0.0004 +/- 0.00262323  (deviation=0.15242586211682463)
# Weight-4 disturbance = 1.96364e-11 +/- 0.00644676  (deviation=3.0454635907403755e-09)
# Check 3 of 20
# Weight-1 disturbance = 0.0475 +/- 0.00553636  (deviation=0.45147856308048423)
# Weight-2 disturbance = 2.23154e-10 +/- 0.000433164  (deviation=4.586541546924755e-07)
# Weight-3 disturbance = 0.0052 +/- 0.00535122  (deviation=0.9715599136852345)
# Weight-4 disturbance = 9.07558e-11 +/- 0.00211758  (deviation=4.2838011804730345e-08)
# Check 4 of 20
# Weight-1 disturbance = 0.0496 +/- 0.00466405  (deviation=0.0857440744874465)
# Weight-2 disturbance = 6.42476e-10 +/- 0.000433392  (deviation=1.4237195828286493e-06)
# Weight-3 disturbance = 0.0012 +/- 0.00467869  (deviation=0.2564274188852626)
# Weight-4 disturbance = 2.72813e-12 +/- 0.00386191  (deviation=7.062367853908311e-10)
# Check 5 of 20
# Weight-1 disturbance = 0.0532 +/- 0.00499752  (deviation=0.6401895401822438)
# Weight-2 disturbance = 1.98426e-10 +/- 0.000433305  (deviation=4.015663289259438e-07)
# Weight-3 disturbance = 0.0026 +/- 0.00486059  (deviation=0.5348045772137217)
# Weight-4 disturbance = 1.7803e-10 +/- 0.0031699  (deviation=5.614479207171478e-08)
# Check 6 of 20
# Weight-1 disturbance = 0.0458 +/- 0.00535032  (deviation=0.7848529477762584)
# Weight-2 disturbance = 2.98746e-10 +/- 0.00044279  (deviation=6.190379179536502e-07)
# Weight-3 disturbance = 0.0059 +/- 0.004847  (deviation=1.216997751120246)
# Weight-4 disturbance = 7.25659e-11 +/- 0.00274635  (deviation=2.6413075073194483e-08)
# Check 7 of 20
# Weight-1 disturbance = 0.0478 +/- 0.00488863  (deviation=0.4499321608793047)
# Weight-2 disturbance = 2.14375e-10 +/- 0.00043331  (deviation=4.3828645154005305e-07)
# Weight-3 disturbance = 0.0023 +/- 0.00480813  (deviation=0.4782573810546827)
# Weight-4 disturbance = 2.13702e-12 +/- 0.00333309  (deviation=6.409611156453671e-10)
# Check 8 of 20
# Weight-1 disturbance = 0.0467 +/- 0.00518763  (deviation=0.6360058126561156)
# Weight-2 disturbance = 1.96953e-10 +/- 0.000433223  (deviation=3.982511807471677e-07)
# Weight-3 disturbance = 0.0035 +/- 0.00501973  (deviation=0.6971095629942556)
# Weight-4 disturbance = 9.86032e-11 +/- 0.00279931  (deviation=3.5211513729420495e-08)
# Check 9 of 20
# Weight-1 disturbance = 0.0496 +/- 0.00155105  (deviation=0.2577236471663445)
# Weight-2 disturbance = 5.81518e-10 +/- 0.00043016  (deviation=1.293009886684383e-06)
# Weight-3 disturbance = -5.20417e-18 +/- 0.000202498  (deviation=2.5573555214648487e-14)
# Weight-4 disturbance = 0.0122 +/- 0.0072623  (deviation=1.6796772204283816)
# Check 10 of 20
# Weight-1 disturbance = 0.0478 +/- 0.00143656  (deviation=1.5303662398736622)
# Weight-2 disturbance = 5.12055e-10 +/- 0.000434102  (deviation=1.121648788761387e-06)
# Weight-3 disturbance = -5.39918e-11 +/- 0.000225348  (deviation=2.385349411375709e-07)
# Weight-4 disturbance = 0.0068 +/- 0.00713676  (deviation=0.9526793435940942)
# Check 11 of 20
# Weight-1 disturbance = 0.0459 +/- 0.00527138  (deviation=0.7776370692625791)
# Weight-2 disturbance = 3.04018e-10 +/- 0.000433186  (deviation=6.448727679444637e-07)
# Weight-3 disturbance = 0.004 +/- 0.00510216  (deviation=0.7838279058355713)
# Weight-4 disturbance = 1.37357e-10 +/- 0.00259417  (deviation=5.2927783535728404e-08)
# Check 12 of 20
# Weight-1 disturbance = 0.0426 +/- 0.00637251  (deviation=1.1610558830298419)
# Weight-2 disturbance = 6.84513e-10 +/- 0.000433296  (deviation=1.5208282510881552e-06)
# Weight-3 disturbance = 0.0099 +/- 0.00625343  (deviation=1.5828789071142932)
# Weight-4 disturbance = 9.65329e-11 +/- 0.000841668  (deviation=1.1455631655632383e-07)
# Check 13 of 20
# Weight-1 disturbance = 0.0455 +/- 0.00521969  (deviation=0.8619556704503195)
# Weight-2 disturbance = 1.86044e-10 +/- 0.000433202  (deviation=3.7314484860497325e-07)
# Weight-3 disturbance = 0.0037 +/- 0.00503671  (deviation=0.73446121090767)
# Weight-4 disturbance = 1.57411e-10 +/- 0.00271693  (deviation=5.7915712430686874e-08)
# Check 14 of 20
# Weight-1 disturbance = 0.0496 +/- 0.00155127  (deviation=0.2576880635605499)
# Weight-2 disturbance = 4.78126e-10 +/- 0.000430056  (deviation=1.0534654225431881e-06)
# Weight-3 disturbance = -1.73472e-18 +/- 0.000202357  (deviation=8.530447069580508e-15)
# Weight-4 disturbance = 0.0086 +/- 0.0072648  (deviation=1.1836273113001887)
# Check 15 of 20
# Weight-1 disturbance = 0.0498 +/- 0.00353508  (deviation=0.056559853775326255)
# Weight-2 disturbance = 2.7023e-10 +/- 0.000430885  (deviation=5.700741845736446e-07)
# Weight-3 disturbance = -9.1073e-18 +/- 0.00365504  (deviation=2.4910275018456626e-15)
# Weight-4 disturbance = 0.0018 +/- 0.00449061  (deviation=0.400747416489954)
# Check 16 of 20
# Weight-1 disturbance = 0.0489 +/- 0.00143255  (deviation=0.7673258901749842)
# Weight-2 disturbance = 5.14055e-10 +/- 0.000433994  (deviation=1.1265256699850258e-06)
# Weight-3 disturbance = -1.23709e-12 +/- 0.00032642  (deviation=3.778299253343833e-09)
# Weight-4 disturbance = 0.0063 +/- 0.00710136  (deviation=0.8870285485093955)
# Check 17 of 20
# Weight-1 disturbance = 0.0485 +/- 0.00153979  (deviation=0.9735283517979988)
# Weight-2 disturbance = 4.73719e-10 +/- 0.000430355  (deviation=1.042517957147106e-06)
# Weight-3 disturbance = 5.20417e-18 +/- 0.000202746  (deviation=2.5542463474694023e-14)
# Weight-4 disturbance = 0.0085 +/- 0.00727995  (deviation=1.1674304631596768)
# Check 18 of 20
# Weight-1 disturbance = 0.0545 +/- 0.00160259  (deviation=2.806209477270537)
# Weight-2 disturbance = 7.51892e-10 +/- 0.0004289  (deviation=1.6931118779832377e-06)
# Weight-3 disturbance = -2.81451e-12 +/- 0.000200827  (deviation=1.3945152508602924e-08)
# Weight-4 disturbance = 0.0116 +/- 0.00721744  (deviation=1.606996287114801)
# Check 19 of 20
# Weight-1 disturbance = 0.0504 +/- 0.00378684  (deviation=0.10560120057132054)
# Weight-2 disturbance = 9.10973e-11 +/- 0.000410375  (deviation=1.630478668224806e-07)
# Weight-3 disturbance = -1.01213e-10 +/- 0.0039427  (deviation=2.566449543512558e-08)
# Weight-4 disturbance = 0.0013 +/- 0.00444044  (deviation=0.29269799584860406)
# Check 20 of 20
# Weight-1 disturbance = 0.0463 +/- 0.00413827  (deviation=0.893877723875702)
# Weight-2 disturbance = 2.19236e-10 +/- 0.000442846  (deviation=4.398220850361314e-07)
# Weight-3 disturbance = 0.004 +/- 0.00378501  (deviation=1.056520269798226)
# Weight-4 disturbance = 9.94746e-11 +/- 0.00397285  (deviation=2.5032321773964056e-08)
# Percentanges within 68% confidence region:
# Weight 1:  [np.float64(0.4815065137857093), np.float64(0.575652814665491), np.float64(0.45147856308048423), np.float64(0.0857440744874465), np.float64(0.6401895401822438), np.float64(0.7848529477762584), np.float64(0.4499321608793047), np.float64(0.6360058126561156), np.float64(0.2577236471663445), np.float64(1.5303662398736622), np.float64(0.7776370692625791), np.float64(1.1610558830298419), np.float64(0.8619556704503195), np.float64(0.2576880635605499), np.float64(0.056559853775326255), np.float64(0.7673258901749842), np.float64(0.9735283517979988), np.float64(2.806209477270537), np.float64(0.10560120057132054), np.float64(0.893877723875702)]
# Weight 2:  [np.float64(1.062121121890128e-06), np.float64(5.987121348571531e-09), np.float64(4.586541546924755e-07), np.float64(1.4237195828286493e-06), np.float64(4.015663289259438e-07), np.float64(6.190379179536502e-07), np.float64(4.3828645154005305e-07), np.float64(3.982511807471677e-07), np.float64(1.293009886684383e-06), np.float64(1.121648788761387e-06), np.float64(6.448727679444637e-07), np.float64(1.5208282510881552e-06), np.float64(3.7314484860497325e-07), np.float64(1.0534654225431881e-06), np.float64(5.700741845736446e-07), np.float64(1.1265256699850258e-06), np.float64(1.042517957147106e-06), np.float64(1.6931118779832377e-06), np.float64(1.630478668224806e-07), np.float64(4.398220850361314e-07)]
# Weight 3:  [np.float64(6.743059061628619e-15), np.float64(0.15242586211682463), np.float64(0.9715599136852345), np.float64(0.2564274188852626), np.float64(0.5348045772137217), np.float64(1.216997751120246), np.float64(0.4782573810546827), np.float64(0.6971095629942556), np.float64(2.5573555214648487e-14), np.float64(2.385349411375709e-07), np.float64(0.7838279058355713), np.float64(1.5828789071142932), np.float64(0.73446121090767), np.float64(8.530447069580508e-15), np.float64(2.4910275018456626e-15), np.float64(3.778299253343833e-09), np.float64(2.5542463474694023e-14), np.float64(1.3945152508602924e-08), np.float64(2.566449543512558e-08), np.float64(1.056520269798226)]
# Weight 4:  [np.float64(0.689730138301771), np.float64(3.0454635907403755e-09), np.float64(4.2838011804730345e-08), np.float64(7.062367853908311e-10), np.float64(5.614479207171478e-08), np.float64(2.6413075073194483e-08), np.float64(6.409611156453671e-10), np.float64(3.5211513729420495e-08), np.float64(1.6796772204283816), np.float64(0.9526793435940942), np.float64(5.2927783535728404e-08), np.float64(1.1455631655632383e-07), np.float64(5.7915712430686874e-08), np.float64(1.1836273113001887), np.float64(0.400747416489954), np.float64(0.8870285485093955), np.float64(1.1674304631596768), np.float64(1.606996287114801), np.float64(0.29269799584860406), np.float64(2.5032321773964056e-08)]

# %%
test_errorbars({'0000': 0.45, '0011': 0.05, '1111': 0.5}) # weight 2 movement
# Out:
# Base weight-1 disturbance = 0
# Base weight-2 disturbance = 0.05
# Base weight-3 disturbance = 1.15975e-11
# Base weight-4 disturbance = 0
# Check 1 of 20
# Weight-1 disturbance = 0 +/- 0.000321965  (deviation=0.0)
# Weight-2 disturbance = 0.0512 +/- 0.00206967  (deviation=0.5795219071169402)
# Weight-3 disturbance = -1.82094e-10 +/- 0.00013997  (deviation=1.3739952027962898e-06)
# Weight-4 disturbance = 0.0007 +/- 0.00528605  (deviation=0.13239909913405926)
# Check 2 of 20
# Weight-1 disturbance = 2.08167e-17 +/- 0.00029279  (deviation=7.085556794087256e-14)
# Weight-2 disturbance = 0.0507 +/- 0.00201325  (deviation=0.3475236855404413)
# Weight-3 disturbance = 2.18599e-11 +/- 9.17399e-05  (deviation=1.1065773412690867e-07)
# Weight-4 disturbance = 0 +/- 0.00296039  (deviation=0.0)
# Check 3 of 20
# Weight-1 disturbance = 0 +/- 0.00015471  (deviation=0.0)
# Weight-2 disturbance = 0.0524 +/- 0.00197466  (deviation=1.2147861690872954)
# Weight-3 disturbance = 5.20417e-18 +/- 0.000200315  (deviation=5.760875621603504e-08)
# Weight-4 disturbance = 0.0114 +/- 0.0064727  (deviation=1.7609721672844458)
# Check 4 of 20
# Weight-1 disturbance = 0 +/- 0.000154711  (deviation=0.0)
# Weight-2 disturbance = 0.0512 +/- 0.00195009  (deviation=0.6150395240062428)
# Weight-3 disturbance = -3.46945e-18 +/- 0.000219719  (deviation=5.2544288827597766e-08)
# Weight-4 disturbance = 0.0136 +/- 0.00761717  (deviation=1.7852047180266963)
# Check 5 of 20
# Weight-1 disturbance = 1.38778e-17 +/- 0.000292791  (deviation=4.723696737008458e-14)
# Weight-2 disturbance = 0.0474 +/- 0.00194632  (deviation=1.3351708237541249)
# Weight-3 disturbance = 4.98209e-11 +/- 0.000138518  (deviation=2.739677952956001e-07)
# Weight-4 disturbance = 0 +/- 0.00412054  (deviation=0.0)
# Check 6 of 20
# Weight-1 disturbance = 1.38778e-17 +/- 0.000351557  (deviation=3.936328316200043e-14)
# Weight-2 disturbance = 0.0494 +/- 0.00191731  (deviation=0.31277539998638204)
# Weight-3 disturbance = 3.84772e-11 +/- 1.9976e-06  (deviation=8.967063848694568e-06)
# Weight-4 disturbance = 0 +/- 0.000718976  (deviation=0.0)
# Check 7 of 20
# Weight-1 disturbance = 0 +/- 0.000154696  (deviation=0.0)
# Weight-2 disturbance = 0.05 +/- 0.00192101  (deviation=6.0340449022068235e-09)
# Weight-3 disturbance = -4.33127e-12 +/- 0.00020145  (deviation=7.86802852964547e-08)
# Weight-4 disturbance = 0.004 +/- 0.00753971  (deviation=0.5304539852818455)
# Check 8 of 20
# Weight-1 disturbance = 0 +/- 0.000287633  (deviation=0.0)
# Weight-2 disturbance = 0.0488 +/- 0.00198741  (deviation=0.603496215809574)
# Weight-3 disturbance = 7.58942e-18 +/- 0.000140581  (deviation=8.191460076126465e-08)
# Weight-4 disturbance = 0.0008 +/- 0.00525944  (deviation=0.15207863856346454)
# Check 9 of 20
# Weight-1 disturbance = 0 +/- 0.000154711  (deviation=0.0)
# Weight-2 disturbance = 0.0492 +/- 0.0019382  (deviation=0.4125415131563133)
# Weight-3 disturbance = -2.77556e-17 +/- 0.000201887  (deviation=5.716255791472262e-08)
# Weight-4 disturbance = 0.0191 +/- 0.00773133  (deviation=2.4701466315494036)
# Check 10 of 20
# Weight-1 disturbance = 2.08167e-17 +/- 0.000351563  (deviation=5.904380325402423e-14)
# Weight-2 disturbance = 0.0521 +/- 0.00195409  (deviation=1.0741191250012434)
# Weight-3 disturbance = 1.12006e-11 +/- 9.16839e-05  (deviation=4.282724340142164e-09)
# Weight-4 disturbance = 0 +/- 0.00236143  (deviation=0.0)
# Check 11 of 20
# Weight-1 disturbance = 6.93889e-18 +/- 0.000154696  (deviation=4.45668947937281e-14)
# Weight-2 disturbance = 0.048 +/- 0.00189122  (deviation=1.0569590837072838)
# Weight-3 disturbance = -3.45698e-10 +/- 0.000202006  (deviation=1.7600253986391102e-06)
# Weight-4 disturbance = 0.006 +/- 0.00762908  (deviation=0.7863614863903545)
# Check 12 of 20
# Weight-1 disturbance = 0 +/- 0.000320418  (deviation=0.0)
# Weight-2 disturbance = 0.0508 +/- 0.00189334  (deviation=0.42231075265269463)
# Weight-3 disturbance = 4.17657e-11 +/- 9.17373e-05  (deviation=3.2530789586363017e-07)
# Weight-4 disturbance = 0 +/- 0.00139589  (deviation=0.0)
# Check 13 of 20
# Weight-1 disturbance = 3.46945e-17 +/- 0.000320418  (deviation=1.0794183168680825e-13)
# Weight-2 disturbance = 0.0486 +/- 0.00186624  (deviation=0.7497699635458609)
# Weight-3 disturbance = 4.41214e-11 +/- 9.18466e-05  (deviation=3.50296272967238e-07)
# Weight-4 disturbance = 0 +/- 0.0015619  (deviation=0.0)
# Check 14 of 20
# Weight-1 disturbance = 6.93889e-18 +/- 0.000320419  (deviation=2.1588338756096232e-14)
# Weight-2 disturbance = 0.0507 +/- 0.00189329  (deviation=0.36953242524848473)
# Weight-3 disturbance = 1.52932e-10 +/- 9.17531e-05  (deviation=1.5237657343885888e-06)
# Weight-4 disturbance = 0 +/- 0.00199478  (deviation=0.0)
# Check 15 of 20
# Weight-1 disturbance = 2.77556e-17 +/- 0.000326581  (deviation=8.472883883431213e-14)
# Weight-2 disturbance = 0.0523 +/- 0.002107  (deviation=1.0910804607514752)
# Weight-3 disturbance = 2.83952e-11 +/- 0.000137532  (deviation=1.212541171972789e-07)
# Weight-4 disturbance = 0 +/- 0.00335284  (deviation=0.0)
# Check 16 of 20
# Weight-1 disturbance = 0 +/- 0.000320418  (deviation=0.0)
# Weight-2 disturbance = 0.0479 +/- 0.0018139  (deviation=1.1570870002995306)
# Weight-3 disturbance = 4.46261e-11 +/- 9.18582e-05  (deviation=3.55687636727812e-07)
# Weight-4 disturbance = 0 +/- 0.00145076  (deviation=0.0)
# Check 17 of 20
# Weight-1 disturbance = 6.93889e-18 +/- 0.00028239  (deviation=2.4485328689895992e-14)
# Weight-2 disturbance = 0.0497 +/- 0.00209159  (deviation=0.14336329487860144)
# Weight-3 disturbance = -7.14288e-12 +/- 0.00014386  (deviation=1.2936932515920526e-07)
# Weight-4 disturbance = 0.0038 +/- 0.00569321  (deviation=0.6673448045313514)
# Check 18 of 20
# Weight-1 disturbance = 6.93889e-18 +/- 0.000292791  (deviation=2.3618488878681468e-14)
# Weight-2 disturbance = 0.0497 +/- 0.00202733  (deviation=0.1479046925689064)
# Weight-3 disturbance = 2.64606e-11 +/- 0.00013806  (deviation=1.0688270577417973e-07)
# Weight-4 disturbance = 0 +/- 0.00323776  (deviation=0.0)
# Check 19 of 20
# Weight-1 disturbance = 0 +/- 0.000326581  (deviation=0.0)
# Weight-2 disturbance = 0.0524 +/- 0.00212117  (deviation=1.13091850446791)
# Weight-3 disturbance = 2.50934e-11 +/- 0.000137508  (deviation=9.74374670033952e-08)
# Weight-4 disturbance = 0 +/- 0.00315747  (deviation=0.0)
# Check 20 of 20
# Weight-1 disturbance = 0 +/- 0.000351564  (deviation=0.0)
# Weight-2 disturbance = 0.0523 +/- 0.00195416  (deviation=1.1763715452271306)
# Weight-3 disturbance = 1.83149e-11 +/- 9.16998e-05  (deviation=7.246314154768911e-08)
# Weight-4 disturbance = 0 +/- 0.00269332  (deviation=0.0)
# Percentanges within 68% confidence region:
# Weight 1:  [np.float64(0.0), np.float64(7.085556794087256e-14), np.float64(0.0), np.float64(0.0), np.float64(4.723696737008458e-14), np.float64(3.936328316200043e-14), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(5.904380325402423e-14), np.float64(4.45668947937281e-14), np.float64(0.0), np.float64(1.0794183168680825e-13), np.float64(2.1588338756096232e-14), np.float64(8.472883883431213e-14), np.float64(0.0), np.float64(2.4485328689895992e-14), np.float64(2.3618488878681468e-14), np.float64(0.0), np.float64(0.0)]
# Weight 2:  [np.float64(0.5795219071169402), np.float64(0.3475236855404413), np.float64(1.2147861690872954), np.float64(0.6150395240062428), np.float64(1.3351708237541249), np.float64(0.31277539998638204), np.float64(6.0340449022068235e-09), np.float64(0.603496215809574), np.float64(0.4125415131563133), np.float64(1.0741191250012434), np.float64(1.0569590837072838), np.float64(0.42231075265269463), np.float64(0.7497699635458609), np.float64(0.36953242524848473), np.float64(1.0910804607514752), np.float64(1.1570870002995306), np.float64(0.14336329487860144), np.float64(0.1479046925689064), np.float64(1.13091850446791), np.float64(1.1763715452271306)]
# Weight 3:  [np.float64(1.3739952027962898e-06), np.float64(1.1065773412690867e-07), np.float64(5.760875621603504e-08), np.float64(5.2544288827597766e-08), np.float64(2.739677952956001e-07), np.float64(8.967063848694568e-06), np.float64(7.86802852964547e-08), np.float64(8.191460076126465e-08), np.float64(5.716255791472262e-08), np.float64(4.282724340142164e-09), np.float64(1.7600253986391102e-06), np.float64(3.2530789586363017e-07), np.float64(3.50296272967238e-07), np.float64(1.5237657343885888e-06), np.float64(1.212541171972789e-07), np.float64(3.55687636727812e-07), np.float64(1.2936932515920526e-07), np.float64(1.0688270577417973e-07), np.float64(9.74374670033952e-08), np.float64(7.246314154768911e-08)]
# Weight 4:  [np.float64(0.13239909913405926), np.float64(0.0), np.float64(1.7609721672844458), np.float64(1.7852047180266963), np.float64(0.0), np.float64(0.0), np.float64(0.5304539852818455), np.float64(0.15207863856346454), np.float64(2.4701466315494036), np.float64(0.0), np.float64(0.7863614863903545), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.6673448045313514), np.float64(0.0), np.float64(0.0), np.float64(0.0)]

# %%
test_errorbars({'0000': 0.45, '0111': 0.05, '1111': 0.5}) # weight 3 movement
# Out:
# Base weight-1 disturbance = 0
# Base weight-2 disturbance = 0
# Base weight-3 disturbance = 0.05
# Base weight-4 disturbance = 1.41699e-11
# Check 1 of 20
# Weight-1 disturbance = 0 +/- 0.00351884  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.000273632  (deviation=0.0)
# Weight-3 disturbance = 0.0487 +/- 0.00367782  (deviation=0.3533744572671686)
# Weight-4 disturbance = 0.0032 +/- 0.00572777  (deviation=0.5585840744744275)
# Check 2 of 20
# Weight-1 disturbance = 0.0038 +/- 0.00561183  (deviation=0.6770198381337033)
# Weight-2 disturbance = 5.03964e-10 +/- 0.000273619  (deviation=1.8351406065948642e-06)
# Weight-3 disturbance = 0.0453 +/- 0.00514317  (deviation=0.913656162111927)
# Weight-4 disturbance = 1.92526e-11 +/- 0.00348886  (deviation=1.4564210613444253e-09)
# Check 3 of 20
# Weight-1 disturbance = 0 +/- 0.000506222  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.000273481  (deviation=0.0)
# Weight-3 disturbance = 0.0515 +/- 0.00286626  (deviation=0.5231480228320916)
# Weight-4 disturbance = 0.0123 +/- 0.00716368  (deviation=1.716755117009657)
# Check 4 of 20
# Weight-1 disturbance = 0 +/- 0.000277156  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.000282444  (deviation=0.0)
# Weight-3 disturbance = 0.0494 +/- 0.00290876  (deviation=0.20620224570176107)
# Weight-4 disturbance = 0.0154 +/- 0.00643287  (deviation=2.393583491992218)
# Check 5 of 20
# Weight-1 disturbance = 0.0059 +/- 0.00612806  (deviation=0.9626273469993355)
# Weight-2 disturbance = 1.94511e-10 +/- 0.000273579  (deviation=7.083982823909856e-07)
# Weight-3 disturbance = 0.045 +/- 0.00561226  (deviation=0.890748243437122)
# Weight-4 disturbance = 1.30482e-10 +/- 0.00248429  (deviation=4.680002202252784e-08)
# Check 6 of 20
# Weight-1 disturbance = 0.0176 +/- 0.00746722  (deviation=2.3566533177823943)
# Weight-2 disturbance = 6.55329e-10 +/- 0.000274094  (deviation=2.382197494856643e-06)
# Weight-3 disturbance = 0.0301 +/- 0.00669493  (deviation=2.97195320603566)
# Weight-4 disturbance = 1.50706e-10 +/- 0.000737497  (deviation=1.8488345963044363e-07)
# Check 7 of 20
# Weight-1 disturbance = 0 +/- 0.00138264  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.000282331  (deviation=0.0)
# Weight-3 disturbance = 0.051 +/- 0.0031462  (deviation=0.3177431508121268)
# Weight-4 disturbance = 0.003 +/- 0.0060874  (deviation=0.49274046774633967)
# Check 8 of 20
# Weight-1 disturbance = 0 +/- 0.00393168  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.000273645  (deviation=0.0)
# Weight-3 disturbance = 0.0473 +/- 0.00387968  (deviation=0.6957543660727997)
# Weight-4 disturbance = 0.0023 +/- 0.00556211  (deviation=0.4134380420720638)
# Check 9 of 20
# Weight-1 disturbance = 0 +/- 0.000277155  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.000282444  (deviation=0.0)
# Weight-3 disturbance = 0.0533 +/- 0.00301112  (deviation=1.095575399784168)
# Weight-4 disturbance = 0.015 +/- 0.00640033  (deviation=2.3432646714948593)
# Check 10 of 20
# Weight-1 disturbance = 0.0105 +/- 0.00736898  (deviation=1.4246976326997904)
# Weight-2 disturbance = 9.50323e-11 +/- 0.000273559  (deviation=3.4612658771859146e-07)
# Weight-3 disturbance = 0.0447 +/- 0.00663355  (deviation=0.798848203931496)
# Weight-4 disturbance = 1.92062e-10 +/- 0.000769627  (deviation=2.3084124566386108e-07)
# Check 11 of 20
# Weight-1 disturbance = 0 +/- 0.00107416  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.00028236  (deviation=0.0)
# Weight-3 disturbance = 0.05 +/- 0.00299765  (deviation=4.7254342488251e-09)
# Weight-4 disturbance = 0.004 +/- 0.00615722  (deviation=0.6495383992446195)
# Check 12 of 20
# Weight-1 disturbance = 0.0075 +/- 0.00656131  (deviation=1.1428908894877792)
# Weight-2 disturbance = 4.26029e-11 +/- 0.000273544  (deviation=1.5517714407663132e-07)
# Weight-3 disturbance = 0.0401 +/- 0.00602253  (deviation=1.6435541685412696)
# Weight-4 disturbance = 3.73624e-10 +/- 0.00171477  (deviation=2.0950056247686085e-07)
# Check 13 of 20
# Weight-1 disturbance = 0.0135 +/- 0.00754064  (deviation=1.7900613551288729)
# Weight-2 disturbance = 2.3898e-11 +/- 0.000273726  (deviation=8.698817231844352e-08)
# Weight-3 disturbance = 0.0386 +/- 0.00669586  (deviation=1.7022910773004154)
# Weight-4 disturbance = 3.12434e-10 +/- 0.000737712  (deviation=4.037617417112866e-07)
# Check 14 of 20
# Weight-1 disturbance = 0.0064 +/- 0.00626607  (deviation=1.0212102265713556)
# Weight-2 disturbance = 6.92203e-11 +/- 0.000273565  (deviation=2.521092380554296e-07)
# Weight-3 disturbance = 0.0421 +/- 0.00576889  (deviation=1.3691763138261193)
# Weight-4 disturbance = 3.26406e-10 +/- 0.0022076  (deviation=1.413729426036141e-07)
# Check 15 of 20
# Weight-1 disturbance = 0 +/- 0.00525578  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.000273673  (deviation=0.0)
# Weight-3 disturbance = 0.048 +/- 0.00486703  (deviation=0.4108434897130836)
# Weight-4 disturbance = 1.44465e-11 +/- 0.00546766  (deviation=5.057785317820475e-11)
# Check 16 of 20
# Weight-1 disturbance = 0.0115 +/- 0.00748088  (deviation=1.537046164692676)
# Weight-2 disturbance = 1.82957e-11 +/- 0.000273553  (deviation=6.663819694978078e-08)
# Weight-3 disturbance = 0.0376 +/- 0.00669594  (deviation=1.851593336772257)
# Weight-4 disturbance = 3.5617e-10 +/- 0.000737955  (deviation=4.6281588844483e-07)
# Check 17 of 20
# Weight-1 disturbance = 0 +/- 0.00425145  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.000273656  (deviation=0.0)
# Weight-3 disturbance = 0.0517 +/- 0.00409954  (deviation=0.4145791117155578)
# Weight-4 disturbance = 0.0018 +/- 0.00554952  (deviation=0.3242939357017309)
# Check 18 of 20
# Weight-1 disturbance = 0.0029 +/- 0.00545488  (deviation=0.5315364963324869)
# Weight-2 disturbance = 1.09737e-11 +/- 0.00027364  (deviation=3.995663781728146e-08)
# Weight-3 disturbance = 0.0452 +/- 0.00500171  (deviation=0.9594804983588249)
# Weight-4 disturbance = 2.20268e-11 +/- 0.0039346  (deviation=1.9963442957203696e-09)
# Check 19 of 20
# Weight-1 disturbance = 0.0032 +/- 0.00553741  (deviation=0.5777828424275036)
# Weight-2 disturbance = 1.67808e-11 +/- 0.000273633  (deviation=6.11024166292009e-08)
# Weight-3 disturbance = 0.0476 +/- 0.00504051  (deviation=0.4760483623514923)
# Weight-4 disturbance = 2.6696e-10 +/- 0.00384015  (deviation=6.581092202951816e-08)
# Check 20 of 20
# Weight-1 disturbance = 0.0048 +/- 0.0058533  (deviation=0.8199103084360762)
# Weight-2 disturbance = 3.86115e-10 +/- 0.000273598  (deviation=1.4061069836058674e-06)
# Weight-3 disturbance = 0.046 +/- 0.0053374  (deviation=0.7492884276668317)
# Weight-4 disturbance = 1.24561e-10 +/- 0.00302306  (deviation=3.650435488800335e-08)
# Percentanges within 68% confidence region:
# Weight 1:  [np.float64(0.0), np.float64(0.6770198381337033), np.float64(0.0), np.float64(0.0), np.float64(0.9626273469993355), np.float64(2.3566533177823943), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(1.4246976326997904), np.float64(0.0), np.float64(1.1428908894877792), np.float64(1.7900613551288729), np.float64(1.0212102265713556), np.float64(0.0), np.float64(1.537046164692676), np.float64(0.0), np.float64(0.5315364963324869), np.float64(0.5777828424275036), np.float64(0.8199103084360762)]
# Weight 2:  [np.float64(0.0), np.float64(1.8351406065948642e-06), np.float64(0.0), np.float64(0.0), np.float64(7.083982823909856e-07), np.float64(2.382197494856643e-06), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(3.4612658771859146e-07), np.float64(0.0), np.float64(1.5517714407663132e-07), np.float64(8.698817231844352e-08), np.float64(2.521092380554296e-07), np.float64(0.0), np.float64(6.663819694978078e-08), np.float64(0.0), np.float64(3.995663781728146e-08), np.float64(6.11024166292009e-08), np.float64(1.4061069836058674e-06)]
# Weight 3:  [np.float64(0.3533744572671686), np.float64(0.913656162111927), np.float64(0.5231480228320916), np.float64(0.20620224570176107), np.float64(0.890748243437122), np.float64(2.97195320603566), np.float64(0.3177431508121268), np.float64(0.6957543660727997), np.float64(1.095575399784168), np.float64(0.798848203931496), np.float64(4.7254342488251e-09), np.float64(1.6435541685412696), np.float64(1.7022910773004154), np.float64(1.3691763138261193), np.float64(0.4108434897130836), np.float64(1.851593336772257), np.float64(0.4145791117155578), np.float64(0.9594804983588249), np.float64(0.4760483623514923), np.float64(0.7492884276668317)]
# Weight 4:  [np.float64(0.5585840744744275), np.float64(1.4564210613444253e-09), np.float64(1.716755117009657), np.float64(2.393583491992218), np.float64(4.680002202252784e-08), np.float64(1.8488345963044363e-07), np.float64(0.49274046774633967), np.float64(0.4134380420720638), np.float64(2.3432646714948593), np.float64(2.3084124566386108e-07), np.float64(0.6495383992446195), np.float64(2.0950056247686085e-07), np.float64(4.037617417112866e-07), np.float64(1.413729426036141e-07), np.float64(5.057785317820475e-11), np.float64(4.6281588844483e-07), np.float64(0.3242939357017309), np.float64(1.9963442957203696e-09), np.float64(6.581092202951816e-08), np.float64(3.650435488800335e-08)]

# %%
test_errorbars({'0000': 0.45, '1111': 0.55}) # weight 4 movement
# Out:
# Base weight-1 disturbance = 0
# Base weight-2 disturbance = 1.38778e-17
# Base weight-3 disturbance = -1.38778e-17
# Base weight-4 disturbance = 0.05
# Check 1 of 20
# Weight-1 disturbance = 0 +/- 0.000223282  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.000275331  (deviation=5.022158723918966e-14)
# Weight-3 disturbance = 1.38778e-17 +/- 0.000315659  (deviation=8.765143069995352e-14)
# Weight-4 disturbance = 0.0519 +/- 0.00661144  (deviation=0.28733729715034184)
# Check 2 of 20
# Weight-1 disturbance = 0 +/- 0.000223282  (deviation=0.0)
# Weight-2 disturbance = 1.38778e-17 +/- 0.000275331  (deviation=0.0)
# Weight-3 disturbance = -1.38778e-17 +/- 0.000315659  (deviation=0.0)
# Weight-4 disturbance = 0.0453 +/- 0.0066117  (deviation=0.7107539745869497)
# Check 3 of 20
# Weight-1 disturbance = 0 +/- 0.000223282  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.00027533  (deviation=5.0221763588738775e-14)
# Weight-3 disturbance = 0 +/- 0.000315659  (deviation=4.3825613574840116e-14)
# Weight-4 disturbance = 0.0638 +/- 0.00661101  (deviation=2.087109747681865)
# Check 4 of 20
# Weight-1 disturbance = 0 +/- 0.00022328  (deviation=0.0)
# Weight-2 disturbance = 1.38778e-17 +/- 0.00028071  (deviation=0.0)
# Weight-3 disturbance = -1.38778e-17 +/- 0.000315659  (deviation=0.0)
# Weight-4 disturbance = 0.0648 +/- 0.00772587  (deviation=1.9153941018488496)
# Check 5 of 20
# Weight-1 disturbance = 0 +/- 0.000223281  (deviation=0.0)
# Weight-2 disturbance = 6.93889e-18 +/- 0.00027533  (deviation=2.5110900394155142e-14)
# Weight-3 disturbance = 6.93889e-18 +/- 0.00031566  (deviation=6.573837621644357e-14)
# Weight-4 disturbance = 0.045 +/- 0.00661171  (deviation=0.7561198675156628)
# Check 6 of 20
# Weight-1 disturbance = 0 +/- 0.000223282  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.000275333  (deviation=5.0221337620897965e-14)
# Weight-3 disturbance = 0 +/- 0.000315658  (deviation=4.3825842621125896e-14)
# Weight-4 disturbance = 0.0301 +/- 0.00661235  (deviation=3.0090628167774667)
# Check 7 of 20
# Weight-1 disturbance = 0 +/- 0.00022328  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.000280711  (deviation=4.926253380329101e-14)
# Weight-3 disturbance = 2.08167e-17 +/- 0.000315658  (deviation=1.0956446241582863e-13)
# Weight-4 disturbance = 0.054 +/- 0.00773513  (deviation=0.5170545817574794)
# Check 8 of 20
# Weight-1 disturbance = 0 +/- 0.000223281  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.00027533  (deviation=5.022180852965307e-14)
# Weight-3 disturbance = 0 +/- 0.00031566  (deviation=4.3825581642209374e-14)
# Weight-4 disturbance = 0.0496 +/- 0.00661153  (deviation=0.06049125719921582)
# Check 9 of 20
# Weight-1 disturbance = 0 +/- 0.00022328  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.00028071  (deviation=4.926269597414634e-14)
# Weight-3 disturbance = 0 +/- 0.000315659  (deviation=4.382568306467767e-14)
# Weight-4 disturbance = 0.0683 +/- 0.00772288  (deviation=2.3692770515325)
# Check 10 of 20
# Weight-1 disturbance = 0 +/- 0.000223282  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.000275331  (deviation=5.022157436844806e-14)
# Weight-3 disturbance = 6.93889e-18 +/- 0.000315659  (deviation=6.573855669297601e-14)
# Weight-4 disturbance = 0.0447 +/- 0.00661172  (deviation=0.8014855753165543)
# Check 11 of 20
# Weight-1 disturbance = 0 +/- 0.00022328  (deviation=0.0)
# Weight-2 disturbance = 6.93889e-18 +/- 0.000280711  (deviation=2.4631212121398642e-14)
# Weight-3 disturbance = 2.77556e-17 +/- 0.000315658  (deviation=1.314775564260334e-13)
# Weight-4 disturbance = 0.054 +/- 0.00773513  (deviation=0.5170545884141458)
# Check 12 of 20
# Weight-1 disturbance = 0 +/- 0.000223282  (deviation=0.0)
# Weight-2 disturbance = 2.08167e-17 +/- 0.000275331  (deviation=2.5110825790677112e-14)
# Weight-3 disturbance = -2.08167e-17 +/- 0.000315659  (deviation=2.1912843429303627e-14)
# Weight-4 disturbance = 0.0401 +/- 0.00661191  (deviation=1.497071332380024)
# Check 13 of 20
# Weight-1 disturbance = 0 +/- 0.000223282  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.000275331  (deviation=5.022155590976557e-14)
# Weight-3 disturbance = 0 +/- 0.000315659  (deviation=4.3825712132696486e-14)
# Weight-4 disturbance = 0.0386 +/- 0.00661198  (deviation=1.7238836217379525)
# Check 14 of 20
# Weight-1 disturbance = 0 +/- 0.000223282  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.00027533  (deviation=5.022170908185116e-14)
# Weight-3 disturbance = 6.93889e-18 +/- 0.000315659  (deviation=6.573845286833995e-14)
# Weight-4 disturbance = 0.0421 +/- 0.00661183  (deviation=1.194647870497375)
# Check 15 of 20
# Weight-1 disturbance = 0 +/- 0.000223282  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.000275331  (deviation=5.0221682389529285e-14)
# Weight-3 disturbance = 1.38778e-17 +/- 0.000315659  (deviation=8.76513004055778e-14)
# Weight-4 disturbance = 0.048 +/- 0.00661159  (deviation=0.30245342722941515)
# Check 16 of 20
# Weight-1 disturbance = 0 +/- 0.000223282  (deviation=0.0)
# Weight-2 disturbance = 1.38778e-17 +/- 0.000275332  (deviation=0.0)
# Weight-3 disturbance = -1.38778e-17 +/- 0.000315658  (deviation=0.0)
# Weight-4 disturbance = 0.0376 +/- 0.00661202  (deviation=1.875089227417351)
# Check 17 of 20
# Weight-1 disturbance = 0 +/- 0.000223282  (deviation=0.0)
# Weight-2 disturbance = 2.77556e-17 +/- 0.00027533  (deviation=5.022175546870331e-14)
# Weight-3 disturbance = -1.38778e-17 +/- 0.000315659  (deviation=0.0)
# Weight-4 disturbance = 0.0535 +/- 0.00661138  (deviation=0.5293103615204593)
# Check 18 of 20
# Weight-1 disturbance = 0 +/- 0.000223281  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.00027533  (deviation=5.0221796370499636e-14)
# Weight-3 disturbance = 0 +/- 0.000315659  (deviation=4.382559385110029e-14)
# Weight-4 disturbance = 0.0452 +/- 0.0066117  (deviation=0.7258759629166031)
# Check 19 of 20
# Weight-1 disturbance = 0 +/- 0.000223282  (deviation=0.0)
# Weight-2 disturbance = 2.08167e-17 +/- 0.00027533  (deviation=2.5110865966120325e-14)
# Weight-3 disturbance = -1.38778e-17 +/- 0.000315659  (deviation=0.0)
# Weight-4 disturbance = 0.0476 +/- 0.0066116  (deviation=0.36294324777537773)
# Check 20 of 20
# Weight-1 disturbance = 0 +/- 0.000223282  (deviation=0.0)
# Weight-2 disturbance = 0 +/- 0.00027533  (deviation=5.0221705518906344e-14)
# Weight-3 disturbance = 0 +/- 0.000315659  (deviation=4.38256419634162e-14)
# Weight-4 disturbance = 0.046 +/- 0.00661167  (deviation=0.6048995806725016)
# Percentanges within 68% confidence region:
# Weight 1:  [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Weight 2:  [np.float64(5.022158723918966e-14), np.float64(0.0), np.float64(5.0221763588738775e-14), np.float64(0.0), np.float64(2.5110900394155142e-14), np.float64(5.0221337620897965e-14), np.float64(4.926253380329101e-14), np.float64(5.022180852965307e-14), np.float64(4.926269597414634e-14), np.float64(5.022157436844806e-14), np.float64(2.4631212121398642e-14), np.float64(2.5110825790677112e-14), np.float64(5.022155590976557e-14), np.float64(5.022170908185116e-14), np.float64(5.0221682389529285e-14), np.float64(0.0), np.float64(5.022175546870331e-14), np.float64(5.0221796370499636e-14), np.float64(2.5110865966120325e-14), np.float64(5.0221705518906344e-14)]
# Weight 3:  [np.float64(8.765143069995352e-14), np.float64(0.0), np.float64(4.3825613574840116e-14), np.float64(0.0), np.float64(6.573837621644357e-14), np.float64(4.3825842621125896e-14), np.float64(1.0956446241582863e-13), np.float64(4.3825581642209374e-14), np.float64(4.382568306467767e-14), np.float64(6.573855669297601e-14), np.float64(1.314775564260334e-13), np.float64(2.1912843429303627e-14), np.float64(4.3825712132696486e-14), np.float64(6.573845286833995e-14), np.float64(8.76513004055778e-14), np.float64(0.0), np.float64(0.0), np.float64(4.382559385110029e-14), np.float64(0.0), np.float64(4.38256419634162e-14)]
# Weight 4:  [np.float64(0.28733729715034184), np.float64(0.7107539745869497), np.float64(2.087109747681865), np.float64(1.9153941018488496), np.float64(0.7561198675156628), np.float64(3.0090628167774667), np.float64(0.5170545817574794), np.float64(0.06049125719921582), np.float64(2.3692770515325), np.float64(0.8014855753165543), np.float64(0.5170545884141458), np.float64(1.497071332380024), np.float64(1.7238836217379525), np.float64(1.194647870497375), np.float64(0.30245342722941515), np.float64(1.875089227417351), np.float64(0.5293103615204593), np.float64(0.7258759629166031), np.float64(0.36294324777537773), np.float64(0.6048995806725016)]
