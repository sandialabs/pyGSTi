# %% [markdown]
# # Simultaneous RB
#
# This tutorial shows how to easily run multiple RB experiments concurrently. This includes running RB on different subsets of a device, as well as running [simultaneous RB](https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.122.200502) experiments. Here we'll demonstrate generating an experiment to run 1, 2, 3 and 4 qubit RB in sequence (i.e., separately), as well as running 1-qubit RB in parallel on all the qubits (i.e., simultaneously).
#
# Note that this functionality is not specific to RB: similar code could be used to combine multiple GST experiments, or GST and RB experiments, etc.

# %%
import pygsti
from pygsti.processors import QubitProcessorSpec as QPS
from pygsti.processors import CliffordCompilationRules as CCR

# %% [markdown]
# Let's define the layout and gates of a 4-qubit device that we want to do this experiment on.

# %%
n_qubits = 4
qubit_labels = ['Q'+str(i) for i in range(n_qubits)]
gate_names = ['Gc{}'.format(i) for i in range(24)] + ['Gcnot'] 
pspec = QPS(n_qubits, gate_names, qubit_labels=qubit_labels, geometry='ring')

compilations = {'absolute': CCR.create_standard(pspec, 'absolute', ('paulis', '1Qcliffords'), verbosity=0),            
                'paulieq': CCR.create_standard(pspec, 'paulieq', ('1Qcliffords', 'allcnots'), verbosity=0)}

# %% [markdown]
# Now let's generate the separate 1-4 qubit RB experiments. We'll run Mirror RB, but this works for all types of RB.

# %%
# The qubit sets of each size to benchmark, and sampling details.
qubits = {1: ['Q0',], 2:['Q0','Q1'], 3:['Q0','Q1','Q2'], 4:['Q0','Q1','Q2', 'Q3']}
# The depths for the different number of qubits.
depths = {1: [0, 2, 4, 8, 16, 32, 64, 128, 256, 512],
          2: [0, 2, 4, 8, 16, 32, 64, 128],
          3: [0, 2, 4, 8, 16, 32, 64],
          4: [0, 2, 4, 8, 16, 32]}

# This loops through an generates the experiment design for each case.
designs = {}
for n in [1,2,3,4]:
    
    designs[str(n)+'Q-RB'] = pygsti.protocols.MirrorRBDesign(pspec, depths[n], 10, qubit_labels=qubits[n],
                                                             clifford_compilations=compilations,
                                                              sampler='edgegrab', samplerargs=[0.5],
                                                              add_default_protocol=True)
# Out:
# - Sampling 10 circuits at MRB length 0 (1 of 10 depths) with seed 308110
# - Sampling 10 circuits at MRB length 2 (2 of 10 depths) with seed 308120
# - Sampling 10 circuits at MRB length 4 (3 of 10 depths) with seed 308130
# - Sampling 10 circuits at MRB length 8 (4 of 10 depths) with seed 308140
# - Sampling 10 circuits at MRB length 16 (5 of 10 depths) with seed 308150
# - Sampling 10 circuits at MRB length 32 (6 of 10 depths) with seed 308160
# - Sampling 10 circuits at MRB length 64 (7 of 10 depths) with seed 308170
# - Sampling 10 circuits at MRB length 128 (8 of 10 depths) with seed 308180
# - Sampling 10 circuits at MRB length 256 (9 of 10 depths) with seed 308190
# - Sampling 10 circuits at MRB length 512 (10 of 10 depths) with seed 308200
# - Sampling 10 circuits at MRB length 0 (1 of 8 depths) with seed 310361
# - Sampling 10 circuits at MRB length 2 (2 of 8 depths) with seed 310371
# - Sampling 10 circuits at MRB length 4 (3 of 8 depths) with seed 310381
# - Sampling 10 circuits at MRB length 8 (4 of 8 depths) with seed 310391
# - Sampling 10 circuits at MRB length 16 (5 of 8 depths) with seed 310401
# - Sampling 10 circuits at MRB length 32 (6 of 8 depths) with seed 310411
# - Sampling 10 circuits at MRB length 64 (7 of 8 depths) with seed 310421
# - Sampling 10 circuits at MRB length 128 (8 of 8 depths) with seed 310431
# - Sampling 10 circuits at MRB length 0 (1 of 7 depths) with seed 716027
# - Sampling 10 circuits at MRB length 2 (2 of 7 depths) with seed 716037
# - Sampling 10 circuits at MRB length 4 (3 of 7 depths) with seed 716047
# - Sampling 10 circuits at MRB length 8 (4 of 7 depths) with seed 716057
# - Sampling 10 circuits at MRB length 16 (5 of 7 depths) with seed 716067
# - Sampling 10 circuits at MRB length 32 (6 of 7 depths) with seed 716077
# - Sampling 10 circuits at MRB length 64 (7 of 7 depths) with seed 716087
# - Sampling 10 circuits at MRB length 0 (1 of 6 depths) with seed 226169
# - Sampling 10 circuits at MRB length 2 (2 of 6 depths) with seed 226179
# - Sampling 10 circuits at MRB length 4 (3 of 6 depths) with seed 226189
# - Sampling 10 circuits at MRB length 8 (4 of 6 depths) with seed 226199
# - Sampling 10 circuits at MRB length 16 (5 of 6 depths) with seed 226209
# - Sampling 10 circuits at MRB length 32 (6 of 6 depths) with seed 226219

# %% [markdown]
# Next, we generate the simultaneous 1-qubit RB experiment. We do this by constructing each of the 1-qubit experiment designs, and then combining them together in a `SimultaneousExperimentDesign`.

# %%
oneQdesigns = []
for q in qubit_labels:
    oneQdesigns.append(pygsti.protocols.MirrorRBDesign(pspec, depths[1], 10, qubit_labels=[q,], 
                                                       clifford_compilations=compilations,
                                                sampler='edgegrab', samplerargs=[0.],
                                                add_default_protocol=True))
    
sim1Qdesign = pygsti.protocols.SimultaneousExperimentDesign(oneQdesigns)
# Out:
# - Sampling 10 circuits at MRB length 0 (1 of 10 depths) with seed 635075
# - Sampling 10 circuits at MRB length 2 (2 of 10 depths) with seed 635085
# - Sampling 10 circuits at MRB length 4 (3 of 10 depths) with seed 635095
# - Sampling 10 circuits at MRB length 8 (4 of 10 depths) with seed 635105
# - Sampling 10 circuits at MRB length 16 (5 of 10 depths) with seed 635115
# - Sampling 10 circuits at MRB length 32 (6 of 10 depths) with seed 635125
# - Sampling 10 circuits at MRB length 64 (7 of 10 depths) with seed 635135
# - Sampling 10 circuits at MRB length 128 (8 of 10 depths) with seed 635145
# - Sampling 10 circuits at MRB length 256 (9 of 10 depths) with seed 635155
# - Sampling 10 circuits at MRB length 512 (10 of 10 depths) with seed 635165
# - Sampling 10 circuits at MRB length 0 (1 of 10 depths) with seed 801031
# - Sampling 10 circuits at MRB length 2 (2 of 10 depths) with seed 801041
# - Sampling 10 circuits at MRB length 4 (3 of 10 depths) with seed 801051
# - Sampling 10 circuits at MRB length 8 (4 of 10 depths) with seed 801061
# - Sampling 10 circuits at MRB length 16 (5 of 10 depths) with seed 801071
# - Sampling 10 circuits at MRB length 32 (6 of 10 depths) with seed 801081
# - Sampling 10 circuits at MRB length 64 (7 of 10 depths) with seed 801091
# - Sampling 10 circuits at MRB length 128 (8 of 10 depths) with seed 801101
# - Sampling 10 circuits at MRB length 256 (9 of 10 depths) with seed 801111
# - Sampling 10 circuits at MRB length 512 (10 of 10 depths) with seed 801121
# - Sampling 10 circuits at MRB length 0 (1 of 10 depths) with seed 336996
# - Sampling 10 circuits at MRB length 2 (2 of 10 depths) with seed 337006
# - Sampling 10 circuits at MRB length 4 (3 of 10 depths) with seed 337016
# - Sampling 10 circuits at MRB length 8 (4 of 10 depths) with seed 337026
# - Sampling 10 circuits at MRB length 16 (5 of 10 depths) with seed 337036
# - Sampling 10 circuits at MRB length 32 (6 of 10 depths) with seed 337046
# - Sampling 10 circuits at MRB length 64 (7 of 10 depths) with seed 337056
# - Sampling 10 circuits at MRB length 128 (8 of 10 depths) with seed 337066
# - Sampling 10 circuits at MRB length 256 (9 of 10 depths) with seed 337076
# - Sampling 10 circuits at MRB length 512 (10 of 10 depths) with seed 337086
# - Sampling 10 circuits at MRB length 0 (1 of 10 depths) with seed 178801
# - Sampling 10 circuits at MRB length 2 (2 of 10 depths) with seed 178811
# - Sampling 10 circuits at MRB length 4 (3 of 10 depths) with seed 178821
# - Sampling 10 circuits at MRB length 8 (4 of 10 depths) with seed 178831
# - Sampling 10 circuits at MRB length 16 (5 of 10 depths) with seed 178841
# - Sampling 10 circuits at MRB length 32 (6 of 10 depths) with seed 178851
# - Sampling 10 circuits at MRB length 64 (7 of 10 depths) with seed 178861
# - Sampling 10 circuits at MRB length 128 (8 of 10 depths) with seed 178871
# - Sampling 10 circuits at MRB length 256 (9 of 10 depths) with seed 178881
# - Sampling 10 circuits at MRB length 512 (10 of 10 depths) with seed 178891

# %% [markdown]
# As we want to run this simultanoeus 1-qubit RB experiment alongside the 1-4 qubit RB experiments, we add it to the `designs` dictionary where we're storing all the experiment designs that are to be run together (but not in parallel).

# %%
designs['1Q-SRB'] = sim1Qdesign

# %% [markdown]
# Then we just combine them together in a `CombinedExperimentDesign`. This is then written to a directory in the same way as with all experiment designs. The dataset template contains all the circuits that need to be run. This will include all the circuits from all the sub-designs, including the simultaneous 1-qubit circuits in the necessary parallel form. After data is added to the template, it is then read-in in the same way as always.

# %%
qubit_error_rate = 0.002
def simulate_taking_data(data_template_filename):
    """Simulate taking data and filling the results into a template dataset.txt file"""
    error_rates = {}
    for gn in pspec.gate_names:
        n = pspec.gate_num_qubits(gn)
        gate_error_rate = n * qubit_error_rate
        error_rates[gn] = [gate_error_rate/(4**n - 1)] * (4**n - 1)
    noisemodel = pygsti.models.create_crosstalk_free_model(pspec, stochastic_error_probs=error_rates)
    pygsti.io.fill_in_empty_dataset_with_fake_data(data_template_filename, noisemodel, num_samples=1000, seed=1234)

# %%
combdesign = pygsti.protocols.CombinedExperimentDesign(designs)

pygsti.io.write_empty_protocol_data('../../../tutorial_files/test_combrb_dir', combdesign, clobber_ok=True)

# -- fill in the dataset file in ../../../tutorial_files/test_combrb_dir/data/dataset.txt --
simulate_taking_data('../../../tutorial_files/test_combrb_dir/data/dataset.txt') # REPLACE with actual data-taking

data = pygsti.io.read_data_from_dir('../../../tutorial_files/test_combrb_dir')

# %% [markdown]
# We can then run any protocols that we want to on the imported data. Because we set `add_default_protocol=True` when creating the protocols, the imported data contains the `RB` protocols ready to run (with the appropriate optional arguments set for Mirror RB). We can run all these default protocols by creating a `pygsti.protocols.DefaultRunner()` protocol, and running it on the data.
#
# We can also run more protocols (e.g., a test for instability if the data is time-stamped) just by creating the relevant protocols objects, and passing them this data.

# %%
protocol = pygsti.protocols.DefaultRunner()
results = protocol.run(data)
# Out:
# Running protocol RB at ./1Q-RB
# Running protocol RB at ./2Q-RB
# Running protocol RB at ./3Q-RB
# Running protocol RB at ./4Q-RB
# Running protocol RB at ./1Q-SRB/('Q0',)
# Running protocol RB at ./1Q-SRB/('Q1',)
# Running protocol RB at ./1Q-SRB/('Q2',)
# Running protocol RB at ./1Q-SRB/('Q3',)

# %%
results['1Q-SRB'].keys()
# Out:
# dict_keys([('Q0',), ('Q1',), ('Q2',), ('Q3',)])

# %% [markdown]
# The `results` behaves like a dictionary, for accessing the individual results.

# %%
for i in ['1Q-RB', '2Q-RB', '3Q-RB' , '4Q-RB']:
    r = results[i].for_protocol['RB'].fits['A-fixed'].estimates['r']
    print('The RB error rate on {} qubit is {}'.format(i, r))
    
print()
for i in [('Q0',),('Q1',),('Q2',),('Q3',)]:
    r = results['1Q-SRB'][i].for_protocol['RB'].fits['A-fixed'].estimates['r']
    print('When running simultaneously, the RB error rate on {} qubit is {}'.format(i, r))
# Out:
# The RB error rate on 1Q-RB qubit is 0.003555668686538449
# The RB error rate on 2Q-RB qubit is 0.006934565339402725
# The RB error rate on 3Q-RB qubit is 0.01034019399236456
# The RB error rate on 4Q-RB qubit is 0.014412710526946322
#
# When running simultaneously, the RB error rate on ('Q0',) qubit is 0.0034082779159992915
# When running simultaneously, the RB error rate on ('Q1',) qubit is 0.0034139571994911133
# When running simultaneously, the RB error rate on ('Q2',) qubit is 0.0035224260832586174
# When running simultaneously, the RB error rate on ('Q3',) qubit is 0.003476636924230281

# %%
for i in ['1Q-RB', '2Q-RB', '3Q-RB' , '4Q-RB']:
    results[i].for_protocol['RB'].plot(title=i)

# %% [markdown]
# **For more information** and examples on running multiple benchmarking protocols on a processor, check out the [volumetric benchmarking tutorial](../benchmarks/VolumetricBenchmarks).
